# %%
""" Importando bibliotecas que serão utilizadas no projeto.
"""

import pandas as pd
import json
import requests
from plyer import notification

# %%
""" Função de alerta sobre a requisição do API. 
A função deverá retornar se houve sucesso ou qual o tipo de alerta, segundo o valor do status do HTTP.
"""


def alerta_API(nome, response):
    titulo = f"Alerta sobre a requisição do API:{nome}"
    
    if response.status_code > 500:
       mensagem  = "Alerta crítico na requisição do API"
    elif 200 > response.status_code < 500:
        mensagem  = "Alerta moderado na requisição do API"
    elif response.status_code == 200:
        mensagem  = "Sucesso ao requisitar o API"
    
    status_HTTP = response.status_code
    
    notification.notify(
        title = titulo,
        message = f"{mensagem}\n o status do HTTP é {status_HTTP}" 
    )

# %%
""" Requisitando os dados sobre a vacinação de COVID no Brasil - API OPENDATASUS
"""

brasil= "Cobertura Vacinal Brasileira"

url = "https://imunizacao-es.saude.gov.br/_search"

payload = json.dumps({
  "size": 10000
})
headers = {
  'Content-Type': 'application/json',
  'Authorization': 'Basic aW11bml6YWNhb19wdWJsaWM6cWx0bzV0JjdyX0ArI1Rsc3RpZ2k='
}

response_brasil = requests.request("POST", url, headers=headers, data=payload)

alerta_API(nome=brasil,response=response_brasil)

response_brasil.json()
vacinas_brasil = response_brasil.json()

# %%
vacinas_brasil["hits"]["hits"]
# Out:
# [{'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'd264ef96-0667-466f-8487-320733836070-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'SIGRAH',
#    'dt_deleted': None,
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_idade': 12,
#    'vacina_categoria_nome': 'Trabalhadores de Saúde',
#    'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_endereco_nmMunicipio': 'BELO HORIZONTE',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'MG',
#    'estabelecimento_razaoSocial': 'MUNICIPIO DE BELO HORIZONTE',
#    'estabelecimento_valor': '9166718',
#    'vacina_lote': 'GY0354',
#    'vacina_dataAplicacao': '2023-12-22T00:00:00.000Z',
#    'paciente_endereco_uf': 'MG',
#    'paciente_endereco_coIbgeMunicipio': '310620',
#    'data_importacao_datalake': '2023-12-23T18:06:22.000Z',
#    'paciente_id': '3a69d2e1dc3984ad0ab59925ef0bfd185f527bb7b185bbd35429659f844c7726',
#    '@timestamp': '2023-12-23T21:15:02.653Z',
#    'document_id': 'd264ef96-0667-466f-8487-320733836070-i0b0',
#    'id_sistema_origem': '19788',
#    'paciente_racaCor_codigo': '03',
#    'ds_condicao_maternal': None,
#    'vacina_descricao_dose': '2ª Dose',
#    'estalecimento_noFantasia': 'CENTRO DE SAUDE ZILAH SPOSITO',
#    'paciente_dataNascimento': '2011-12-14',
#    'data_importacao_rnds': '2023-12-22T19:14:26.000Z',
#    '@version': '1',
#    'vacina_codigo': '99',
#    'vacina_numDose': '2',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'vacina_categoria_codigo': '9',
#    'co_condicao_maternal': None,
#    'status': 'final',
#    'paciente_enumSexoBiologico': 'F',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'BELO HORIZONTE',
#    'vacina_grupoAtendimento_codigo': '000926',
#    'paciente_racaCor_valor': 'PARDA',
#    'paciente_endereco_cep': '31748',
#    'estabelecimento_municipio_codigo': '310620',
#    'vacina_fabricante_referencia': None,
#    'vacina_grupoAtendimento_nome': 'Outros'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '5f52e28f-438c-4acb-993e-a966c9a65d7d-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'Novo PNI',
#    'dt_deleted': None,
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_idade': 10,
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_endereco_nmMunicipio': 'SAO GONCALO',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'RJ',
#    'estabelecimento_razaoSocial': 'SECRETARIA MUNICIPAL DE SAUDE DE SAO GONCALO',
#    'estabelecimento_valor': '2702959',
#    'vacina_lote': 'GN0764',
#    'vacina_dataAplicacao': '2023-12-22T00:00:00.000Z',
#    'paciente_endereco_uf': 'RJ',
#    'paciente_endereco_coIbgeMunicipio': '330490',
#    'data_importacao_datalake': '2023-12-23T18:06:22.000Z',
#    'paciente_id': 'b2fb11b0bffa405519adfbdfdc6925faa1fe4034ffee187e6b7d1156ba547da6',
#    '@timestamp': '2023-12-23T21:15:02.628Z',
#    'document_id': '5f52e28f-438c-4acb-993e-a966c9a65d7d-i0b0',
#    'id_sistema_origem': '16341',
#    'paciente_racaCor_codigo': '03',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_descricao_dose': '2ª Dose',
#    'estalecimento_noFantasia': 'POLO SANITARIO JORGE TEIXEIRA DE LIMA',
#    'paciente_dataNascimento': '2013-03-17',
#    'data_importacao_rnds': '2023-12-22T19:39:16.000Z',
#    '@version': '1',
#    'vacina_codigo': '99',
#    'vacina_numDose': '2',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'vacina_categoria_codigo': '2',
#    'co_condicao_maternal': 1,
#    'status': 'final',
#    'paciente_enumSexoBiologico': 'M',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'SAO GONCALO',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'paciente_racaCor_valor': 'PARDA',
#    'paciente_endereco_cep': '24716',
#    'estabelecimento_municipio_codigo': '330490',
#    'vacina_fabricante_referencia': '28290',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '03d35d7a-5a30-4665-8873-cb27fc1bfde7-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'Novo PNI',
#    'dt_deleted': None,
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_idade': 12,
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_nome': 'SINOVAC/BUTANTAN',
#    'paciente_endereco_nmMunicipio': 'MANAUS',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'AM',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE CAREIRO DA VARZEA',
#    'estabelecimento_valor': '3940713',
#    'vacina_lote': '220303',
#    'vacina_dataAplicacao': '2023-09-22T00:00:00.000Z',
#    'paciente_endereco_uf': 'AM',
#    'paciente_endereco_coIbgeMunicipio': '130260',
#    'data_importacao_datalake': '2023-12-23T18:06:22.000Z',
#    'paciente_id': '41c476e2a9bc892f825d34c9ee53b79fb11e5a465c80ec5a43435f678e049a6c',
#    '@timestamp': '2023-12-23T21:15:02.630Z',
#    'document_id': '03d35d7a-5a30-4665-8873-cb27fc1bfde7-i0b0',
#    'id_sistema_origem': '16341',
#    'paciente_racaCor_codigo': '03',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_descricao_dose': '2ª Dose',
#    'estalecimento_noFantasia': 'UNIDADE BASICA DE SAUDE PEDRO FIGUEIREDO DE SOUZA',
#    'paciente_dataNascimento': '2010-11-17',
#    'data_importacao_rnds': '2023-12-23T02:15:37.000Z',
#    '@version': '1',
#    'vacina_codigo': '86',
#    'vacina_numDose': '2',
#    'vacina_nome': 'COVID-19 SINOVAC/BUTANTAN - CORONAVAC',
#    'vacina_categoria_codigo': '2',
#    'co_condicao_maternal': 1,
#    'status': 'final',
#    'paciente_enumSexoBiologico': 'F',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'CAREIRO DA VARZEA',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'paciente_racaCor_valor': 'PARDA',
#    'paciente_endereco_cep': '69075',
#    'estabelecimento_municipio_codigo': '130115',
#    'vacina_fabricante_referencia': '152',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '6691e569-b108-4205-a228-fdcea04063b4-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'Novo PNI',
#    'dt_deleted': None,
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_idade': 10,
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_endereco_nmMunicipio': 'RIO DE JANEIRO',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'RJ',
#    'estabelecimento_razaoSocial': 'SMS RIO CMS DR NAGIB JORGE FARAH AP 31',
#    'estabelecimento_valor': '2296535',
#    'vacina_lote': 'GN0764',
#    'vacina_dataAplicacao': '2023-09-25T00:00:00.000Z',
#    'paciente_endereco_uf': 'RJ',
#    'paciente_endereco_coIbgeMunicipio': '330455',
#    'data_importacao_datalake': '2023-12-23T18:06:22.000Z',
#    'paciente_id': 'bc85ec3d9976781207f406683c5ea9ca0ea1c6084fc5ff2582bf2e5a903a94a2',
#    '@timestamp': '2023-12-23T21:15:02.656Z',
#    'document_id': '6691e569-b108-4205-a228-fdcea04063b4-i0b0',
#    'id_sistema_origem': '16341',
#    'paciente_racaCor_codigo': '03',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_descricao_dose': '3ª Dose',
#    'estalecimento_noFantasia': 'SMS CMS NAGIB JORGE FARAH AP 31',
#    'paciente_dataNascimento': '2013-03-21',
#    'data_importacao_rnds': '2023-12-23T15:16:54.000Z',
#    '@version': '1',
#    'vacina_codigo': '99',
#    'vacina_numDose': '3',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'vacina_categoria_codigo': '2',
#    'co_condicao_maternal': 1,
#    'status': 'final',
#    'paciente_enumSexoBiologico': 'M',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'RIO DE JANEIRO',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'paciente_racaCor_valor': 'PARDA',
#    'paciente_endereco_cep': '21240',
#    'estabelecimento_municipio_codigo': '330455',
#    'vacina_fabricante_referencia': '28290',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'd877440d-1702-469e-b869-a6f39672f5d6-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'Novo PNI',
#    'dt_deleted': None,
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_idade': 10,
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_endereco_nmMunicipio': 'GRANJA',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'CE',
#    'estabelecimento_razaoSocial': 'PREF M GRANJA',
#    'estabelecimento_valor': '7559208',
#    'vacina_lote': 'GY0354',
#    'vacina_dataAplicacao': '2023-12-16T00:00:00.000Z',
#    'paciente_endereco_uf': 'CE',
#    'paciente_endereco_coIbgeMunicipio': '230470',
#    'data_importacao_datalake': '2023-12-23T18:06:22.000Z',
#    'paciente_id': '6c90a8786abcd54e680e45d1fdf0be39097ce46b6656293b3dc2f82d7afb33a9',
#    '@timestamp': '2023-12-23T21:15:02.658Z',
#    'document_id': 'd877440d-1702-469e-b869-a6f39672f5d6-i0b0',
#    'id_sistema_origem': '16341',
#    'paciente_racaCor_codigo': '03',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_descricao_dose': '3ª Dose',
#    'estalecimento_noFantasia': 'UNIDADE BASICA DE SAUDE MARIA IRACY ARRUDA',
#    'paciente_dataNascimento': '2013-06-26',
#    'data_importacao_rnds': '2023-12-22T23:11:10.000Z',
#    '@version': '1',
#    'vacina_codigo': '99',
#    'vacina_numDose': '3',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'vacina_categoria_codigo': '2',
#    'co_condicao_maternal': 1,
#    'status': 'final',
#    'paciente_enumSexoBiologico': 'F',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'GRANJA',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'paciente_racaCor_valor': 'PARDA',
#    'paciente_endereco_cep': '62437',
#    'estabelecimento_municipio_codigo': '230470',
#    'vacina_fabricante_referencia': '28290',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'ef4a1e15-07ae-4cf0-8d76-6c72d78ecd79-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'SIGRAH',
#    'dt_deleted': None,
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_idade': 14,
#    'vacina_categoria_nome': 'Trabalhadores de Saúde',
#    'vacina_fabricante_nome': 'PFIZER',
#    'paciente_endereco_nmMunicipio': 'BELO HORIZONTE',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'MG',
#    'estabelecimento_razaoSocial': 'MUNICIPIO DE BELO HORIZONTE',
#    'estabelecimento_valor': '0022640',
#    'vacina_lote': 'FW6014',
#    'vacina_dataAplicacao': '2023-02-03T00:00:00.000Z',
#    'paciente_endereco_uf': 'MG',
#    'paciente_endereco_coIbgeMunicipio': '310620',
#    'data_importacao_datalake': '2023-12-23T18:06:22.000Z',
#    'paciente_id': '7f25365f8ce7fa25230bbc3a9107e8a10e1120815c7d3fac880818602ae4de69',
#    '@timestamp': '2023-12-23T21:15:02.660Z',
#    'document_id': 'ef4a1e15-07ae-4cf0-8d76-6c72d78ecd79-i0b0',
#    'id_sistema_origem': '19788',
#    'paciente_racaCor_codigo': '01',
#    'ds_condicao_maternal': None,
#    'vacina_descricao_dose': 'Reforço',
#    'estalecimento_noFantasia': 'CENTRO DE SAUDE DR JOSE DOMINGOS',
#    'paciente_dataNascimento': '2008-12-16',
#    'data_importacao_rnds': '2023-12-22T19:06:02.000Z',
#    '@version': '1',
#    'vacina_codigo': '87',
#    'vacina_numDose': '38',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY',
#    'vacina_categoria_codigo': '9',
#    'co_condicao_maternal': None,
#    'status': 'final',
#    'paciente_enumSexoBiologico': 'M',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'BELO HORIZONTE',
#    'vacina_grupoAtendimento_codigo': '000926',
#    'paciente_racaCor_valor': 'BRANCA',
#    'paciente_endereco_cep': '30610',
#    'estabelecimento_municipio_codigo': '310620',
#    'vacina_fabricante_referencia': None,
#    'vacina_grupoAtendimento_nome': 'Outros'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'b30fbfec-bdda-4897-8a79-8da872d6a33d-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'Novo PNI',
#    'dt_deleted': None,
#    'paciente_nacionalidade_enumNacionalidade': 'E',
#    'paciente_idade': 20,
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_nome': 'PFIZER',
#    'paciente_endereco_nmMunicipio': 'PACARAIMA',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'RR',
#    'estabelecimento_razaoSocial': 'ESTADO DE RORAIMA',
#    'estabelecimento_valor': '2476827',
#    'vacina_lote': 'PCA0101',
#    'vacina_dataAplicacao': '2023-11-23T00:00:00.000Z',
#    'paciente_endereco_uf': 'RR',
#    'paciente_endereco_coIbgeMunicipio': '140045',
#    'data_importacao_datalake': '2023-12-23T18:06:22.000Z',
#    'paciente_id': 'd0ebea05dd6f32deba3c5fd552190cb2b933f295ccf6b45f23c86c3380f6d5dd',
#    '@timestamp': '2023-12-23T21:15:02.674Z',
#    'document_id': 'b30fbfec-bdda-4897-8a79-8da872d6a33d-i0b0',
#    'id_sistema_origem': '16341',
#    'paciente_racaCor_codigo': '03',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_descricao_dose': '3ª Dose',
#    'estalecimento_noFantasia': 'HOSPITAL DELIO DE OLIVEIRA TUPINAMBA',
#    'paciente_dataNascimento': '2003-10-23',
#    'data_importacao_rnds': '2023-12-22T18:32:19.000Z',
#    '@version': '1',
#    'vacina_codigo': '87',
#    'vacina_numDose': '3',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY',
#    'vacina_categoria_codigo': '2',
#    'co_condicao_maternal': 1,
#    'status': 'final',
#    'paciente_enumSexoBiologico': 'F',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'PACARAIMA',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'paciente_racaCor_valor': 'PARDA',
#    'paciente_endereco_cep': '69345',
#    'estabelecimento_municipio_codigo': '140045',
#    'vacina_fabricante_referencia': '28290',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'dc866de7-69bd-4102-ba46-8a71506edb51-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'Novo PNI',
#    'dt_deleted': None,
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_idade': 9,
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_endereco_nmMunicipio': 'EIRUNEPE',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'AM',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE EIRUNEPE',
#    'estabelecimento_valor': '2018691',
#    'vacina_lote': 'GN0764',
#    'vacina_dataAplicacao': '2023-12-01T00:00:00.000Z',
#    'paciente_endereco_uf': 'AM',
#    'paciente_endereco_coIbgeMunicipio': '130140',
#    'data_importacao_datalake': '2023-12-23T18:06:22.000Z',
#    'paciente_id': '5dd19b701c963a5a15c82f4a0fa5544675b93e3097d0ea14fd720f90b90c7827',
#    '@timestamp': '2023-12-23T21:15:02.676Z',
#    'document_id': 'dc866de7-69bd-4102-ba46-8a71506edb51-i0b0',
#    'id_sistema_origem': '16341',
#    'paciente_racaCor_codigo': '03',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_descricao_dose': '3ª Dose',
#    'estalecimento_noFantasia': 'UNIDADE BASICA GENESIO ALBUQUERQUE',
#    'paciente_dataNascimento': '2014-06-03',
#    'data_importacao_rnds': '2023-12-22T20:50:06.000Z',
#    '@version': '1',
#    'vacina_codigo': '99',
#    'vacina_numDose': '3',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'vacina_categoria_codigo': '2',
#    'co_condicao_maternal': 1,
#    'status': 'final',
#    'paciente_enumSexoBiologico': 'F',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'EIRUNEPE',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'paciente_racaCor_valor': 'PARDA',
#    'paciente_endereco_cep': '',
#    'estabelecimento_municipio_codigo': '130140',
#    'vacina_fabricante_referencia': '28290',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '39c3e3cb-8404-4bf8-bf45-32a766ecaddf-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'Novo PNI',
#    'dt_deleted': None,
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_idade': 15,
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_nome': 'PFIZER',
#    'paciente_endereco_nmMunicipio': 'MACEIO',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'AL',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE MACEIO',
#    'estabelecimento_valor': '2009765',
#    'vacina_lote': '2F1070A',
#    'vacina_dataAplicacao': '2023-12-22T00:00:00.000Z',
#    'paciente_endereco_uf': 'AL',
#    'paciente_endereco_coIbgeMunicipio': '270430',
#    'data_importacao_datalake': '2023-12-23T18:06:22.000Z',
#    'paciente_id': '6b45e61b150d0f7162ebefb1891a2a2ca998b6e29fec1f6150707255645a0d39',
#    '@timestamp': '2023-12-23T21:15:02.665Z',
#    'document_id': '39c3e3cb-8404-4bf8-bf45-32a766ecaddf-i0b0',
#    'id_sistema_origem': '16341',
#    'paciente_racaCor_codigo': '01',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_descricao_dose': '1ª Dose Revacinação',
#    'estalecimento_noFantasia': 'DISTRITO SANITARIO',
#    'paciente_dataNascimento': '2008-07-04',
#    'data_importacao_rnds': '2023-12-22T22:21:23.000Z',
#    '@version': '1',
#    'vacina_codigo': '87',
#    'vacina_numDose': '32',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY',
#    'vacina_categoria_codigo': '2',
#    'co_condicao_maternal': 1,
#    'status': 'final',
#    'paciente_enumSexoBiologico': 'M',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'MACEIO',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'paciente_racaCor_valor': 'BRANCA',
#    'paciente_endereco_cep': '57082',
#    'estabelecimento_municipio_codigo': '270430',
#    'vacina_fabricante_referencia': '28290',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '1eac05e5-4dbf-4aec-90a7-723b393db7a0-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'Novo PNI',
#    'dt_deleted': None,
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_idade': 5,
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_endereco_nmMunicipio': 'CARDEAL DA SILVA',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'BA',
#    'estabelecimento_razaoSocial': 'MUNICIPIO DE CARDEAL DA SILVA',
#    'estabelecimento_valor': '2512130',
#    'vacina_lote': 'GY0354',
#    'vacina_dataAplicacao': '2023-12-07T00:00:00.000Z',
#    'paciente_endereco_uf': 'BA',
#    'paciente_endereco_coIbgeMunicipio': '290700',
#    'data_importacao_datalake': '2023-12-23T18:06:22.000Z',
#    'paciente_id': 'aeb713b53f396bdc88c1f6f969bf9eb6d7697d0cab6723547569bc0a77236c9f',
#    '@timestamp': '2023-12-23T21:15:02.682Z',
#    'document_id': '1eac05e5-4dbf-4aec-90a7-723b393db7a0-i0b0',
#    'id_sistema_origem': '16341',
#    'paciente_racaCor_codigo': '01',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_descricao_dose': '1º Reforço',
#    'estalecimento_noFantasia': 'PSF ALEXANDRE BARBOSA SEDE',
#    'paciente_dataNascimento': '2018-02-07',
#    'data_importacao_rnds': '2023-12-22T19:15:01.000Z',
#    '@version': '1',
#    'vacina_codigo': '99',
#    'vacina_numDose': '6',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'vacina_categoria_codigo': '2',
#    'co_condicao_maternal': 1,
#    'status': 'final',
#    'paciente_enumSexoBiologico': 'F',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'CARDEAL DA SILVA',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'paciente_racaCor_valor': 'BRANCA',
#    'paciente_endereco_cep': '48390',
#    'estabelecimento_municipio_codigo': '290700',
#    'vacina_fabricante_referencia': '28290',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '57358f61-b6b4-4d13-bda8-dd7e866614c5-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'Novo PNI',
#    'dt_deleted': None,
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_idade': 6,
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_endereco_nmMunicipio': 'JUAZEIRO',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'BA',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE JUAZEIRO',
#    'estabelecimento_valor': '5881617',
#    'vacina_lote': 'GN0764',
#    'vacina_dataAplicacao': '2023-12-22T00:00:00.000Z',
#    'paciente_endereco_uf': 'BA',
#    'paciente_endereco_coIbgeMunicipio': '291840',
#    'data_importacao_datalake': '2023-12-23T18:06:22.000Z',
#    'paciente_id': 'c0f4fa022073a36bb9433ad6f86f0d66b410cc27147ac284fd84f2f2ffa51ff6',
#    '@timestamp': '2023-12-23T21:15:02.677Z',
#    'document_id': '57358f61-b6b4-4d13-bda8-dd7e866614c5-i0b0',
#    'id_sistema_origem': '16341',
#    'paciente_racaCor_codigo': '03',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_descricao_dose': '3ª Dose',
#    'estalecimento_noFantasia': 'USF VILA JACARE',
#    'paciente_dataNascimento': '2017-11-19',
#    'data_importacao_rnds': '2023-12-22T18:23:56.000Z',
#    '@version': '1',
#    'vacina_codigo': '99',
#    'vacina_numDose': '3',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'vacina_categoria_codigo': '2',
#    'co_condicao_maternal': 1,
#    'status': 'final',
#    'paciente_enumSexoBiologico': 'M',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'JUAZEIRO',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'paciente_racaCor_valor': 'PARDA',
#    'paciente_endereco_cep': '48917',
#    'estabelecimento_municipio_codigo': '291840',
#    'vacina_fabricante_referencia': '28290',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'b0c913a0-338c-4323-a66e-a9c39a229488-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'Novo PNI',
#    'dt_deleted': None,
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_idade': 10,
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_endereco_nmMunicipio': 'RIO DE JANEIRO',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'RJ',
#    'estabelecimento_razaoSocial': 'SMS RIO CF RINALDO DE LAMARE AP 21',
#    'estabelecimento_valor': '6506232',
#    'vacina_lote': 'GN0764',
#    'vacina_dataAplicacao': '2023-09-19T00:00:00.000Z',
#    'paciente_endereco_uf': 'RJ',
#    'paciente_endereco_coIbgeMunicipio': '330455',
#    'data_importacao_datalake': '2023-12-23T18:06:22.000Z',
#    'paciente_id': 'bf62b762cc61be3298940366c42ff24d947f81468f691de6083833e56e904a5c',
#    '@timestamp': '2023-12-23T21:15:02.771Z',
#    'document_id': 'b0c913a0-338c-4323-a66e-a9c39a229488-i0b0',
#    'id_sistema_origem': '16341',
#    'paciente_racaCor_codigo': '03',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_descricao_dose': '1º Reforço',
#    'estalecimento_noFantasia': 'SMS CF RINALDO DE LAMARE AP 21',
#    'paciente_dataNascimento': '2013-05-05',
#    'data_importacao_rnds': '2023-12-23T14:05:54.000Z',
#    '@version': '1',
#    'vacina_codigo': '99',
#    'vacina_numDose': '6',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'vacina_categoria_codigo': '2',
#    'co_condicao_maternal': 1,
#    'status': 'final',
#    'paciente_enumSexoBiologico': 'M',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'RIO DE JANEIRO',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'paciente_racaCor_valor': 'PARDA',
#    'paciente_endereco_cep': '22451',
#    'estabelecimento_municipio_codigo': '330455',
#    'vacina_fabricante_referencia': '28290',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'e0b00e1f-983e-4d7d-84b5-3ece2c8c71a3-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'Novo PNI',
#    'dt_deleted': None,
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_idade': 11,
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_endereco_nmMunicipio': 'TAMBORIL',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'CE',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE TAMBORIL',
#    'estabelecimento_valor': '2517221',
#    'vacina_lote': 'GY0354',
#    'vacina_dataAplicacao': '2023-12-23T00:00:00.000Z',
#    'paciente_endereco_uf': 'CE',
#    'paciente_endereco_coIbgeMunicipio': '231320',
#    'data_importacao_datalake': '2023-12-23T18:06:22.000Z',
#    'paciente_id': '3ab125a595b5ccb5999954d45d1a5209b94c1c6aa448f270af19aa1bfe7569df',
#    '@timestamp': '2023-12-23T21:15:02.785Z',
#    'document_id': 'e0b00e1f-983e-4d7d-84b5-3ece2c8c71a3-i0b0',
#    'id_sistema_origem': '16341',
#    'paciente_racaCor_codigo': '03',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_descricao_dose': '2ª Dose',
#    'estalecimento_noFantasia': 'UNIDADE DE SAUDE DA FAMILIA SEDE II',
#    'paciente_dataNascimento': '2012-09-17',
#    'data_importacao_rnds': '2023-12-23T11:02:31.000Z',
#    '@version': '1',
#    'vacina_codigo': '99',
#    'vacina_numDose': '2',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'vacina_categoria_codigo': '2',
#    'co_condicao_maternal': 1,
#    'status': 'final',
#    'paciente_enumSexoBiologico': 'M',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'TAMBORIL',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'paciente_racaCor_valor': 'PARDA',
#    'paciente_endereco_cep': '63750',
#    'estabelecimento_municipio_codigo': '231320',
#    'vacina_fabricante_referencia': '28290',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'b561bd45-ec2a-488b-8742-73a64153f07d-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'Novo PNI',
#    'dt_deleted': '2023-12-23T00:00:00.000Z',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_idade': 5,
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_endereco_nmMunicipio': 'SANTA BARBARA',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'MG',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE BARAO DE COCAIS',
#    'estabelecimento_valor': '3578097',
#    'vacina_lote': 'GN0764',
#    'vacina_dataAplicacao': '2023-10-21T00:00:00.000Z',
#    'paciente_endereco_uf': 'MG',
#    'paciente_endereco_coIbgeMunicipio': '315720',
#    'data_importacao_datalake': '2023-12-23T18:54:29.000Z',
#    'paciente_id': 'bd0735e2cdbfe2c572c7d60504da4a56b9b77106c24582b9d22b28c518f62275',
#    '@timestamp': '2023-12-23T21:15:02.790Z',
#    'document_id': 'b561bd45-ec2a-488b-8742-73a64153f07d-i0b0',
#    'id_sistema_origem': '16341',
#    'paciente_racaCor_codigo': '01',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_descricao_dose': '3ª Dose',
#    'estalecimento_noFantasia': 'UNIDADE BASICA DE SAUDE DR LINNEU DE OLIVEIRA LARA',
#    'paciente_dataNascimento': '2017-12-05',
#    'data_importacao_rnds': '2023-10-21T17:20:50.000Z',
#    '@version': '1',
#    'vacina_codigo': '99',
#    'vacina_numDose': '3',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'vacina_categoria_codigo': '2',
#    'co_condicao_maternal': 1,
#    'status': 'entered-in-error',
#    'paciente_enumSexoBiologico': 'F',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'BARAO DE COCAIS',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'paciente_racaCor_valor': 'BRANCA',
#    'paciente_endereco_cep': '35960',
#    'estabelecimento_municipio_codigo': '310540',
#    'vacina_fabricante_referencia': '28290',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '1ec517c0-1b0d-48bd-8530-34dc2a7be0ed-i0b0',
#   '_score': 1.0,
#   '_source': {'vacina_nome': 'COVID-19 PFIZER - COMIRNATY',
#    'paciente_endereco_uf': 'SP',
#    'paciente_dataNascimento': '1995-01-30',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_lote': '2F1070A',
#    '@version': '1',
#    'paciente_endereco_cep': '03568',
#    'vacina_fabricante_referencia': None,
#    'id_sistema_origem': '18262',
#    'co_condicao_maternal': None,
#    'paciente_endereco_nmMunicipio': 'SAO PAULO',
#    'vacina_categoria_codigo': '2',
#    'estalecimento_noFantasia': 'UBS PARQUE PAULISTANO',
#    'paciente_idade': 28,
#    'vacina_grupoAtendimento_codigo': '000210',
#    'estabelecimento_razaoSocial': 'PREFEITURA DO MUNICIPIO DE SAO PAULO',
#    'paciente_endereco_coPais': '10',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_racaCor_valor': 'SEM INFORMACAO',
#    'paciente_enumSexoBiologico': 'M',
#    'estabelecimento_valor': '6283616',
#    'estabelecimento_uf': 'SP',
#    'sistema_origem': 'VACIVIDA',
#    'data_importacao_datalake': '2023-12-22T18:06:23.000Z',
#    'data_importacao_rnds': '2023-12-21T21:12:50.000Z',
#    'paciente_id': 'bc32a9714583ba623d3df4af850f95ba8dab5b7aefd3c6df5c0014ee631a9957',
#    'ds_condicao_maternal': None,
#    '@timestamp': '2023-12-22T21:15:02.377Z',
#    'vacina_dataAplicacao': '2023-12-21T00:00:00.000Z',
#    'vacina_numDose': '1',
#    'estabelecimento_municipio_nome': 'SAO PAULO',
#    'vacina_codigo': '87',
#    'status': 'final',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária',
#    'vacina_descricao_dose': '1ª Dose',
#    'paciente_endereco_coIbgeMunicipio': '355030',
#    'dt_deleted': None,
#    'paciente_endereco_nmPais': 'BRASIL',
#    'document_id': '1ec517c0-1b0d-48bd-8530-34dc2a7be0ed-i0b0',
#    'vacina_fabricante_nome': 'PFIZER',
#    'paciente_racaCor_codigo': '99',
#    'estabelecimento_municipio_codigo': '355030'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '53cf9452-a6b5-46c8-a424-976176cae35d-i0b0',
#   '_score': 1.0,
#   '_source': {'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'paciente_endereco_uf': 'MT',
#    'paciente_dataNascimento': '2013-01-26',
#    'vacina_categoria_nome': 'Povos Indígenas',
#    'vacina_lote': 'GN0764',
#    '@version': '1',
#    'paciente_endereco_cep': '78640',
#    'vacina_fabricante_referencia': '28290',
#    'id_sistema_origem': '16341',
#    'co_condicao_maternal': 1,
#    'paciente_endereco_nmMunicipio': 'CANARANA',
#    'vacina_categoria_codigo': '7',
#    'estalecimento_noFantasia': 'POLO BASE AGUA BOA',
#    'paciente_idade': 10,
#    'vacina_grupoAtendimento_codigo': '000703',
#    'estabelecimento_razaoSocial': 'MINISTERIO DA SAUDE',
#    'paciente_endereco_coPais': '10',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_racaCor_valor': 'INDIGENA',
#    'paciente_enumSexoBiologico': 'M',
#    'estabelecimento_valor': '7227302',
#    'estabelecimento_uf': 'MT',
#    'sistema_origem': 'Novo PNI',
#    'data_importacao_datalake': '2023-12-22T18:06:23.000Z',
#    'data_importacao_rnds': '2023-12-22T13:08:38.000Z',
#    'paciente_id': '840b20da4d9b7012b4299afcd54018c7e249222528a9f17db02cadbb589172a8',
#    'ds_condicao_maternal': 'Nenhuma',
#    '@timestamp': '2023-12-22T21:15:02.399Z',
#    'vacina_dataAplicacao': '2023-10-19T00:00:00.000Z',
#    'vacina_numDose': '6',
#    'estabelecimento_municipio_nome': 'AGUA BOA',
#    'vacina_codigo': '99',
#    'status': 'final',
#    'vacina_grupoAtendimento_nome': 'Povos indígenas vivendo em terras indígenas',
#    'vacina_descricao_dose': '1º Reforço',
#    'paciente_endereco_coIbgeMunicipio': '510270',
#    'dt_deleted': None,
#    'paciente_endereco_nmPais': 'BRASIL',
#    'document_id': '53cf9452-a6b5-46c8-a424-976176cae35d-i0b0',
#    'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_racaCor_codigo': '05',
#    'estabelecimento_municipio_codigo': '510020'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '0ad37d9a-0fdb-4770-b04f-924f2d576da0-i0b0',
#   '_score': 1.0,
#   '_source': {'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'paciente_endereco_uf': 'AM',
#    'paciente_dataNascimento': '2016-11-21',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_lote': 'GN0764',
#    '@version': '1',
#    'paciente_endereco_cep': '69084',
#    'vacina_fabricante_referencia': None,
#    'id_sistema_origem': '18183',
#    'co_condicao_maternal': None,
#    'paciente_endereco_nmMunicipio': 'MANAUS',
#    'vacina_categoria_codigo': '2',
#    'estalecimento_noFantasia': 'USF DR ALFREDO CAMPOS',
#    'paciente_idade': 7,
#    'vacina_grupoAtendimento_codigo': '000210',
#    'estabelecimento_razaoSocial': 'MANAUS SECRETARIA MUNICIPAL DE SAUDE',
#    'paciente_endereco_coPais': '10',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_racaCor_valor': 'PARDA',
#    'paciente_enumSexoBiologico': 'M',
#    'estabelecimento_valor': '2013916',
#    'estabelecimento_uf': 'AM',
#    'sistema_origem': 'SMV',
#    'data_importacao_datalake': '2023-12-22T18:06:23.000Z',
#    'data_importacao_rnds': '2023-12-22T01:23:23.000Z',
#    'paciente_id': 'b2c5e73bbc02f8c51b3c05f1cd8bca397a190b7a1d1878707c7428df88e2b83b',
#    'ds_condicao_maternal': None,
#    '@timestamp': '2023-12-22T21:15:02.378Z',
#    'vacina_dataAplicacao': '2023-12-19T00:00:00.000Z',
#    'vacina_numDose': '1',
#    'estabelecimento_municipio_nome': 'MANAUS',
#    'vacina_codigo': '99',
#    'status': 'final',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária',
#    'vacina_descricao_dose': '1ª Dose',
#    'paciente_endereco_coIbgeMunicipio': '130260',
#    'dt_deleted': None,
#    'paciente_endereco_nmPais': 'BRASIL',
#    'document_id': '0ad37d9a-0fdb-4770-b04f-924f2d576da0-i0b0',
#    'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_racaCor_codigo': '03',
#    'estabelecimento_municipio_codigo': '130260'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '4a204087-cf71-4d82-b577-909d23b1fcf1-i0b0',
#   '_score': 1.0,
#   '_source': {'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'paciente_endereco_uf': 'AM',
#    'paciente_dataNascimento': '2016-03-01',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_lote': 'GN0764',
#    '@version': '1',
#    'paciente_endereco_cep': '',
#    'vacina_fabricante_referencia': None,
#    'id_sistema_origem': '18183',
#    'co_condicao_maternal': None,
#    'paciente_endereco_nmMunicipio': 'MANAUS',
#    'vacina_categoria_codigo': '2',
#    'estalecimento_noFantasia': 'USF O 16',
#    'paciente_idade': 7,
#    'vacina_grupoAtendimento_codigo': '000210',
#    'estabelecimento_razaoSocial': 'MANAUS SECRETARIA MUNICIPAL DE SAUDE',
#    'paciente_endereco_coPais': '10',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_racaCor_valor': 'PARDA',
#    'paciente_enumSexoBiologico': 'M',
#    'estabelecimento_valor': '2016737',
#    'estabelecimento_uf': 'AM',
#    'sistema_origem': 'SMV',
#    'data_importacao_datalake': '2023-12-22T18:06:23.000Z',
#    'data_importacao_rnds': '2023-12-22T01:40:10.000Z',
#    'paciente_id': '46c1ed28d798fdcc6ead28897e7385a3e901ed58cb3c0b025bde6644a12ac310',
#    'ds_condicao_maternal': None,
#    '@timestamp': '2023-12-22T21:15:02.396Z',
#    'vacina_dataAplicacao': '2023-12-19T00:00:00.000Z',
#    'vacina_numDose': '6',
#    'estabelecimento_municipio_nome': 'MANAUS',
#    'vacina_codigo': '99',
#    'status': 'final',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária',
#    'vacina_descricao_dose': '1º Reforço',
#    'paciente_endereco_coIbgeMunicipio': '130260',
#    'dt_deleted': None,
#    'paciente_endereco_nmPais': 'BRASIL',
#    'document_id': '4a204087-cf71-4d82-b577-909d23b1fcf1-i0b0',
#    'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_racaCor_codigo': '03',
#    'estabelecimento_municipio_codigo': '130260'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '422e0b13-1c7c-49ea-bfc7-b6aef3c274f2-i0b0',
#   '_score': 1.0,
#   '_source': {'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'paciente_endereco_uf': 'MG',
#    'paciente_dataNascimento': '2018-05-16',
#    'vacina_categoria_nome': 'Trabalhadores de Saúde',
#    'vacina_lote': 'GN0764',
#    '@version': '1',
#    'paciente_endereco_cep': '30510',
#    'vacina_fabricante_referencia': None,
#    'id_sistema_origem': '19788',
#    'co_condicao_maternal': None,
#    'paciente_endereco_nmMunicipio': 'BELO HORIZONTE',
#    'vacina_categoria_codigo': '9',
#    'estalecimento_noFantasia': 'CENTRO DE SAUDE SALGADO FILHO',
#    'paciente_idade': 5,
#    'vacina_grupoAtendimento_codigo': '000926',
#    'estabelecimento_razaoSocial': 'MUNICIPIO DE BELO HORIZONTE',
#    'paciente_endereco_coPais': '10',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_racaCor_valor': 'PARDA',
#    'paciente_enumSexoBiologico': 'F',
#    'estabelecimento_valor': '0023442',
#    'estabelecimento_uf': 'MG',
#    'sistema_origem': 'SIGRAH',
#    'data_importacao_datalake': '2023-12-22T18:06:23.000Z',
#    'data_importacao_rnds': '2023-12-22T14:14:07.000Z',
#    'paciente_id': 'b337cf9154d13fef74000a36f291187d14a48b4b2b94c193a2026ec7f1c8e719',
#    'ds_condicao_maternal': None,
#    '@timestamp': '2023-12-22T21:15:02.386Z',
#    'vacina_dataAplicacao': '2023-12-22T00:00:00.000Z',
#    'vacina_numDose': '1',
#    'estabelecimento_municipio_nome': 'BELO HORIZONTE',
#    'vacina_codigo': '99',
#    'status': 'final',
#    'vacina_grupoAtendimento_nome': 'Outros',
#    'vacina_descricao_dose': '1ª Dose',
#    'paciente_endereco_coIbgeMunicipio': '310620',
#    'dt_deleted': None,
#    'paciente_endereco_nmPais': 'BRASIL',
#    'document_id': '422e0b13-1c7c-49ea-bfc7-b6aef3c274f2-i0b0',
#    'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_racaCor_codigo': '03',
#    'estabelecimento_municipio_codigo': '310620'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'f3d4e9ed-e3a2-4522-a05b-7d5e11dd2c5d-i0b0',
#   '_score': 1.0,
#   '_source': {'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'paciente_endereco_uf': 'RS',
#    'paciente_dataNascimento': '2017-09-24',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_lote': 'GN0764',
#    '@version': '1',
#    'paciente_endereco_cep': '91520',
#    'vacina_fabricante_referencia': '28290',
#    'id_sistema_origem': '16341',
#    'co_condicao_maternal': 1,
#    'paciente_endereco_nmMunicipio': 'PORTO ALEGRE',
#    'vacina_categoria_codigo': '2',
#    'estalecimento_noFantasia': 'UNIDADE DE SAUDE ERNESTO ARAUJO',
#    'paciente_idade': 6,
#    'vacina_grupoAtendimento_codigo': '000210',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE PORTO ALEGRE',
#    'paciente_endereco_coPais': '10',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_racaCor_valor': 'BRANCA',
#    'paciente_enumSexoBiologico': 'F',
#    'estabelecimento_valor': '8006849',
#    'estabelecimento_uf': 'RS',
#    'sistema_origem': 'Novo PNI',
#    'data_importacao_datalake': '2023-12-22T18:06:23.000Z',
#    'data_importacao_rnds': '2023-12-22T11:49:17.000Z',
#    'paciente_id': '13717baac04b0822b61a617ad3295f201598d44418d65eb1d6e8841472abb1b1',
#    'ds_condicao_maternal': 'Nenhuma',
#    '@timestamp': '2023-12-22T21:15:02.417Z',
#    'vacina_dataAplicacao': '2023-12-22T00:00:00.000Z',
#    'vacina_numDose': '6',
#    'estabelecimento_municipio_nome': 'PORTO ALEGRE',
#    'vacina_codigo': '99',
#    'status': 'final',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária',
#    'vacina_descricao_dose': '1º Reforço',
#    'paciente_endereco_coIbgeMunicipio': '431490',
#    'dt_deleted': None,
#    'paciente_endereco_nmPais': 'BRASIL',
#    'document_id': 'f3d4e9ed-e3a2-4522-a05b-7d5e11dd2c5d-i0b0',
#    'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_racaCor_codigo': '01',
#    'estabelecimento_municipio_codigo': '431490'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '2494dc6a-a499-445b-9ca0-a206c85b12c7-i0b0',
#   '_score': 1.0,
#   '_source': {'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'paciente_endereco_uf': 'AM',
#    'paciente_dataNascimento': '2015-04-17',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_lote': 'GN0764',
#    '@version': '1',
#    'paciente_endereco_cep': '69460',
#    'vacina_fabricante_referencia': '28290',
#    'id_sistema_origem': '16341',
#    'co_condicao_maternal': 1,
#    'paciente_endereco_nmMunicipio': 'COARI',
#    'vacina_categoria_codigo': '2',
#    'estalecimento_noFantasia': 'UNIDADE BASICA DE SAUDE LUIZ CARLOS HERVAL',
#    'paciente_idade': 8,
#    'vacina_grupoAtendimento_codigo': '000210',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE COARI',
#    'paciente_endereco_coPais': '10',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_racaCor_valor': 'PARDA',
#    'paciente_enumSexoBiologico': 'F',
#    'estabelecimento_valor': '2011980',
#    'estabelecimento_uf': 'AM',
#    'sistema_origem': 'Novo PNI',
#    'data_importacao_datalake': '2023-12-22T18:06:23.000Z',
#    'data_importacao_rnds': '2023-12-21T19:54:25.000Z',
#    'paciente_id': '24f16de69b8505cbab92827e779a0fe3601d891a83356f4a798f3bac45ffe092',
#    'ds_condicao_maternal': 'Nenhuma',
#    '@timestamp': '2023-12-22T21:15:02.423Z',
#    'vacina_dataAplicacao': '2023-12-05T00:00:00.000Z',
#    'vacina_numDose': '6',
#    'estabelecimento_municipio_nome': 'COARI',
#    'vacina_codigo': '99',
#    'status': 'final',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária',
#    'vacina_descricao_dose': '1º Reforço',
#    'paciente_endereco_coIbgeMunicipio': '130120',
#    'dt_deleted': None,
#    'paciente_endereco_nmPais': 'BRASIL',
#    'document_id': '2494dc6a-a499-445b-9ca0-a206c85b12c7-i0b0',
#    'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_racaCor_codigo': '03',
#    'estabelecimento_municipio_codigo': '130120'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '8aebed8e-e2b2-4dbe-8dcd-3687994e7c38-i0b0',
#   '_score': 1.0,
#   '_source': {'vacina_nome': 'COVID-19 PFIZER - COMIRNATY',
#    'paciente_endereco_uf': 'MG',
#    'paciente_dataNascimento': '1981-09-02',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_lote': '2F1070A',
#    '@version': '1',
#    'paciente_endereco_cep': '32050',
#    'vacina_fabricante_referencia': None,
#    'id_sistema_origem': '18262',
#    'co_condicao_maternal': None,
#    'paciente_endereco_nmMunicipio': 'CONTAGEM',
#    'vacina_categoria_codigo': '2',
#    'estalecimento_noFantasia': 'CENTRO DE DETENCAO PROVISORIA DE DIADEMA',
#    'paciente_idade': 42,
#    'vacina_grupoAtendimento_codigo': '000210',
#    'estabelecimento_razaoSocial': 'SAO PAULO SECRETARIA DA ADMINISTRACAO PENITENCIARIA',
#    'paciente_endereco_coPais': '10',
#    'paciente_nacionalidade_enumNacionalidade': None,
#    'paciente_racaCor_valor': 'SEM INFORMACAO',
#    'paciente_enumSexoBiologico': 'M',
#    'estabelecimento_valor': '3772683',
#    'estabelecimento_uf': 'SP',
#    'sistema_origem': 'VACIVIDA',
#    'data_importacao_datalake': '2023-12-22T18:06:23.000Z',
#    'data_importacao_rnds': '2023-12-22T12:56:56.000Z',
#    'paciente_id': '068913b6db25a8e078ac4168132e4575f055e5c29cec88d54d7e91784cf6e5c3',
#    'ds_condicao_maternal': None,
#    '@timestamp': '2023-12-22T21:15:02.479Z',
#    'vacina_dataAplicacao': '2023-12-22T00:00:00.000Z',
#    'vacina_numDose': '2',
#    'estabelecimento_municipio_nome': 'DIADEMA',
#    'vacina_codigo': '87',
#    'status': 'final',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária',
#    'vacina_descricao_dose': '2ª Dose',
#    'paciente_endereco_coIbgeMunicipio': '311860',
#    'dt_deleted': None,
#    'paciente_endereco_nmPais': 'BRASIL',
#    'document_id': '8aebed8e-e2b2-4dbe-8dcd-3687994e7c38-i0b0',
#    'vacina_fabricante_nome': 'PFIZER',
#    'paciente_racaCor_codigo': '99',
#    'estabelecimento_municipio_codigo': '351380'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '4ac214c0-74cc-40ad-a121-f81cb5914066-i0b0',
#   '_score': 1.0,
#   '_source': {'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'paciente_endereco_uf': 'PE',
#    'paciente_dataNascimento': '2012-12-07',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_lote': 'GN0764',
#    '@version': '1',
#    'paciente_endereco_cep': '54320',
#    'vacina_fabricante_referencia': '28290',
#    'id_sistema_origem': '16341',
#    'co_condicao_maternal': 1,
#    'paciente_endereco_nmMunicipio': 'JABOATAO DOS GUARARAPES',
#    'vacina_categoria_codigo': '2',
#    'estalecimento_noFantasia': 'SECRETARIA DE SAUDE DO JABOATAO DOS GUARARAPES',
#    'paciente_idade': 10,
#    'vacina_grupoAtendimento_codigo': '000210',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL JABOATAO DOS GUARARAPES',
#    'paciente_endereco_coPais': '10',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_racaCor_valor': 'PARDA',
#    'paciente_enumSexoBiologico': 'F',
#    'estabelecimento_valor': '2431319',
#    'estabelecimento_uf': 'PE',
#    'sistema_origem': 'Novo PNI',
#    'data_importacao_datalake': '2023-12-22T18:06:23.000Z',
#    'data_importacao_rnds': '2023-12-22T12:17:07.000Z',
#    'paciente_id': '79dbfbb98393258f3c5ac9d821832ca3e83352110fc67efea21a05a55e010f89',
#    'ds_condicao_maternal': 'Nenhuma',
#    '@timestamp': '2023-12-22T21:15:02.394Z',
#    'vacina_dataAplicacao': '2023-11-17T00:00:00.000Z',
#    'vacina_numDose': '6',
#    'estabelecimento_municipio_nome': 'JABOATAO DOS GUARARAPES',
#    'vacina_codigo': '99',
#    'status': 'final',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária',
#    'vacina_descricao_dose': '1º Reforço',
#    'paciente_endereco_coIbgeMunicipio': '260790',
#    'dt_deleted': None,
#    'paciente_endereco_nmPais': 'BRASIL',
#    'document_id': '4ac214c0-74cc-40ad-a121-f81cb5914066-i0b0',
#    'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_racaCor_codigo': '03',
#    'estabelecimento_municipio_codigo': '260790'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'b5a3de9e-61c7-4c52-af4e-24f303fbb69a-i0b0',
#   '_score': 1.0,
#   '_source': {'vacina_nome': 'COVID-19 PFIZER - COMIRNATY',
#    'paciente_endereco_uf': 'SP',
#    'paciente_dataNascimento': '2011-09-20',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_lote': '2F1071A',
#    '@version': '1',
#    'paciente_endereco_cep': '18115',
#    'vacina_fabricante_referencia': None,
#    'id_sistema_origem': '18262',
#    'co_condicao_maternal': None,
#    'paciente_endereco_nmMunicipio': 'VOTORANTIM',
#    'vacina_categoria_codigo': '2',
#    'estalecimento_noFantasia': 'UNIDADE BASICA DE SAUDE JARDIM SERRANO',
#    'paciente_idade': 12,
#    'vacina_grupoAtendimento_codigo': '000210',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE VOTORANTIM',
#    'paciente_endereco_coPais': '10',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_racaCor_valor': 'BRANCA',
#    'paciente_enumSexoBiologico': 'F',
#    'estabelecimento_valor': '2087553',
#    'estabelecimento_uf': 'SP',
#    'sistema_origem': 'VACIVIDA',
#    'data_importacao_datalake': '2023-12-22T18:06:23.000Z',
#    'data_importacao_rnds': '2023-12-22T13:56:20.000Z',
#    'paciente_id': '7ac6cc63c97f0d349a76404a8357d58c9c0813de705daf03ba5cfe49e067d96b',
#    'ds_condicao_maternal': None,
#    '@timestamp': '2023-12-22T21:15:02.402Z',
#    'vacina_dataAplicacao': '2023-12-22T00:00:00.000Z',
#    'vacina_numDose': '6',
#    'estabelecimento_municipio_nome': 'VOTORANTIM',
#    'vacina_codigo': '87',
#    'status': 'final',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária',
#    'vacina_descricao_dose': '1º Reforço',
#    'paciente_endereco_coIbgeMunicipio': '355700',
#    'dt_deleted': None,
#    'paciente_endereco_nmPais': 'BRASIL',
#    'document_id': 'b5a3de9e-61c7-4c52-af4e-24f303fbb69a-i0b0',
#    'vacina_fabricante_nome': 'PFIZER',
#    'paciente_racaCor_codigo': '01',
#    'estabelecimento_municipio_codigo': '355700'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'c5e33715-3cfb-47cc-ba8d-2cd2f9c6a6bf-i0b0',
#   '_score': 1.0,
#   '_source': {'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'paciente_endereco_uf': 'CE',
#    'paciente_dataNascimento': '2015-04-20',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_lote': 'GY0354',
#    '@version': '1',
#    'paciente_endereco_cep': '',
#    'vacina_fabricante_referencia': '28290',
#    'id_sistema_origem': '16341',
#    'co_condicao_maternal': 1,
#    'paciente_endereco_nmMunicipio': 'GRANJA',
#    'vacina_categoria_codigo': '2',
#    'estalecimento_noFantasia': 'UNID BASICA DE SAUDE FRANCISCO CARNEIRO MAGALHAES',
#    'paciente_idade': 8,
#    'vacina_grupoAtendimento_codigo': '000210',
#    'estabelecimento_razaoSocial': 'PREF M GRANJA',
#    'paciente_endereco_coPais': '10',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_racaCor_valor': 'SEM INFORMACAO',
#    'paciente_enumSexoBiologico': 'F',
#    'estabelecimento_valor': '7173318',
#    'estabelecimento_uf': 'CE',
#    'sistema_origem': 'Novo PNI',
#    'data_importacao_datalake': '2023-12-22T18:06:23.000Z',
#    'data_importacao_rnds': '2023-12-22T12:39:02.000Z',
#    'paciente_id': 'b3ab92498745ff9c68d1efa1669cc37c6fd539e2fb73d368b6f80435c690fedd',
#    'ds_condicao_maternal': 'Nenhuma',
#    '@timestamp': '2023-12-22T21:15:02.394Z',
#    'vacina_dataAplicacao': '2023-12-22T00:00:00.000Z',
#    'vacina_numDose': '6',
#    'estabelecimento_municipio_nome': 'GRANJA',
#    'vacina_codigo': '99',
# ...
#    'paciente_idade': 7,
#    'paciente_enumSexoBiologico': 'F',
#    'estabelecimento_uf': 'CE',
#    'dt_deleted': None,
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária',
#    'vacina_dataAplicacao': '2023-09-30T00:00:00.000Z',
#    'estabelecimento_municipio_nome': 'RUSSAS',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_valor': '9599789',
#    'sistema_origem': 'Novo PNI',
#    'co_condicao_maternal': 1,
#    'estabelecimento_razaoSocial': 'MUNICIPIO DE RUSSAS'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'b4898022-b166-466f-837f-0a4038b5f069-i0b0',
#   '_score': 1.0,
#   '_source': {'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_endereco_cep': 'None',
#    'vacina_descricao_dose': '3ª Dose',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_categoria_codigo': '2',
#    'data_importacao_rnds': '2023-10-24T19:04:19.000Z',
#    'vacina_numDose': '3',
#    'vacina_lote': 'FX9154',
#    'paciente_id': '9c5acc5f875849bf87da285b7555554bc1bf117979a59b7a2093dd4c416e9b57',
#    'vacina_fabricante_referencia': '28290',
#    '@timestamp': '2023-10-25T21:16:21.333Z',
#    'paciente_endereco_nmMunicipio': 'CANTO DO BURITI',
#    'status': 'final',
#    'paciente_racaCor_valor': 'BRANCA',
#    'id_sistema_origem': '16341',
#    'document_id': 'b4898022-b166-466f-837f-0a4038b5f069-i0b0',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_codigo': '99',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'paciente_endereco_uf': 'PI',
#    'estabelecimento_municipio_codigo': '220230',
#    '@version': '1',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'estalecimento_noFantasia': 'UBS ANTONIO POLICARPO',
#    'paciente_endereco_coIbgeMunicipio': '220230',
#    'paciente_dataNascimento': '2012-09-27',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'data_importacao_datalake': '2023-10-25T18:06:27.000Z',
#    'paciente_racaCor_codigo': '01',
#    'paciente_idade': 10,
#    'paciente_enumSexoBiologico': 'M',
#    'estabelecimento_uf': 'PI',
#    'dt_deleted': None,
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária',
#    'vacina_dataAplicacao': '2023-09-13T00:00:00.000Z',
#    'estabelecimento_municipio_nome': 'CANTO DO BURITI',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_valor': '4008332',
#    'sistema_origem': 'Novo PNI',
#    'co_condicao_maternal': 1,
#    'estabelecimento_razaoSocial': 'SMS DE CANTO DO BURITI'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '22407236-6bda-4d0d-b07d-c3e35b962213-i0b0',
#   '_score': 1.0,
#   '_source': {'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_endereco_cep': '21380',
#    'vacina_descricao_dose': '3ª Dose',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_categoria_codigo': '2',
#    'data_importacao_rnds': '2023-10-25T15:39:31.000Z',
#    'vacina_numDose': '3',
#    'vacina_lote': 'GN0764',
#    'paciente_id': '8c9ebdb3bc99842a7d8f214503dfd7fdd6d57443e0120a59b9fdc5f2d5426fd3',
#    'vacina_fabricante_referencia': '28290',
#    '@timestamp': '2023-10-25T21:16:21.334Z',
#    'paciente_endereco_nmMunicipio': 'RIO DE JANEIRO',
#    'status': 'final',
#    'paciente_racaCor_valor': 'SEM INFORMACAO',
#    'id_sistema_origem': '16341',
#    'document_id': '22407236-6bda-4d0d-b07d-c3e35b962213-i0b0',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_codigo': '99',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'paciente_endereco_uf': 'RJ',
#    'estabelecimento_municipio_codigo': '330455',
#    '@version': '1',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'estalecimento_noFantasia': 'SMS CMS MARIA AUGUSTA ESTRELLA AP 22',
#    'paciente_endereco_coIbgeMunicipio': '330455',
#    'paciente_dataNascimento': '2013-01-12',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'data_importacao_datalake': '2023-10-25T18:06:27.000Z',
#    'paciente_racaCor_codigo': '99',
#    'paciente_idade': 10,
#    'paciente_enumSexoBiologico': 'F',
#    'estabelecimento_uf': 'RJ',
#    'dt_deleted': None,
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária',
#    'vacina_dataAplicacao': '2023-10-25T00:00:00.000Z',
#    'estabelecimento_municipio_nome': 'RIO DE JANEIRO',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_valor': '2280272',
#    'sistema_origem': 'Novo PNI',
#    'co_condicao_maternal': 1,
#    'estabelecimento_razaoSocial': 'SMS RIO CMS MARIA AUGUSTA ESTRELLA AP 22'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '82f4ccb7-47d5-4c0f-9eb9-4a6c1ce8d608-i0b0',
#   '_score': 1.0,
#   '_source': {'vacina_fabricante_nome': 'PFIZER',
#    'paciente_endereco_cep': '58393',
#    'vacina_descricao_dose': '3ª Dose',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_categoria_codigo': '2',
#    'data_importacao_rnds': '2023-10-25T14:37:43.000Z',
#    'vacina_numDose': '3',
#    'vacina_lote': 'PCA0096',
#    'paciente_id': '79cfbd6419ce6ca76340b4598c19dbe7ab323755a5c094bb3eee9d325ca02db1',
#    'vacina_fabricante_referencia': '28290',
#    '@timestamp': '2023-10-25T21:16:21.335Z',
#    'paciente_endereco_nmMunicipio': 'PILOES',
#    'status': 'final',
#    'paciente_racaCor_valor': 'PARDA',
#    'id_sistema_origem': '16341',
#    'document_id': '82f4ccb7-47d5-4c0f-9eb9-4a6c1ce8d608-i0b0',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_codigo': '87',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'paciente_endereco_uf': 'PB',
#    'estabelecimento_municipio_codigo': '250180',
#    '@version': '1',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'estalecimento_noFantasia': 'POLICLINICA MUNICIPAL BENJAMIN MARANHAO',
#    'paciente_endereco_coIbgeMunicipio': '251160',
#    'paciente_dataNascimento': '2009-04-20',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'data_importacao_datalake': '2023-10-25T18:06:27.000Z',
#    'paciente_racaCor_codigo': '03',
#    'paciente_idade': 14,
#    'paciente_enumSexoBiologico': 'F',
#    'estabelecimento_uf': 'PB',
#    'dt_deleted': None,
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária',
#    'vacina_dataAplicacao': '2023-08-25T00:00:00.000Z',
#    'estabelecimento_municipio_nome': 'BAYEUX',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_valor': '2342413',
#    'sistema_origem': 'Novo PNI',
#    'co_condicao_maternal': 1,
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE BAYEUX'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '1019fe8f-5750-4a1e-8523-71417952c969-i0b0',
#   '_score': 1.0,
#   '_source': {'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_endereco_cep': '28510',
#    'vacina_descricao_dose': '3ª Dose',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_categoria_codigo': '2',
#    'data_importacao_rnds': '2023-10-25T12:27:38.000Z',
#    'vacina_numDose': '3',
#    'vacina_lote': 'GN0764',
#    'paciente_id': 'caf71bb7abf7fac9a5b5feb774b0903656df264c515c14699336cbf72f32b720',
#    'vacina_fabricante_referencia': '28290',
#    '@timestamp': '2023-10-25T21:16:21.431Z',
#    'paciente_endereco_nmMunicipio': 'CANTAGALO',
#    'status': 'final',
#    'paciente_racaCor_valor': 'PARDA',
#    'id_sistema_origem': '16341',
#    'document_id': '1019fe8f-5750-4a1e-8523-71417952c969-i0b0',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_codigo': '99',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'paciente_endereco_uf': 'RJ',
#    'estabelecimento_municipio_codigo': '330340',
#    '@version': '1',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'estalecimento_noFantasia': 'UNIDADE BASICA DE SAUDE ARIOSTO BENTO DE MELLO',
#    'paciente_endereco_coIbgeMunicipio': '330110',
#    'paciente_dataNascimento': '2016-11-18',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'data_importacao_datalake': '2023-10-25T18:06:27.000Z',
#    'paciente_racaCor_codigo': '03',
#    'paciente_idade': 6,
#    'paciente_enumSexoBiologico': 'M',
#    'estabelecimento_uf': 'RJ',
#    'dt_deleted': None,
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária',
#    'vacina_dataAplicacao': '2023-10-25T00:00:00.000Z',
#    'estabelecimento_municipio_nome': 'NOVA FRIBURGO',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_valor': '2271842',
#    'sistema_origem': 'Novo PNI',
#    'co_condicao_maternal': 1,
#    'estabelecimento_razaoSocial': 'MUNICIPIO DE NOVA FRIBURGO'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '786f6d83-b3e3-4544-882c-6f1bf3d19909-i0b0',
#   '_score': 1.0,
#   '_source': {'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_endereco_cep': '54705',
#    'vacina_descricao_dose': '3ª Dose',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_categoria_codigo': '2',
#    'data_importacao_rnds': '2023-10-25T15:49:25.000Z',
#    'vacina_numDose': '3',
#    'vacina_lote': 'GG3661',
#    'paciente_id': '2ead6f9306f104d7bc7f7c35201688cda130aeb6ae96ea66f1c5ec21998588d1',
#    'vacina_fabricante_referencia': '28290',
#    '@timestamp': '2023-10-25T21:16:21.435Z',
#    'paciente_endereco_nmMunicipio': 'SAO LOURENCO DA MATA',
#    'status': 'final',
#    'paciente_racaCor_valor': 'SEM INFORMACAO',
#    'id_sistema_origem': '16341',
#    'document_id': '786f6d83-b3e3-4544-882c-6f1bf3d19909-i0b0',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_codigo': '99',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'paciente_endereco_uf': 'PE',
#    'estabelecimento_municipio_codigo': '260345',
#    '@version': '1',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'estalecimento_noFantasia': 'USF BAIRRO NOVO I',
#    'paciente_endereco_coIbgeMunicipio': '261370',
#    'paciente_dataNascimento': '2014-03-31',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'data_importacao_datalake': '2023-10-25T18:06:27.000Z',
#    'paciente_racaCor_codigo': '99',
#    'paciente_idade': 9,
#    'paciente_enumSexoBiologico': 'F',
#    'estabelecimento_uf': 'PE',
#    'dt_deleted': None,
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária',
#    'vacina_dataAplicacao': '2023-06-13T00:00:00.000Z',
#    'estabelecimento_municipio_nome': 'CAMARAGIBE',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_valor': '2346117',
#    'sistema_origem': 'Novo PNI',
#    'co_condicao_maternal': 1,
#    'estabelecimento_razaoSocial': 'MUNICIPIO DE CAMARAGIBE'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '25c23847-eea2-42bc-bded-5ded2411203f-i0b0',
#   '_score': 1.0,
#   '_source': {'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_endereco_cep': '81770',
#    'vacina_descricao_dose': '2ª Dose',
#    'ds_condicao_maternal': None,
#    'vacina_categoria_codigo': '2',
#    'data_importacao_rnds': '2023-10-24T18:29:47.000Z',
#    'vacina_numDose': '2',
#    'vacina_lote': 'GN0764',
#    'paciente_id': '19767969ce80351fe89094c2df2de3d8152dae061575793f41ef1f3dcfff5074',
#    'vacina_fabricante_referencia': None,
#    '@timestamp': '2023-10-25T21:16:21.442Z',
#    'paciente_endereco_nmMunicipio': 'CURITIBA',
#    'status': 'final',
#    'paciente_racaCor_valor': 'SEM INFORMACAO',
#    'id_sistema_origem': '19762',
#    'document_id': '25c23847-eea2-42bc-bded-5ded2411203f-i0b0',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_codigo': '99',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'paciente_endereco_uf': 'PR',
#    'estabelecimento_municipio_codigo': '410690',
#    '@version': '1',
#    'vacina_grupoAtendimento_codigo': '000207',
#    'estalecimento_noFantasia': 'UMS OSTERNACK PSF',
#    'paciente_endereco_coIbgeMunicipio': '410690',
#    'paciente_dataNascimento': '2017-09-15',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'data_importacao_datalake': '2023-10-25T18:06:27.000Z',
#    'paciente_racaCor_codigo': '99',
#    'paciente_idade': 6,
#    'paciente_enumSexoBiologico': 'M',
#    'estabelecimento_uf': 'PR',
#    'dt_deleted': None,
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'vacina_grupoAtendimento_nome': 'Pessoas de 5 a 11 anos',
#    'vacina_dataAplicacao': '2023-10-23T00:00:00.000Z',
#    'estabelecimento_municipio_nome': 'CURITIBA',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_valor': '0016942',
#    'sistema_origem': 'E-saúde Curitiba',
#    'co_condicao_maternal': None,
#    'estabelecimento_razaoSocial': 'MUNICIPIO DE CURITIBA'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'f324323d-afab-4c71-8ae4-a007c6eb6188-i0b0',
#   '_score': 1.0,
#   '_source': {'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_endereco_cep': '46650',
#    'vacina_descricao_dose': '3ª Dose',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_categoria_codigo': '2',
#    'data_importacao_rnds': '2023-10-25T17:55:01.000Z',
#    'vacina_numDose': '3',
#    'vacina_lote': 'GG3661',
#    'paciente_id': '01f0f07db31514fb97074e667e352dc5a2a7867658ab00f926e2cfe5b07f7fad',
#    'vacina_fabricante_referencia': '28290',
#    '@timestamp': '2023-10-25T21:16:21.442Z',
#    'paciente_endereco_nmMunicipio': 'BARRA DA ESTIVA',
#    'status': 'final',
#    'paciente_racaCor_valor': 'BRANCA',
#    'id_sistema_origem': '16341',
#    'document_id': 'f324323d-afab-4c71-8ae4-a007c6eb6188-i0b0',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_codigo': '99',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'paciente_endereco_uf': 'BA',
#    'estabelecimento_municipio_codigo': '290280',
#    '@version': '1',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'estalecimento_noFantasia': 'CENTRO DE SAUDE',
#    'paciente_endereco_coIbgeMunicipio': '290280',
#    'paciente_dataNascimento': '2013-07-12',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'data_importacao_datalake': '2023-10-25T18:06:27.000Z',
#    'paciente_racaCor_codigo': '01',
#    'paciente_idade': 10,
#    'paciente_enumSexoBiologico': 'M',
#    'estabelecimento_uf': 'BA',
#    'dt_deleted': None,
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária',
#    'vacina_dataAplicacao': '2023-07-26T00:00:00.000Z',
#    'estabelecimento_municipio_nome': 'BARRA DA ESTIVA',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_valor': '2384442',
#    'sistema_origem': 'Novo PNI',
#    'co_condicao_maternal': 1,
#    'estabelecimento_razaoSocial': 'MUNICIPIO DE BARRA DA ESTIVA'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'fd03248a-752a-4db7-ba2b-720e9d72dadf-i0b0',
#   '_score': 1.0,
#   '_source': {'vacina_fabricante_nome': 'JANSSEN',
#    'paciente_endereco_cep': '69345',
#    'vacina_descricao_dose': '2ª Dose',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_categoria_codigo': '2',
#    'data_importacao_rnds': '2023-10-25T18:05:28.000Z',
#    'vacina_numDose': '2',
#    'vacina_lote': '2407380',
#    'paciente_id': '27fce7732af9095b9d9cceaf15a72e4d45f015c496c22024f0eab7ce2ebec96d',
#    'vacina_fabricante_referencia': '30587',
#    '@timestamp': '2023-10-25T21:16:21.444Z',
#    'paciente_endereco_nmMunicipio': 'PACARAIMA',
#    'status': 'final',
#    'paciente_racaCor_valor': 'PARDA',
#    'id_sistema_origem': '16341',
#    'document_id': 'fd03248a-752a-4db7-ba2b-720e9d72dadf-i0b0',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_codigo': '88',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'paciente_endereco_uf': 'RR',
#    'estabelecimento_municipio_codigo': '140045',
#    '@version': '1',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'estalecimento_noFantasia': 'HOSPITAL DELIO DE OLIVEIRA TUPINAMBA',
#    'paciente_endereco_coIbgeMunicipio': '140045',
#    'paciente_dataNascimento': '1991-09-21',
#    'paciente_nacionalidade_enumNacionalidade': 'E',
#    'data_importacao_datalake': '2023-10-25T18:06:27.000Z',
#    'paciente_racaCor_codigo': '03',
#    'paciente_idade': 32,
#    'paciente_enumSexoBiologico': 'M',
#    'estabelecimento_uf': 'RR',
#    'dt_deleted': None,
#    'vacina_nome': 'COVID-19 JANSSEN - Ad26.COV2.S',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária',
#    'vacina_dataAplicacao': '2023-10-23T00:00:00.000Z',
#    'estabelecimento_municipio_nome': 'PACARAIMA',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_valor': '2476827',
#    'sistema_origem': 'Novo PNI',
#    'co_condicao_maternal': 1,
#    'estabelecimento_razaoSocial': 'ESTADO DE RORAIMA'}},
#  ...]

# %%
df_vacinas_brasil = pd.json_normalize(vacinas_brasil["hits"]["hits"])
df_vacinas_brasil
# Out:
#                   _index _type                                        _id  \
# 0     desc-imunizacao-v5  _doc  d264ef96-0667-466f-8487-320733836070-i0b0
# 1     desc-imunizacao-v5  _doc  5f52e28f-438c-4acb-993e-a966c9a65d7d-i0b0
# 2     desc-imunizacao-v5  _doc  03d35d7a-5a30-4665-8873-cb27fc1bfde7-i0b0
# 3     desc-imunizacao-v5  _doc  6691e569-b108-4205-a228-fdcea04063b4-i0b0
# 4     desc-imunizacao-v5  _doc  d877440d-1702-469e-b869-a6f39672f5d6-i0b0
# ...                  ...   ...                                        ...
# 9995  desc-imunizacao-v5  _doc  288e9b36-ee78-4125-a739-63e5a17f558d-i0b0
# 9996  desc-imunizacao-v5  _doc  20123d4c-011e-4058-8509-f802cd07b894-i0b0
# 9997  desc-imunizacao-v5  _doc  93424408-1f65-433e-99a3-2e470637751e-i0b0
# 9998  desc-imunizacao-v5  _doc  2fabb7c8-727d-4c6d-8944-1f4aafeb6231-i0b0
# 9999  desc-imunizacao-v5  _doc  939b807a-8484-4218-a4cf-d5f1aabf9950-i0b0
#
#       _score _source.sistema_origem _source.dt_deleted  \
# 0        1.0                 SIGRAH               None
# 1        1.0               Novo PNI               None
# 2        1.0               Novo PNI               None
# 3        1.0               Novo PNI               None
# 4        1.0               Novo PNI               None
# ...      ...                    ...                ...
# 9995     1.0               Novo PNI               None
# 9996     1.0               VACIVIDA               None
# 9997     1.0               Novo PNI               None
# 9998     1.0               VACIVIDA               None
# 9999     1.0               Novo PNI               None
#
#      _source.paciente_nacionalidade_enumNacionalidade  _source.paciente_idade  \
# 0                                                   B                      12
# 1                                                   B                      10
# 2                                                   B                      12
# 3                                                   B                      10
# 4                                                   B                      10
# ...                                               ...                     ...
# 9995                                                B                      11
# 9996                                                B                       9
# 9997                                                B                       5
# 9998                                                B                       5
# 9999                                                B                       5
#
#      _source.vacina_categoria_nome _source.vacina_fabricante_nome  ...  \
# 0           Trabalhadores de Saúde            PFIZER - PEDIÁTRICA  ...
# 1                     Faixa Etária            PFIZER - PEDIÁTRICA  ...
# 2                     Faixa Etária               SINOVAC/BUTANTAN  ...
# 3                     Faixa Etária            PFIZER - PEDIÁTRICA  ...
# 4                     Faixa Etária            PFIZER - PEDIÁTRICA  ...
# ...                            ...                            ...  ...
# 9995                  Faixa Etária            PFIZER - PEDIÁTRICA  ...
# 9996                  Faixa Etária            PFIZER - PEDIÁTRICA  ...
# 9997                  Faixa Etária            PFIZER - PEDIÁTRICA  ...
# 9998                  Faixa Etária            PFIZER - PEDIÁTRICA  ...
# 9999                  Faixa Etária            PFIZER - PEDIÁTRICA  ...
#
#      _source.status _source.paciente_enumSexoBiologico  \
# 0             final                                  F
# 1             final                                  M
# 2             final                                  F
# 3             final                                  M
# 4             final                                  F
# ...             ...                                ...
# 9995          final                                  F
# 9996          final                                  F
# 9997          final                                  M
# 9998          final                                  M
# 9999          final                                  M
#
#      _source.paciente_endereco_nmPais _source.estabelecimento_municipio_nome  \
# 0                              BRASIL                         BELO HORIZONTE
# 1                              BRASIL                            SAO GONCALO
# 2                              BRASIL                      CAREIRO DA VARZEA
# 3                              BRASIL                         RIO DE JANEIRO
# 4                              BRASIL                                 GRANJA
# ...                               ...                                    ...
# 9995                           BRASIL                                 TORRES
# 9996                           BRASIL                       FRANCISCO MORATO
# 9997                           BRASIL                                 PASSOS
# 9998                           BRASIL                                  COTIA
# 9999                           BRASIL                         SENADOR CANEDO
#
#      _source.vacina_grupoAtendimento_codigo _source.paciente_racaCor_valor  \
# 0                                    000926                          PARDA
# 1                                    000210                          PARDA
# 2                                    000210                          PARDA
# 3                                    000210                          PARDA
# 4                                    000210                          PARDA
# ...                                     ...                            ...
# 9995                                 000210                         BRANCA
# 9996                                 000210                          PARDA
# 9997                                 000210                          PRETA
# 9998                                 000210                          PARDA
# 9999                                 000210                          PARDA
#
#      _source.paciente_endereco_cep _source.estabelecimento_municipio_codigo  \
# 0                            31748                                   310620
# 1                            24716                                   330490
# 2                            69075                                   130115
# 3                            21240                                   330455
# 4                            62437                                   230470
# ...                            ...                                      ...
# 9995                         95560                                   432150
# 9996                         07991                                   351630
# 9997                         37903                                   314790
# 9998                         06726                                   351300
# 9999                         75261                                   522045
#
#      _source.vacina_fabricante_referencia _source.vacina_grupoAtendimento_nome
# 0                                    None                               Outros
# 1                                   28290                         Faixa Etária
# 2                                     152                         Faixa Etária
# 3                                   28290                         Faixa Etária
# 4                                   28290                         Faixa Etária
# ...                                   ...                                  ...
# 9995                                28290                         Faixa Etária
# 9996                                 None                         Faixa Etária
# 9997                                28290                         Faixa Etária
# 9998                                 None                         Faixa Etária
# 9999                                28290                         Faixa Etária
#
# [10000 rows x 46 columns]

# %%
""" Analisando e tratando as informações contidas em cada coluna e quais delas serão utilizadas para gerar três novos DataFrames.
"""

df_vacinas_brasil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 46 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   _index                                            10000 non-null  object
#  1   _type                                             10000 non-null  object
#  2   _id                                               10000 non-null  object
#  3   _score                                            10000 non-null  float64
#  4   _source.sistema_origem                            10000 non-null  object
#  5   _source.dt_deleted                                170 non-null    object
#  6   _source.paciente_nacionalidade_enumNacionalidade  9999 non-null   object
#  7   _source.paciente_idade                            10000 non-null  int64
#  8   _source.vacina_categoria_nome                     9991 non-null   object
#  9   _source.vacina_fabricante_nome                    10000 non-null  object
#  10  _source.paciente_endereco_nmMunicipio             10000 non-null  object
#  11  _source.paciente_endereco_coPais                  10000 non-null  object
#  12  _source.estabelecimento_uf                        10000 non-null  object
#  13  _source.estabelecimento_razaoSocial               10000 non-null  object
#  14  _source.estabelecimento_valor                     10000 non-null  object
#  15  _source.vacina_lote                               10000 non-null  object
#  16  _source.vacina_dataAplicacao                      10000 non-null  object
#  17  _source.paciente_endereco_uf                      10000 non-null  object
#  18  _source.paciente_endereco_coIbgeMunicipio         10000 non-null  object
#  19  _source.data_importacao_datalake                  10000 non-null  object
#  20  _source.paciente_id                               10000 non-null  object
#  21  _source.@timestamp                                10000 non-null  object
#  22  _source.document_id                               10000 non-null  object
#  23  _source.id_sistema_origem                         10000 non-null  object
#  24  _source.paciente_racaCor_codigo                   10000 non-null  object
#  25  _source.ds_condicao_maternal                      6235 non-null   object
#  26  _source.vacina_descricao_dose                     10000 non-null  object
#  27  _source.estalecimento_noFantasia                  10000 non-null  object
#  28  _source.paciente_dataNascimento                   10000 non-null  object
#  29  _source.data_importacao_rnds                      10000 non-null  object
#  30  _source.@version                                  10000 non-null  object
#  31  _source.vacina_codigo                             10000 non-null  object
#  32  _source.vacina_numDose                            10000 non-null  object
#  33  _source.vacina_nome                               10000 non-null  object
#  34  _source.vacina_categoria_codigo                   9991 non-null   object
#  35  _source.co_condicao_maternal                      6235 non-null   float64
#  36  _source.status                                    10000 non-null  object
#  37  _source.paciente_enumSexoBiologico                10000 non-null  object
#  38  _source.paciente_endereco_nmPais                  10000 non-null  object
#  39  _source.estabelecimento_municipio_nome            10000 non-null  object
#  40  _source.vacina_grupoAtendimento_codigo            10000 non-null  object
#  41  _source.paciente_racaCor_valor                    10000 non-null  object
#  42  _source.paciente_endereco_cep                     10000 non-null  object
#  43  _source.estabelecimento_municipio_codigo          10000 non-null  object
#  44  _source.vacina_fabricante_referencia              6506 non-null   object
#  45  _source.vacina_grupoAtendimento_nome              9998 non-null   object
# dtypes: float64(2), int64(1), object(43)
# memory usage: 3.5+ MB

# %%
""" Criando os Data Frames com as colunas desejadas.
"""

#Data Frame com as informações sobre os pacientes.

df_pacientes_selecao = ['_id','_source.paciente_dataNascimento','_source.paciente_idade',
                        '_source.paciente_racaCor_codigo', '_source.paciente_enumSexoBiologico','_source.paciente_endereco_uf','_source.paciente_endereco_coIbgeMunicipio'] 
df_pacientes = df_vacinas_brasil[df_pacientes_selecao]
df_pacientes.head(10)
# Out:
#                                          _id _source.paciente_dataNascimento  \
# 0  d264ef96-0667-466f-8487-320733836070-i0b0                      2011-12-14
# 1  5f52e28f-438c-4acb-993e-a966c9a65d7d-i0b0                      2013-03-17
# 2  03d35d7a-5a30-4665-8873-cb27fc1bfde7-i0b0                      2010-11-17
# 3  6691e569-b108-4205-a228-fdcea04063b4-i0b0                      2013-03-21
# 4  d877440d-1702-469e-b869-a6f39672f5d6-i0b0                      2013-06-26
# 5  ef4a1e15-07ae-4cf0-8d76-6c72d78ecd79-i0b0                      2008-12-16
# 6  b30fbfec-bdda-4897-8a79-8da872d6a33d-i0b0                      2003-10-23
# 7  dc866de7-69bd-4102-ba46-8a71506edb51-i0b0                      2014-06-03
# 8  39c3e3cb-8404-4bf8-bf45-32a766ecaddf-i0b0                      2008-07-04
# 9  1eac05e5-4dbf-4aec-90a7-723b393db7a0-i0b0                      2018-02-07
#
#    _source.paciente_idade _source.paciente_racaCor_codigo  \
# 0                      12                              03
# 1                      10                              03
# 2                      12                              03
# 3                      10                              03
# 4                      10                              03
# 5                      14                              01
# 6                      20                              03
# 7                       9                              03
# 8                      15                              01
# 9                       5                              01
#
#   _source.paciente_enumSexoBiologico _source.paciente_endereco_uf  \
# 0                                  F                           MG
# 1                                  M                           RJ
# 2                                  F                           AM
# 3                                  M                           RJ
# 4                                  F                           CE
# 5                                  M                           MG
# 6                                  F                           RR
# 7                                  F                           AM
# 8                                  M                           AL
# 9                                  F                           BA
#
#   _source.paciente_endereco_coIbgeMunicipio
# 0                                    310620
# 1                                    330490
# 2                                    130260
# 3                                    330455
# 4                                    230470
# 5                                    310620
# 6                                    140045
# 7                                    130140
# 8                                    270430
# 9                                    290700

# %%
#Data Frame com as informações sobre as vacinas.

df_info_vacinas_selecao = ['_id', '_source.vacina_nome','_source.vacina_fabricante_nome', '_source.vacina_lote', '_source.vacina_codigo', '_source.vacina_fabricante_referencia',
                            '_source.vacina_categoria_codigo', '_source.vacina_grupoAtendimento_nome', '_source.status' ]
df_info_vacinas = df_vacinas_brasil[df_info_vacinas_selecao]
df_info_vacinas.head(10)
# Out:
#                                          _id  \
# 0  d264ef96-0667-466f-8487-320733836070-i0b0
# 1  5f52e28f-438c-4acb-993e-a966c9a65d7d-i0b0
# 2  03d35d7a-5a30-4665-8873-cb27fc1bfde7-i0b0
# 3  6691e569-b108-4205-a228-fdcea04063b4-i0b0
# 4  d877440d-1702-469e-b869-a6f39672f5d6-i0b0
# 5  ef4a1e15-07ae-4cf0-8d76-6c72d78ecd79-i0b0
# 6  b30fbfec-bdda-4897-8a79-8da872d6a33d-i0b0
# 7  dc866de7-69bd-4102-ba46-8a71506edb51-i0b0
# 8  39c3e3cb-8404-4bf8-bf45-32a766ecaddf-i0b0
# 9  1eac05e5-4dbf-4aec-90a7-723b393db7a0-i0b0
#
#                       _source.vacina_nome _source.vacina_fabricante_nome  \
# 0  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA            PFIZER - PEDIÁTRICA
# 1  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA            PFIZER - PEDIÁTRICA
# 2   COVID-19 SINOVAC/BUTANTAN - CORONAVAC               SINOVAC/BUTANTAN
# 3  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA            PFIZER - PEDIÁTRICA
# 4  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA            PFIZER - PEDIÁTRICA
# 5             COVID-19 PFIZER - COMIRNATY                         PFIZER
# 6             COVID-19 PFIZER - COMIRNATY                         PFIZER
# 7  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA            PFIZER - PEDIÁTRICA
# 8             COVID-19 PFIZER - COMIRNATY                         PFIZER
# 9  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA            PFIZER - PEDIÁTRICA
#
#   _source.vacina_lote _source.vacina_codigo _source.vacina_categoria_codigo  \
# 0              GY0354                    99                               9
# 1              GN0764                    99                               2
# 2              220303                    86                               2
# 3              GN0764                    99                               2
# 4              GY0354                    99                               2
# 5              FW6014                    87                               9
# 6             PCA0101                    87                               2
# 7              GN0764                    99                               2
# 8             2F1070A                    87                               2
# 9              GY0354                    99                               2
#
#   _source.status
# 0          final
# 1          final
# 2          final
# 3          final
# 4          final
# 5          final
# 6          final
# 7          final
# 8          final
# 9          final

# %%
#Data Frame com as informações sobre as aplicações.


df_aplicacao_selecao = ['_id','_source.vacina_nome','_source.vacina_categoria_nome', '_source.estabelecimento_uf', '_source.estabelecimento_municipio_nome'
                        ,'_source.estabelecimento_razaoSocial','_source.vacina_dataAplicacao', '_source.vacina_descricao_dose','_source.vacina_numDose' ]
df_aplicacao = df_vacinas_brasil[df_aplicacao_selecao]
df_aplicacao.head(5)
# Out:
#                                          _id  \
# 0  d264ef96-0667-466f-8487-320733836070-i0b0
# 1  5f52e28f-438c-4acb-993e-a966c9a65d7d-i0b0
# 2  03d35d7a-5a30-4665-8873-cb27fc1bfde7-i0b0
# 3  6691e569-b108-4205-a228-fdcea04063b4-i0b0
# 4  d877440d-1702-469e-b869-a6f39672f5d6-i0b0
#
#                       _source.vacina_nome _source.vacina_categoria_nome  \
# 0  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA        Trabalhadores de Saúde
# 1  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA                  Faixa Etária
# 2   COVID-19 SINOVAC/BUTANTAN - CORONAVAC                  Faixa Etária
# 3  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA                  Faixa Etária
# 4  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA                  Faixa Etária
#
#   _source.estabelecimento_uf _source.estabelecimento_municipio_nome  \
# 0                         MG                         BELO HORIZONTE
# 1                         RJ                            SAO GONCALO
# 2                         AM                      CAREIRO DA VARZEA
# 3                         RJ                         RIO DE JANEIRO
# 4                         CE                                 GRANJA
#
#             _source.estabelecimento_razaoSocial _source.vacina_dataAplicacao  \
# 0                   MUNICIPIO DE BELO HORIZONTE     2023-12-22T00:00:00.000Z
# 1  SECRETARIA MUNICIPAL DE SAUDE DE SAO GONCALO     2023-12-22T00:00:00.000Z
# 2     PREFEITURA MUNICIPAL DE CAREIRO DA VARZEA     2023-09-22T00:00:00.000Z
# 3        SMS RIO CMS DR NAGIB JORGE FARAH AP 31     2023-09-25T00:00:00.000Z
# 4                                 PREF M GRANJA     2023-12-16T00:00:00.000Z
#
#   _source.vacina_descricao_dose _source.vacina_numDose
# 0                       2ª Dose                      2
# 1                       2ª Dose                      2
# 2                       2ª Dose                      2
# 3                       3ª Dose                      3
# 4                       3ª Dose                      3

# %%
""" Renomeando as colunas dos DataFrames.
"""


renomeadas_pacientes = {'_id':'id_paciente','_source.paciente_dataNascimento': 'data_nascimento','_source.paciente_idade': 'idade',
                        '_source.paciente_racaCor_codigo' : 'codigo_raca', '_source.paciente_enumSexoBiologico': 'sexo','_source.paciente_endereco_uf': 'UF',
                        '_source.paciente_endereco_coIbgeMunicipio': 'codigo_municipio'}


df_pacientes= df_pacientes.rename(columns= renomeadas_pacientes)
df_pacientes.head(5)
# Out:
#                                  id_paciente data_nascimento  idade  \
# 0  d264ef96-0667-466f-8487-320733836070-i0b0      2011-12-14     12
# 1  5f52e28f-438c-4acb-993e-a966c9a65d7d-i0b0      2013-03-17     10
# 2  03d35d7a-5a30-4665-8873-cb27fc1bfde7-i0b0      2010-11-17     12
# 3  6691e569-b108-4205-a228-fdcea04063b4-i0b0      2013-03-21     10
# 4  d877440d-1702-469e-b869-a6f39672f5d6-i0b0      2013-06-26     10
#
#   codigo_raca sexo  UF codigo_municipio
# 0          03    F  MG           310620
# 1          03    M  RJ           330490
# 2          03    F  AM           130260
# 3          03    M  RJ           330455
# 4          03    F  CE           230470

# %%
renomeadas_info_vacinas = {'_id':'id_paciente', '_source.vacina_nome':'nome_vacina','_source.vacina_fabricante_nome':'fabricante', '_source.vacina_lote':'lote',
                            '_source.vacina_codigo':'lote_vacina', '_source.vacina_fabricante_referencia':'referencia_fabricante',
                            '_source.vacina_categoria_codigo':'codigo_categoria', '_source.vacina_grupoAtendimento_nome':'grupo_atendimento', '_source.status': 'status'}

df_info_vacinas = df_info_vacinas.rename(columns= renomeadas_info_vacinas)
df_info_vacinas.head(5)
# Out:
#                                  id_paciente  \
# 0  d264ef96-0667-466f-8487-320733836070-i0b0
# 1  5f52e28f-438c-4acb-993e-a966c9a65d7d-i0b0
# 2  03d35d7a-5a30-4665-8873-cb27fc1bfde7-i0b0
# 3  6691e569-b108-4205-a228-fdcea04063b4-i0b0
# 4  d877440d-1702-469e-b869-a6f39672f5d6-i0b0
#
#                               nome_vacina           fabricante    lote  \
# 0  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA  PFIZER - PEDIÁTRICA  GY0354
# 1  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA  PFIZER - PEDIÁTRICA  GN0764
# 2   COVID-19 SINOVAC/BUTANTAN - CORONAVAC     SINOVAC/BUTANTAN  220303
# 3  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA  PFIZER - PEDIÁTRICA  GN0764
# 4  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA  PFIZER - PEDIÁTRICA  GY0354
#
#   lote_vacina codigo_categoria status
# 0          99                9  final
# 1          99                2  final
# 2          86                2  final
# 3          99                2  final
# 4          99                2  final

# %%
renomeadas_aplicacao = {'_id':'id_paciente','_source.vacina_nome':'nome_vacina','_source.vacina_categoria_nome':'categoria_aplicacao', '_source.estabelecimento_uf': 'UF_estabelecimento',
                         '_source.estabelecimento_municipio_nome':'nome_municipio','_source.estabelecimento_razaoSocial':'razao_social','_source.vacina_dataAplicacao':'data_aplicacao', 
                         '_source.vacina_descricao_dose':'descricao_dose','_source.vacina_numDose':'numero_dose'}

df_aplicacao = df_aplicacao.rename(columns= renomeadas_aplicacao)
df_aplicacao.head(5)
# Out:
#                                  id_paciente  \
# 0  d264ef96-0667-466f-8487-320733836070-i0b0
# 1  5f52e28f-438c-4acb-993e-a966c9a65d7d-i0b0
# 2  03d35d7a-5a30-4665-8873-cb27fc1bfde7-i0b0
# 3  6691e569-b108-4205-a228-fdcea04063b4-i0b0
# 4  d877440d-1702-469e-b869-a6f39672f5d6-i0b0
#
#                               nome_vacina     categoria_aplicacao  \
# 0  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA  Trabalhadores de Saúde
# 1  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA            Faixa Etária
# 2   COVID-19 SINOVAC/BUTANTAN - CORONAVAC            Faixa Etária
# 3  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA            Faixa Etária
# 4  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA            Faixa Etária
#
#   UF_estabelecimento     nome_municipio  \
# 0                 MG     BELO HORIZONTE
# 1                 RJ        SAO GONCALO
# 2                 AM  CAREIRO DA VARZEA
# 3                 RJ     RIO DE JANEIRO
# 4                 CE             GRANJA
#
#                                    razao_social            data_aplicacao  \
# 0                   MUNICIPIO DE BELO HORIZONTE  2023-12-22T00:00:00.000Z
# 1  SECRETARIA MUNICIPAL DE SAUDE DE SAO GONCALO  2023-12-22T00:00:00.000Z
# 2     PREFEITURA MUNICIPAL DE CAREIRO DA VARZEA  2023-09-22T00:00:00.000Z
# 3        SMS RIO CMS DR NAGIB JORGE FARAH AP 31  2023-09-25T00:00:00.000Z
# 4                                 PREF M GRANJA  2023-12-16T00:00:00.000Z
#
#   descricao_dose numero_dose
# 0        2ª Dose           2
# 1        2ª Dose           2
# 2        2ª Dose           2
# 3        3ª Dose           3
# 4        3ª Dose           3

# %%
"""
Verificando o tipo das variáveis das colunas para o ajuste de seu tipo.
"""


df_pacientes.dtypes
# Out:
# id_paciente         object
# data_nascimento     object
# idade                int64
# codigo_raca         object
# sexo                object
# UF                  object
# codigo_municipio    object
# dtype: object

# %%
df_pacientes['data_nascimento'] = pd.to_datetime(df_pacientes['data_nascimento'])
df_pacientes.dtypes
# Out:
# id_paciente                 object
# data_nascimento     datetime64[ns]
# idade                        int64
# codigo_raca                 object
# sexo                        object
# UF                          object
# codigo_municipio            object
# dtype: object

# %%
converter_int = ['codigo_raca']

df_pacientes[converter_int] = df_pacientes[converter_int].astype(int)
df_pacientes.dtypes
# Out:
# id_paciente                 object
# data_nascimento     datetime64[ns]
# idade                        int64
# codigo_raca                  int32
# sexo                        object
# UF                          object
# codigo_municipio           float64
# dtype: object

# %%
df_info_vacinas.dtypes
# Out:
# id_paciente         object
# nome_vacina         object
# fabricante          object
# lote                object
# lote_vacina         object
# codigo_categoria    object
# status              object
# dtype: object

# %%
df_aplicacao.dtypes
converter_int = ['numero_dose']

df_aplicacao[converter_int] = df_aplicacao[converter_int].astype(int)
df_aplicacao.dtypes
# Out:
# id_paciente            object
# nome_vacina            object
# categoria_aplicacao    object
# UF_estabelecimento     object
# nome_municipio         object
# razao_social           object
# data_aplicacao         object
# descricao_dose         object
# numero_dose             int32
# dtype: object

# %%
df_aplicacao['data_aplicacao'] = pd.to_datetime(df_aplicacao['data_aplicacao'])
df_aplicacao['data_aplicacao'] = df_aplicacao['data_aplicacao'].dt.strftime('%Y-%m-%d')
df_aplicacao['data_aplicacao'] = pd.to_datetime(df_aplicacao['data_aplicacao'])

df_aplicacao.dtypes
# Out:
# id_paciente                    object
# nome_vacina                    object
# categoria_aplicacao            object
# UF_estabelecimento             object
# nome_municipio                 object
# razao_social                   object
# data_aplicacao         datetime64[ns]
# descricao_dose                 object
# numero_dose                     int32
# dtype: object

# %%
""" Verificando a existência de nulos nos DataFrames e lidando com a ausência de dados.
"""

#pacientes
df_pacientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_paciente       10000 non-null  object
#  1   data_nascimento   10000 non-null  datetime64[ns]
#  2   idade             10000 non-null  int64
#  3   codigo_raca       10000 non-null  int32
#  4   sexo              10000 non-null  object
#  5   UF                10000 non-null  object
#  6   codigo_municipio  9893 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int32(1), int64(1), object(3)
# memory usage: 507.9+ KB

# %%
df_pacientes['codigo_municipio'] = df_pacientes['codigo_municipio'].fillna('ausente')
df_pacientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_paciente       10000 non-null  object
#  1   data_nascimento   10000 non-null  datetime64[ns]
#  2   idade             10000 non-null  int64
#  3   codigo_raca       10000 non-null  int32
#  4   sexo              10000 non-null  object
#  5   UF                10000 non-null  object
#  6   codigo_municipio  10000 non-null  object
# dtypes: datetime64[ns](1), int32(1), int64(1), object(4)
# memory usage: 507.9+ KB

# %%
#info_vacinas
df_info_vacinas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_paciente       10000 non-null  object
#  1   nome_vacina       10000 non-null  object
#  2   fabricante        10000 non-null  object
#  3   lote              10000 non-null  object
#  4   lote_vacina       10000 non-null  object
#  5   codigo_categoria  9991 non-null   object
#  6   status            10000 non-null  object
# dtypes: object(7)
# memory usage: 547.0+ KB

# %%
df_info_vacinas['codigo_categoria'] = df_info_vacinas['codigo_categoria'].fillna('ausente')
df_info_vacinas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_paciente       10000 non-null  object
#  1   nome_vacina       10000 non-null  object
#  2   fabricante        10000 non-null  object
#  3   lote              10000 non-null  object
#  4   lote_vacina       10000 non-null  object
#  5   codigo_categoria  10000 non-null  object
#  6   status            10000 non-null  object
# dtypes: object(7)
# memory usage: 547.0+ KB

# %%
#aplicação

df_aplicacao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id_paciente          10000 non-null  object
#  1   nome_vacina          10000 non-null  object
#  2   categoria_aplicacao  9991 non-null   object
#  3   UF_estabelecimento   10000 non-null  object
#  4   nome_municipio       10000 non-null  object
#  5   razao_social         10000 non-null  object
#  6   data_aplicacao       10000 non-null  datetime64[ns]
#  7   descricao_dose       10000 non-null  object
#  8   numero_dose          10000 non-null  int32
# dtypes: datetime64[ns](1), int32(1), object(7)
# memory usage: 664.2+ KB

# %%
df_aplicacao['categoria_aplicacao'] = df_aplicacao['categoria_aplicacao'].fillna('ausente')
df_aplicacao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id_paciente          10000 non-null  object
#  1   nome_vacina          10000 non-null  object
#  2   categoria_aplicacao  10000 non-null  object
#  3   UF_estabelecimento   10000 non-null  object
#  4   nome_municipio       10000 non-null  object
#  5   razao_social         10000 non-null  object
#  6   data_aplicacao       10000 non-null  datetime64[ns]
#  7   descricao_dose       10000 non-null  object
#  8   numero_dose          10000 non-null  int32
# dtypes: datetime64[ns](1), int32(1), object(7)
# memory usage: 664.2+ KB

# %%
""" Realizando o relacionamento entre os DataFrames.
"""

# %%
# DataFrame de informações de vacinas por paciente.

df_pacientes_info_vacinas = pd.merge(df_pacientes, df_info_vacinas, on='id_paciente', how='left')
df_pacientes_info_vacinas.head(10)
# Out:
#                                  id_paciente data_nascimento  idade  \
# 0  d264ef96-0667-466f-8487-320733836070-i0b0      2011-12-14     12
# 1  5f52e28f-438c-4acb-993e-a966c9a65d7d-i0b0      2013-03-17     10
# 2  03d35d7a-5a30-4665-8873-cb27fc1bfde7-i0b0      2010-11-17     12
# 3  6691e569-b108-4205-a228-fdcea04063b4-i0b0      2013-03-21     10
# 4  d877440d-1702-469e-b869-a6f39672f5d6-i0b0      2013-06-26     10
# 5  ef4a1e15-07ae-4cf0-8d76-6c72d78ecd79-i0b0      2008-12-16     14
# 6  b30fbfec-bdda-4897-8a79-8da872d6a33d-i0b0      2003-10-23     20
# 7  dc866de7-69bd-4102-ba46-8a71506edb51-i0b0      2014-06-03      9
# 8  39c3e3cb-8404-4bf8-bf45-32a766ecaddf-i0b0      2008-07-04     15
# 9  1eac05e5-4dbf-4aec-90a7-723b393db7a0-i0b0      2018-02-07      5
#
#    codigo_raca sexo  UF codigo_municipio  \
# 0            3    F  MG         310620.0
# 1            3    M  RJ         330490.0
# 2            3    F  AM         130260.0
# 3            3    M  RJ         330455.0
# 4            3    F  CE         230470.0
# 5            1    M  MG         310620.0
# 6            3    F  RR         140045.0
# 7            3    F  AM         130140.0
# 8            1    M  AL         270430.0
# 9            1    F  BA         290700.0
#
#                               nome_vacina           fabricante     lote  \
# 0  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA  PFIZER - PEDIÁTRICA   GY0354
# 1  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA  PFIZER - PEDIÁTRICA   GN0764
# 2   COVID-19 SINOVAC/BUTANTAN - CORONAVAC     SINOVAC/BUTANTAN   220303
# 3  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA  PFIZER - PEDIÁTRICA   GN0764
# 4  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA  PFIZER - PEDIÁTRICA   GY0354
# 5             COVID-19 PFIZER - COMIRNATY               PFIZER   FW6014
# 6             COVID-19 PFIZER - COMIRNATY               PFIZER  PCA0101
# 7  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA  PFIZER - PEDIÁTRICA   GN0764
# 8             COVID-19 PFIZER - COMIRNATY               PFIZER  2F1070A
# 9  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA  PFIZER - PEDIÁTRICA   GY0354
#
#   lote_vacina codigo_categoria status
# 0          99                9  final
# 1          99                2  final
# 2          86                2  final
# 3          99                2  final
# 4          99                2  final
# 5          87                9  final
# 6          87                2  final
# 7          99                2  final
# 8          87                2  final
# 9          99                2  final

# %%
# DataFrame de informações de aplicações por paciente.

df_pacientes_aplicacao = pd.merge(df_pacientes, df_aplicacao, on='id_paciente', how='left')
df_pacientes_aplicacao.head(5)
# Out:
#                                  id_paciente data_nascimento  idade  \
# 0  d264ef96-0667-466f-8487-320733836070-i0b0      2011-12-14     12
# 1  5f52e28f-438c-4acb-993e-a966c9a65d7d-i0b0      2013-03-17     10
# 2  03d35d7a-5a30-4665-8873-cb27fc1bfde7-i0b0      2010-11-17     12
# 3  6691e569-b108-4205-a228-fdcea04063b4-i0b0      2013-03-21     10
# 4  d877440d-1702-469e-b869-a6f39672f5d6-i0b0      2013-06-26     10
#
#    codigo_raca sexo  UF codigo_municipio  \
# 0            3    F  MG         310620.0
# 1            3    M  RJ         330490.0
# 2            3    F  AM         130260.0
# 3            3    M  RJ         330455.0
# 4            3    F  CE         230470.0
#
#                               nome_vacina     categoria_aplicacao  \
# 0  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA  Trabalhadores de Saúde
# 1  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA            Faixa Etária
# 2   COVID-19 SINOVAC/BUTANTAN - CORONAVAC            Faixa Etária
# 3  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA            Faixa Etária
# 4  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA            Faixa Etária
#
#   UF_estabelecimento     nome_municipio  \
# 0                 MG     BELO HORIZONTE
# 1                 RJ        SAO GONCALO
# 2                 AM  CAREIRO DA VARZEA
# 3                 RJ     RIO DE JANEIRO
# 4                 CE             GRANJA
#
#                                    razao_social data_aplicacao descricao_dose  \
# 0                   MUNICIPIO DE BELO HORIZONTE     2023-12-22        2ª Dose
# 1  SECRETARIA MUNICIPAL DE SAUDE DE SAO GONCALO     2023-12-22        2ª Dose
# 2     PREFEITURA MUNICIPAL DE CAREIRO DA VARZEA     2023-09-22        2ª Dose
# 3        SMS RIO CMS DR NAGIB JORGE FARAH AP 31     2023-09-25        3ª Dose
# 4                                 PREF M GRANJA     2023-12-16        3ª Dose
#
#    numero_dose
# 0            2
# 1            2
# 2            2
# 3            3
# 4            3

# %%
# DataFrame de informações de vacinas por aplicação.

df_vacinas_aplicacao = pd.merge(df_info_vacinas, df_aplicacao, on='id_paciente', how='left')
df_pacientes_aplicacao.head(5)
# Out:
#                                  id_paciente data_nascimento  idade  \
# 0  d264ef96-0667-466f-8487-320733836070-i0b0      2011-12-14     12
# 1  5f52e28f-438c-4acb-993e-a966c9a65d7d-i0b0      2013-03-17     10
# 2  03d35d7a-5a30-4665-8873-cb27fc1bfde7-i0b0      2010-11-17     12
# 3  6691e569-b108-4205-a228-fdcea04063b4-i0b0      2013-03-21     10
# 4  d877440d-1702-469e-b869-a6f39672f5d6-i0b0      2013-06-26     10
#
#    codigo_raca sexo  UF codigo_municipio  \
# 0            3    F  MG         310620.0
# 1            3    M  RJ         330490.0
# 2            3    F  AM         130260.0
# 3            3    M  RJ         330455.0
# 4            3    F  CE         230470.0
#
#                               nome_vacina     categoria_aplicacao  \
# 0  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA  Trabalhadores de Saúde
# 1  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA            Faixa Etária
# 2   COVID-19 SINOVAC/BUTANTAN - CORONAVAC            Faixa Etária
# 3  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA            Faixa Etária
# 4  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA            Faixa Etária
#
#   UF_estabelecimento     nome_municipio  \
# 0                 MG     BELO HORIZONTE
# 1                 RJ        SAO GONCALO
# 2                 AM  CAREIRO DA VARZEA
# 3                 RJ     RIO DE JANEIRO
# 4                 CE             GRANJA
#
#                                    razao_social data_aplicacao descricao_dose  \
# 0                   MUNICIPIO DE BELO HORIZONTE     2023-12-22        2ª Dose
# 1  SECRETARIA MUNICIPAL DE SAUDE DE SAO GONCALO     2023-12-22        2ª Dose
# 2     PREFEITURA MUNICIPAL DE CAREIRO DA VARZEA     2023-09-22        2ª Dose
# 3        SMS RIO CMS DR NAGIB JORGE FARAH AP 31     2023-09-25        3ª Dose
# 4                                 PREF M GRANJA     2023-12-16        3ª Dose
#
#    numero_dose
# 0            2
# 1            2
# 2            2
# 3            3
# 4            3
