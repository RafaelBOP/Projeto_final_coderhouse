# %%
""" Importando bibliotecas que serão utilizadas no projeto.
"""

import pandas as pd
import json
import requests
from plyer import notification

# %%
""" Função de alerta sobre a requisição do API. 
A função deverá retornar se houve sucesso ou qual o tipo de alerta, segundo o valor do status do HTTP.
"""


def alerta_API(nome, response):
    titulo = f"Alerta sobre a requisição do API:{nome}"
    
    if response.status_code > 500:
       mensagem  = "Alerta crítico na requisição do API"
    elif 200 > response.status_code < 500:
        mensagem  = "Alerta moderado na requisição do API"
    elif response.status_code == 200:
        mensagem  = "Sucesso ao requisitar o API"
    
    status_HTTP = response.status_code
    
    notification.notify(
        title = titulo,
        message = f"{mensagem}\n o status do HTTP é {status_HTTP}" 
    )

# %%
""" Requisitando os dados sobre a vacinação de COVID no Brasil - API OPENDATASUS
"""

brasil= "Cobertura Vacinal Brasileira"

url = "https://imunizacao-es.saude.gov.br/_search"

payload = json.dumps({
  "size": 10000
})
headers = {
  'Content-Type': 'application/json',
  'Authorization': 'Basic aW11bml6YWNhb19wdWJsaWM6cWx0bzV0JjdyX0ArI1Rsc3RpZ2k='
}

response_brasil = requests.request("POST", url, headers=headers, data=payload)

alerta_API(nome=brasil,response=response_brasil)

response_brasil.json()
vacinas_brasil = response_brasil.json()

# %%
vacinas_brasil["hits"]["hits"]
# Out:
# [{'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'b561bd45-ec2a-488b-8742-73a64153f07d-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'Novo PNI',
#    'dt_deleted': '2023-12-23T00:00:00.000Z',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_idade': 5,
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_endereco_nmMunicipio': 'SANTA BARBARA',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'MG',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE BARAO DE COCAIS',
#    'estabelecimento_valor': '3578097',
#    'vacina_lote': 'GN0764',
#    'vacina_dataAplicacao': '2023-10-21T00:00:00.000Z',
#    'paciente_endereco_uf': 'MG',
#    'paciente_endereco_coIbgeMunicipio': '315720',
#    'data_importacao_datalake': '2023-12-23T18:54:29.000Z',
#    'paciente_id': 'bd0735e2cdbfe2c572c7d60504da4a56b9b77106c24582b9d22b28c518f62275',
#    '@timestamp': '2023-12-23T21:15:02.790Z',
#    'document_id': 'b561bd45-ec2a-488b-8742-73a64153f07d-i0b0',
#    'id_sistema_origem': '16341',
#    'paciente_racaCor_codigo': '01',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_descricao_dose': '3ª Dose',
#    'estalecimento_noFantasia': 'UNIDADE BASICA DE SAUDE DR LINNEU DE OLIVEIRA LARA',
#    'paciente_dataNascimento': '2017-12-05',
#    'data_importacao_rnds': '2023-10-21T17:20:50.000Z',
#    '@version': '1',
#    'vacina_codigo': '99',
#    'vacina_numDose': '3',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'vacina_categoria_codigo': '2',
#    'co_condicao_maternal': 1,
#    'status': 'entered-in-error',
#    'paciente_enumSexoBiologico': 'F',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'BARAO DE COCAIS',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'paciente_racaCor_valor': 'BRANCA',
#    'paciente_endereco_cep': '35960',
#    'estabelecimento_municipio_codigo': '310540',
#    'vacina_fabricante_referencia': '28290',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '5f52e28f-438c-4acb-993e-a966c9a65d7d-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'Novo PNI',
#    'dt_deleted': None,
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_idade': 10,
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_endereco_nmMunicipio': 'SAO GONCALO',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'RJ',
#    'estabelecimento_razaoSocial': 'SECRETARIA MUNICIPAL DE SAUDE DE SAO GONCALO',
#    'estabelecimento_valor': '2702959',
#    'vacina_lote': 'GN0764',
#    'vacina_dataAplicacao': '2023-12-22T00:00:00.000Z',
#    'paciente_endereco_uf': 'RJ',
#    'paciente_endereco_coIbgeMunicipio': '330490',
#    'data_importacao_datalake': '2023-12-23T18:06:22.000Z',
#    'paciente_id': 'b2fb11b0bffa405519adfbdfdc6925faa1fe4034ffee187e6b7d1156ba547da6',
#    '@timestamp': '2023-12-23T21:15:02.628Z',
#    'document_id': '5f52e28f-438c-4acb-993e-a966c9a65d7d-i0b0',
#    'id_sistema_origem': '16341',
#    'paciente_racaCor_codigo': '03',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_descricao_dose': '2ª Dose',
#    'estalecimento_noFantasia': 'POLO SANITARIO JORGE TEIXEIRA DE LIMA',
#    'paciente_dataNascimento': '2013-03-17',
#    'data_importacao_rnds': '2023-12-22T19:39:16.000Z',
#    '@version': '1',
#    'vacina_codigo': '99',
#    'vacina_numDose': '2',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'vacina_categoria_codigo': '2',
#    'co_condicao_maternal': 1,
#    'status': 'final',
#    'paciente_enumSexoBiologico': 'M',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'SAO GONCALO',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'paciente_racaCor_valor': 'PARDA',
#    'paciente_endereco_cep': '24716',
#    'estabelecimento_municipio_codigo': '330490',
#    'vacina_fabricante_referencia': '28290',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'dc866de7-69bd-4102-ba46-8a71506edb51-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'Novo PNI',
#    'dt_deleted': None,
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_idade': 9,
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_endereco_nmMunicipio': 'EIRUNEPE',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'AM',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE EIRUNEPE',
#    'estabelecimento_valor': '2018691',
#    'vacina_lote': 'GN0764',
#    'vacina_dataAplicacao': '2023-12-01T00:00:00.000Z',
#    'paciente_endereco_uf': 'AM',
#    'paciente_endereco_coIbgeMunicipio': '130140',
#    'data_importacao_datalake': '2023-12-23T18:06:22.000Z',
#    'paciente_id': '5dd19b701c963a5a15c82f4a0fa5544675b93e3097d0ea14fd720f90b90c7827',
#    '@timestamp': '2023-12-23T21:15:02.676Z',
#    'document_id': 'dc866de7-69bd-4102-ba46-8a71506edb51-i0b0',
#    'id_sistema_origem': '16341',
#    'paciente_racaCor_codigo': '03',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_descricao_dose': '3ª Dose',
#    'estalecimento_noFantasia': 'UNIDADE BASICA GENESIO ALBUQUERQUE',
#    'paciente_dataNascimento': '2014-06-03',
#    'data_importacao_rnds': '2023-12-22T20:50:06.000Z',
#    '@version': '1',
#    'vacina_codigo': '99',
#    'vacina_numDose': '3',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'vacina_categoria_codigo': '2',
#    'co_condicao_maternal': 1,
#    'status': 'final',
#    'paciente_enumSexoBiologico': 'F',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'EIRUNEPE',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'paciente_racaCor_valor': 'PARDA',
#    'paciente_endereco_cep': '',
#    'estabelecimento_municipio_codigo': '130140',
#    'vacina_fabricante_referencia': '28290',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '03d35d7a-5a30-4665-8873-cb27fc1bfde7-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'Novo PNI',
#    'dt_deleted': None,
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_idade': 12,
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_nome': 'SINOVAC/BUTANTAN',
#    'paciente_endereco_nmMunicipio': 'MANAUS',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'AM',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE CAREIRO DA VARZEA',
#    'estabelecimento_valor': '3940713',
#    'vacina_lote': '220303',
#    'vacina_dataAplicacao': '2023-09-22T00:00:00.000Z',
#    'paciente_endereco_uf': 'AM',
#    'paciente_endereco_coIbgeMunicipio': '130260',
#    'data_importacao_datalake': '2023-12-23T18:06:22.000Z',
#    'paciente_id': '41c476e2a9bc892f825d34c9ee53b79fb11e5a465c80ec5a43435f678e049a6c',
#    '@timestamp': '2023-12-23T21:15:02.630Z',
#    'document_id': '03d35d7a-5a30-4665-8873-cb27fc1bfde7-i0b0',
#    'id_sistema_origem': '16341',
#    'paciente_racaCor_codigo': '03',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_descricao_dose': '2ª Dose',
#    'estalecimento_noFantasia': 'UNIDADE BASICA DE SAUDE PEDRO FIGUEIREDO DE SOUZA',
#    'paciente_dataNascimento': '2010-11-17',
#    'data_importacao_rnds': '2023-12-23T02:15:37.000Z',
#    '@version': '1',
#    'vacina_codigo': '86',
#    'vacina_numDose': '2',
#    'vacina_nome': 'COVID-19 SINOVAC/BUTANTAN - CORONAVAC',
#    'vacina_categoria_codigo': '2',
#    'co_condicao_maternal': 1,
#    'status': 'final',
#    'paciente_enumSexoBiologico': 'F',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'CAREIRO DA VARZEA',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'paciente_racaCor_valor': 'PARDA',
#    'paciente_endereco_cep': '69075',
#    'estabelecimento_municipio_codigo': '130115',
#    'vacina_fabricante_referencia': '152',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'ef4a1e15-07ae-4cf0-8d76-6c72d78ecd79-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'SIGRAH',
#    'dt_deleted': None,
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_idade': 14,
#    'vacina_categoria_nome': 'Trabalhadores de Saúde',
#    'vacina_fabricante_nome': 'PFIZER',
#    'paciente_endereco_nmMunicipio': 'BELO HORIZONTE',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'MG',
#    'estabelecimento_razaoSocial': 'MUNICIPIO DE BELO HORIZONTE',
#    'estabelecimento_valor': '0022640',
#    'vacina_lote': 'FW6014',
#    'vacina_dataAplicacao': '2023-02-03T00:00:00.000Z',
#    'paciente_endereco_uf': 'MG',
#    'paciente_endereco_coIbgeMunicipio': '310620',
#    'data_importacao_datalake': '2023-12-23T18:06:22.000Z',
#    'paciente_id': '7f25365f8ce7fa25230bbc3a9107e8a10e1120815c7d3fac880818602ae4de69',
#    '@timestamp': '2023-12-23T21:15:02.660Z',
#    'document_id': 'ef4a1e15-07ae-4cf0-8d76-6c72d78ecd79-i0b0',
#    'id_sistema_origem': '19788',
#    'paciente_racaCor_codigo': '01',
#    'ds_condicao_maternal': None,
#    'vacina_descricao_dose': 'Reforço',
#    'estalecimento_noFantasia': 'CENTRO DE SAUDE DR JOSE DOMINGOS',
#    'paciente_dataNascimento': '2008-12-16',
#    'data_importacao_rnds': '2023-12-22T19:06:02.000Z',
#    '@version': '1',
#    'vacina_codigo': '87',
#    'vacina_numDose': '38',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY',
#    'vacina_categoria_codigo': '9',
#    'co_condicao_maternal': None,
#    'status': 'final',
#    'paciente_enumSexoBiologico': 'M',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'BELO HORIZONTE',
#    'vacina_grupoAtendimento_codigo': '000926',
#    'paciente_racaCor_valor': 'BRANCA',
#    'paciente_endereco_cep': '30610',
#    'estabelecimento_municipio_codigo': '310620',
#    'vacina_fabricante_referencia': None,
#    'vacina_grupoAtendimento_nome': 'Outros'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '39c3e3cb-8404-4bf8-bf45-32a766ecaddf-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'Novo PNI',
#    'dt_deleted': None,
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_idade': 15,
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_nome': 'PFIZER',
#    'paciente_endereco_nmMunicipio': 'MACEIO',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'AL',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE MACEIO',
#    'estabelecimento_valor': '2009765',
#    'vacina_lote': '2F1070A',
#    'vacina_dataAplicacao': '2023-12-22T00:00:00.000Z',
#    'paciente_endereco_uf': 'AL',
#    'paciente_endereco_coIbgeMunicipio': '270430',
#    'data_importacao_datalake': '2023-12-23T18:06:22.000Z',
#    'paciente_id': '6b45e61b150d0f7162ebefb1891a2a2ca998b6e29fec1f6150707255645a0d39',
#    '@timestamp': '2023-12-23T21:15:02.665Z',
#    'document_id': '39c3e3cb-8404-4bf8-bf45-32a766ecaddf-i0b0',
#    'id_sistema_origem': '16341',
#    'paciente_racaCor_codigo': '01',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_descricao_dose': '1ª Dose Revacinação',
#    'estalecimento_noFantasia': 'DISTRITO SANITARIO',
#    'paciente_dataNascimento': '2008-07-04',
#    'data_importacao_rnds': '2023-12-22T22:21:23.000Z',
#    '@version': '1',
#    'vacina_codigo': '87',
#    'vacina_numDose': '32',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY',
#    'vacina_categoria_codigo': '2',
#    'co_condicao_maternal': 1,
#    'status': 'final',
#    'paciente_enumSexoBiologico': 'M',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'MACEIO',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'paciente_racaCor_valor': 'BRANCA',
#    'paciente_endereco_cep': '57082',
#    'estabelecimento_municipio_codigo': '270430',
#    'vacina_fabricante_referencia': '28290',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '57358f61-b6b4-4d13-bda8-dd7e866614c5-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'Novo PNI',
#    'dt_deleted': None,
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_idade': 6,
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_endereco_nmMunicipio': 'JUAZEIRO',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'BA',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE JUAZEIRO',
#    'estabelecimento_valor': '5881617',
#    'vacina_lote': 'GN0764',
#    'vacina_dataAplicacao': '2023-12-22T00:00:00.000Z',
#    'paciente_endereco_uf': 'BA',
#    'paciente_endereco_coIbgeMunicipio': '291840',
#    'data_importacao_datalake': '2023-12-23T18:06:22.000Z',
#    'paciente_id': 'c0f4fa022073a36bb9433ad6f86f0d66b410cc27147ac284fd84f2f2ffa51ff6',
#    '@timestamp': '2023-12-23T21:15:02.677Z',
#    'document_id': '57358f61-b6b4-4d13-bda8-dd7e866614c5-i0b0',
#    'id_sistema_origem': '16341',
#    'paciente_racaCor_codigo': '03',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_descricao_dose': '3ª Dose',
#    'estalecimento_noFantasia': 'USF VILA JACARE',
#    'paciente_dataNascimento': '2017-11-19',
#    'data_importacao_rnds': '2023-12-22T18:23:56.000Z',
#    '@version': '1',
#    'vacina_codigo': '99',
#    'vacina_numDose': '3',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'vacina_categoria_codigo': '2',
#    'co_condicao_maternal': 1,
#    'status': 'final',
#    'paciente_enumSexoBiologico': 'M',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'JUAZEIRO',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'paciente_racaCor_valor': 'PARDA',
#    'paciente_endereco_cep': '48917',
#    'estabelecimento_municipio_codigo': '291840',
#    'vacina_fabricante_referencia': '28290',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'b0c913a0-338c-4323-a66e-a9c39a229488-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'Novo PNI',
#    'dt_deleted': None,
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_idade': 10,
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_endereco_nmMunicipio': 'RIO DE JANEIRO',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'RJ',
#    'estabelecimento_razaoSocial': 'SMS RIO CF RINALDO DE LAMARE AP 21',
#    'estabelecimento_valor': '6506232',
#    'vacina_lote': 'GN0764',
#    'vacina_dataAplicacao': '2023-09-19T00:00:00.000Z',
#    'paciente_endereco_uf': 'RJ',
#    'paciente_endereco_coIbgeMunicipio': '330455',
#    'data_importacao_datalake': '2023-12-23T18:06:22.000Z',
#    'paciente_id': 'bf62b762cc61be3298940366c42ff24d947f81468f691de6083833e56e904a5c',
#    '@timestamp': '2023-12-23T21:15:02.771Z',
#    'document_id': 'b0c913a0-338c-4323-a66e-a9c39a229488-i0b0',
#    'id_sistema_origem': '16341',
#    'paciente_racaCor_codigo': '03',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_descricao_dose': '1º Reforço',
#    'estalecimento_noFantasia': 'SMS CF RINALDO DE LAMARE AP 21',
#    'paciente_dataNascimento': '2013-05-05',
#    'data_importacao_rnds': '2023-12-23T14:05:54.000Z',
#    '@version': '1',
#    'vacina_codigo': '99',
#    'vacina_numDose': '6',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'vacina_categoria_codigo': '2',
#    'co_condicao_maternal': 1,
#    'status': 'final',
#    'paciente_enumSexoBiologico': 'M',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'RIO DE JANEIRO',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'paciente_racaCor_valor': 'PARDA',
#    'paciente_endereco_cep': '22451',
#    'estabelecimento_municipio_codigo': '330455',
#    'vacina_fabricante_referencia': '28290',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'e0b00e1f-983e-4d7d-84b5-3ece2c8c71a3-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'Novo PNI',
#    'dt_deleted': None,
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_idade': 11,
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_endereco_nmMunicipio': 'TAMBORIL',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'CE',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE TAMBORIL',
#    'estabelecimento_valor': '2517221',
#    'vacina_lote': 'GY0354',
#    'vacina_dataAplicacao': '2023-12-23T00:00:00.000Z',
#    'paciente_endereco_uf': 'CE',
#    'paciente_endereco_coIbgeMunicipio': '231320',
#    'data_importacao_datalake': '2023-12-23T18:06:22.000Z',
#    'paciente_id': '3ab125a595b5ccb5999954d45d1a5209b94c1c6aa448f270af19aa1bfe7569df',
#    '@timestamp': '2023-12-23T21:15:02.785Z',
#    'document_id': 'e0b00e1f-983e-4d7d-84b5-3ece2c8c71a3-i0b0',
#    'id_sistema_origem': '16341',
#    'paciente_racaCor_codigo': '03',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_descricao_dose': '2ª Dose',
#    'estalecimento_noFantasia': 'UNIDADE DE SAUDE DA FAMILIA SEDE II',
#    'paciente_dataNascimento': '2012-09-17',
#    'data_importacao_rnds': '2023-12-23T11:02:31.000Z',
#    '@version': '1',
#    'vacina_codigo': '99',
#    'vacina_numDose': '2',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'vacina_categoria_codigo': '2',
#    'co_condicao_maternal': 1,
#    'status': 'final',
#    'paciente_enumSexoBiologico': 'M',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'TAMBORIL',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'paciente_racaCor_valor': 'PARDA',
#    'paciente_endereco_cep': '63750',
#    'estabelecimento_municipio_codigo': '231320',
#    'vacina_fabricante_referencia': '28290',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '89d446ef-4310-496a-a36d-a5672f77207a-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'Novo PNI',
#    'dt_deleted': None,
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_idade': 6,
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_endereco_nmMunicipio': 'BARREIRA',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'CE',
#    'estabelecimento_razaoSocial': 'PREF MUN BARREIRA',
#    'estabelecimento_valor': '2373548',
#    'vacina_lote': 'FX9154',
#    'vacina_dataAplicacao': '2023-05-12T00:00:00.000Z',
#    'paciente_endereco_uf': 'CE',
#    'paciente_endereco_coIbgeMunicipio': '230195',
#    'data_importacao_datalake': '2023-12-23T18:06:22.000Z',
#    'paciente_id': '4a81eb758e20f8eecac00e128014fd92d3e3d123d82caafb0b781013ccfba645',
#    '@timestamp': '2023-12-23T21:15:02.654Z',
#    'document_id': '89d446ef-4310-496a-a36d-a5672f77207a-i0b0',
#    'id_sistema_origem': '16341',
#    'paciente_racaCor_codigo': '03',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_descricao_dose': '3ª Dose',
#    'estalecimento_noFantasia': 'CENTRO DE SAUDE DE BARREIRA',
#    'paciente_dataNascimento': '2016-06-03',
#    'data_importacao_rnds': '2023-12-23T17:31:51.000Z',
#    '@version': '1',
#    'vacina_codigo': '99',
#    'vacina_numDose': '3',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'vacina_categoria_codigo': '2',
#    'co_condicao_maternal': 1,
#    'status': 'final',
#    'paciente_enumSexoBiologico': 'M',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'BARREIRA',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'paciente_racaCor_valor': 'PARDA',
#    'paciente_endereco_cep': '62795',
#    'estabelecimento_municipio_codigo': '230195',
#    'vacina_fabricante_referencia': '28290',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'be6352cc-5677-47d5-8282-eda6741aef35-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'SIGRAH',
#    'dt_deleted': None,
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_idade': 5,
#    'vacina_categoria_nome': 'Trabalhadores de Saúde',
#    'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_endereco_nmMunicipio': 'BELO HORIZONTE',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'MG',
#    'estabelecimento_razaoSocial': 'MUNICIPIO DE BELO HORIZONTE',
#    'estabelecimento_valor': '0023655',
#    'vacina_lote': 'GY0354',
#    'vacina_dataAplicacao': '2023-12-22T00:00:00.000Z',
#    'paciente_endereco_uf': 'MG',
#    'paciente_endereco_coIbgeMunicipio': '310620',
#    'data_importacao_datalake': '2023-12-23T18:06:22.000Z',
#    'paciente_id': 'c0f68f4b71afa406ad4aeed611f21d75d0a9a35dc17c46a2e02f6933038e99ac',
#    '@timestamp': '2023-12-23T21:15:02.658Z',
#    'document_id': 'be6352cc-5677-47d5-8282-eda6741aef35-i0b0',
#    'id_sistema_origem': '19788',
#    'paciente_racaCor_codigo': '99',
#    'ds_condicao_maternal': None,
#    'vacina_descricao_dose': 'Reforço',
#    'estalecimento_noFantasia': 'CENTRO DE SAUDE MANTIQUEIRA',
#    'paciente_dataNascimento': '2018-10-13',
#    'data_importacao_rnds': '2023-12-22T20:49:32.000Z',
#    '@version': '1',
#    'vacina_codigo': '99',
#    'vacina_numDose': '38',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'vacina_categoria_codigo': '9',
#    'co_condicao_maternal': None,
#    'status': 'final',
#    'paciente_enumSexoBiologico': 'F',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'BELO HORIZONTE',
#    'vacina_grupoAtendimento_codigo': '000926',
#    'paciente_racaCor_valor': 'SEM INFORMACAO',
#    'paciente_endereco_cep': '31575',
#    'estabelecimento_municipio_codigo': '310620',
#    'vacina_fabricante_referencia': None,
#    'vacina_grupoAtendimento_nome': 'Outros'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'dae82dc8-63a9-4845-84b0-3464d8f0b105-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'Novo PNI',
#    'dt_deleted': None,
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_idade': 29,
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_nome': 'PFIZER',
#    'paciente_endereco_nmMunicipio': 'UARINI',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'AM',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE UARINI',
#    'estabelecimento_valor': '3320413',
#    'vacina_lote': '2F1070A',
#    'vacina_dataAplicacao': '2023-10-26T00:00:00.000Z',
#    'paciente_endereco_uf': 'AM',
#    'paciente_endereco_coIbgeMunicipio': '130426',
#    'data_importacao_datalake': '2023-12-23T18:06:22.000Z',
#    'paciente_id': 'c9abfba5aee5c2b8f7e2d2f657f2fe9292d624d817374a4195db44f6b6cb98e4',
#    '@timestamp': '2023-12-23T21:15:02.679Z',
#    'document_id': 'dae82dc8-63a9-4845-84b0-3464d8f0b105-i0b0',
#    'id_sistema_origem': '16341',
#    'paciente_racaCor_codigo': '04',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_descricao_dose': 'Revacinação',
#    'estalecimento_noFantasia': 'CENTRO DE SAUDE MARIO LOPES',
#    'paciente_dataNascimento': '1994-10-16',
#    'data_importacao_rnds': '2023-12-22T19:51:08.000Z',
#    '@version': '1',
#    'vacina_codigo': '87',
#    'vacina_numDose': '10',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY',
#    'vacina_categoria_codigo': '2',
#    'co_condicao_maternal': 1,
#    'status': 'final',
#    'paciente_enumSexoBiologico': 'F',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'UARINI',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'paciente_racaCor_valor': 'AMARELA',
#    'paciente_endereco_cep': '69530',
#    'estabelecimento_municipio_codigo': '130426',
#    'vacina_fabricante_referencia': '28290',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '331b2bdd-7808-441a-a3fe-02faf38cabfe-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'Novo PNI',
#    'dt_deleted': None,
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_idade': 9,
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_endereco_nmMunicipio': 'EIRUNEPE',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'AM',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE EIRUNEPE',
#    'estabelecimento_valor': '2018691',
#    'vacina_lote': 'GN0764',
#    'vacina_dataAplicacao': '2023-12-01T00:00:00.000Z',
#    'paciente_endereco_uf': 'AM',
#    'paciente_endereco_coIbgeMunicipio': '130140',
#    'data_importacao_datalake': '2023-12-23T18:06:22.000Z',
#    'paciente_id': '43c9ff819b2385afc61a25c48cb9c81b3cebc25251e90212ec8fd2314ad34246',
#    '@timestamp': '2023-12-23T21:15:02.609Z',
#    'document_id': '331b2bdd-7808-441a-a3fe-02faf38cabfe-i0b0',
#    'id_sistema_origem': '16341',
#    'paciente_racaCor_codigo': '03',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_descricao_dose': '1ª Dose',
#    'estalecimento_noFantasia': 'UNIDADE BASICA GENESIO ALBUQUERQUE',
#    'paciente_dataNascimento': '2014-09-28',
#    'data_importacao_rnds': '2023-12-22T20:49:25.000Z',
#    '@version': '1',
#    'vacina_codigo': '99',
#    'vacina_numDose': '1',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'vacina_categoria_codigo': '2',
#    'co_condicao_maternal': 1,
#    'status': 'final',
#    'paciente_enumSexoBiologico': 'M',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'EIRUNEPE',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'paciente_racaCor_valor': 'PARDA',
#    'paciente_endereco_cep': '',
#    'estabelecimento_municipio_codigo': '130140',
#    'vacina_fabricante_referencia': '28290',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '59becf01-0345-420d-9d8c-1f207a8cc90c-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'Novo PNI',
#    'dt_deleted': None,
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_idade': 15,
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_nome': 'PFIZER',
#    'paciente_endereco_nmMunicipio': 'EIRUNEPE',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'AM',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE EIRUNEPE',
#    'estabelecimento_valor': '2018691',
#    'vacina_lote': '2F1070A',
#    'vacina_dataAplicacao': '2023-12-01T00:00:00.000Z',
#    'paciente_endereco_uf': 'AM',
#    'paciente_endereco_coIbgeMunicipio': '130140',
#    'data_importacao_datalake': '2023-12-23T18:06:22.000Z',
#    'paciente_id': 'fd361d52d92c737d1693642ca06b65c832e3d6eb9fa21dc8dd28a29bd6a43679',
#    '@timestamp': '2023-12-23T21:15:02.686Z',
#    'document_id': '59becf01-0345-420d-9d8c-1f207a8cc90c-i0b0',
#    'id_sistema_origem': '16341',
#    'paciente_racaCor_codigo': '03',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_descricao_dose': '3ª Dose',
#    'estalecimento_noFantasia': 'UNIDADE BASICA GENESIO ALBUQUERQUE',
#    'paciente_dataNascimento': '2007-12-27',
#    'data_importacao_rnds': '2023-12-22T21:14:06.000Z',
#    '@version': '1',
#    'vacina_codigo': '87',
#    'vacina_numDose': '3',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY',
#    'vacina_categoria_codigo': '2',
#    'co_condicao_maternal': 1,
#    'status': 'final',
#    'paciente_enumSexoBiologico': 'F',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'EIRUNEPE',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'paciente_racaCor_valor': 'PARDA',
#    'paciente_endereco_cep': '69880',
#    'estabelecimento_municipio_codigo': '130140',
#    'vacina_fabricante_referencia': '28290',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '5d66c90b-ba78-4752-b453-f2e5cc611f37-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'Novo PNI',
#    'dt_deleted': None,
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_idade': 5,
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_endereco_nmMunicipio': 'AGUAS BELAS',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'PE',
#    'estabelecimento_razaoSocial': 'PREFEITURA DE AGUAS BELAS',
#    'estabelecimento_valor': '6818633',
#    'vacina_lote': 'GY0354',
#    'vacina_dataAplicacao': '2023-12-15T00:00:00.000Z',
#    'paciente_endereco_uf': 'PE',
#    'paciente_endereco_coIbgeMunicipio': '260050',
#    'data_importacao_datalake': '2023-12-23T18:06:22.000Z',
#    'paciente_id': '2070cfe367016188484041fef05ee4bf16efb98ab5e454f4510813035ef2ad5b',
#    '@timestamp': '2023-12-23T21:15:02.763Z',
#    'document_id': '5d66c90b-ba78-4752-b453-f2e5cc611f37-i0b0',
#    'id_sistema_origem': '16341',
#    'paciente_racaCor_codigo': '03',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_descricao_dose': '2ª Dose',
#    'estalecimento_noFantasia': 'USF DR CLECIO XAVIER',
#    'paciente_dataNascimento': '2018-08-19',
#    'data_importacao_rnds': '2023-12-22T20:13:01.000Z',
#    '@version': '1',
#    'vacina_codigo': '99',
#    'vacina_numDose': '2',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'vacina_categoria_codigo': '2',
#    'co_condicao_maternal': 1,
#    'status': 'final',
#    'paciente_enumSexoBiologico': 'M',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'AGUAS BELAS',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'paciente_racaCor_valor': 'PARDA',
#    'paciente_endereco_cep': '55340',
#    'estabelecimento_municipio_codigo': '260050',
#    'vacina_fabricante_referencia': '28290',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'ea882410-7b1b-463f-9f4a-9e67948e636f-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'Novo PNI',
#    'dt_deleted': None,
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_idade': 31,
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_nome': 'PFIZER',
#    'paciente_endereco_nmMunicipio': 'BELO HORIZONTE',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'MG',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL PRESIDENTE JUSCELINO',
#    'estabelecimento_valor': '2157357',
#    'vacina_lote': 'FJ4184',
#    'vacina_dataAplicacao': '2023-02-28T00:00:00.000Z',
#    'paciente_endereco_uf': 'MG',
#    'paciente_endereco_coIbgeMunicipio': '310620',
#    'data_importacao_datalake': '2023-12-23T18:06:22.000Z',
#    'paciente_id': '3709b497fe88bcf2ab7b920e3981655631874f45f9f6007065cef1c296bdd3f8',
#    '@timestamp': '2023-12-23T21:15:02.636Z',
#    'document_id': 'ea882410-7b1b-463f-9f4a-9e67948e636f-i0b0',
#    'id_sistema_origem': '16341',
#    'paciente_racaCor_codigo': '03',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_descricao_dose': '3ª Dose',
#    'estalecimento_noFantasia': 'CENTRO DE SAUDE DE PRESIDENTE JUSCELINO',
#    'paciente_dataNascimento': '1992-01-15',
#    'data_importacao_rnds': '2023-12-22T22:52:37.000Z',
#    '@version': '1',
#    'vacina_codigo': '87',
#    'vacina_numDose': '3',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY',
#    'vacina_categoria_codigo': '2',
#    'co_condicao_maternal': 1,
#    'status': 'final',
#    'paciente_enumSexoBiologico': 'F',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'PRESIDENTE JUSCELINO',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'paciente_racaCor_valor': 'PARDA',
#    'paciente_endereco_cep': '30640',
#    'estabelecimento_municipio_codigo': '315320',
#    'vacina_fabricante_referencia': '28290',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'd5470d9d-aaa8-4984-995f-76db6f763eb6-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'VACIVIDA',
#    'dt_deleted': None,
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_idade': 5,
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_endereco_nmMunicipio': 'GUARULHOS',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'SP',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE GUARULHOS',
#    'estabelecimento_valor': '2055198',
#    'vacina_lote': 'GY0354',
#    'vacina_dataAplicacao': '2023-12-22T00:00:00.000Z',
#    'paciente_endereco_uf': 'SP',
#    'paciente_endereco_coIbgeMunicipio': '351880',
#    'data_importacao_datalake': '2023-12-23T18:06:22.000Z',
#    'paciente_id': '6dbeeabd8a33741855026549fd4a329cfbca59680996df27c0ae0cbe05548d11',
#    '@timestamp': '2023-12-23T21:15:02.645Z',
#    'document_id': 'd5470d9d-aaa8-4984-995f-76db6f763eb6-i0b0',
#    'id_sistema_origem': '18262',
#    'paciente_racaCor_codigo': '03',
#    'ds_condicao_maternal': None,
#    'vacina_descricao_dose': '1º Reforço',
#    'estalecimento_noFantasia': 'UBS VILA BARROS',
#    'paciente_dataNascimento': '2018-09-12',
#    'data_importacao_rnds': '2023-12-22T18:25:32.000Z',
#    '@version': '1',
#    'vacina_codigo': '99',
#    'vacina_numDose': '6',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'vacina_categoria_codigo': '2',
#    'co_condicao_maternal': None,
#    'status': 'final',
#    'paciente_enumSexoBiologico': 'M',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'GUARULHOS',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'paciente_racaCor_valor': 'PARDA',
#    'paciente_endereco_cep': '07195',
#    'estabelecimento_municipio_codigo': '351880',
#    'vacina_fabricante_referencia': None,
#    'vacina_grupoAtendimento_nome': 'Faixa Etária'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'dc76affc-5c96-433b-9ae8-b72a8e223f7d-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'Novo PNI',
#    'dt_deleted': None,
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_idade': 68,
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_nome': 'PFIZER',
#    'paciente_endereco_nmMunicipio': 'BELO HORIZONTE',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'MG',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL PRESIDENTE JUSCELINO',
#    'estabelecimento_valor': '2157357',
#    'vacina_lote': 'FF8845',
#    'vacina_dataAplicacao': '2023-05-05T00:00:00.000Z',
#    'paciente_endereco_uf': 'MG',
#    'paciente_endereco_coIbgeMunicipio': '310620',
#    'data_importacao_datalake': '2023-12-23T18:06:22.000Z',
#    'paciente_id': 'acdc3112dfc0bbc14c6dd6d566dc54b52a85cd0bd230929e6f3180d5cf1af5a7',
#    '@timestamp': '2023-12-23T21:15:02.677Z',
#    'document_id': 'dc76affc-5c96-433b-9ae8-b72a8e223f7d-i0b0',
#    'id_sistema_origem': '16341',
#    'paciente_racaCor_codigo': '01',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_descricao_dose': '3ª Dose',
#    'estalecimento_noFantasia': 'CENTRO DE SAUDE DE PRESIDENTE JUSCELINO',
#    'paciente_dataNascimento': '1954-05-07',
#    'data_importacao_rnds': '2023-12-23T00:34:02.000Z',
#    '@version': '1',
#    'vacina_codigo': '87',
#    'vacina_numDose': '3',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY',
#    'vacina_categoria_codigo': '2',
#    'co_condicao_maternal': 1,
#    'status': 'final',
#    'paciente_enumSexoBiologico': 'F',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'PRESIDENTE JUSCELINO',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'paciente_racaCor_valor': 'BRANCA',
#    'paciente_endereco_cep': '30640',
#    'estabelecimento_municipio_codigo': '315320',
#    'vacina_fabricante_referencia': '28290',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '025f2224-8222-41be-8d96-76e86b46ac1d-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'VACIVIDA',
#    'dt_deleted': None,
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_idade': 36,
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_nome': 'PFIZER',
#    'paciente_endereco_nmMunicipio': 'PINDAMONHANGABA',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'SP',
#    'estabelecimento_razaoSocial': 'PREFEITURA DO MUNICIPIO DE SAO PAULO',
#    'estabelecimento_valor': '2752344',
#    'vacina_lote': '2F1071A',
#    'vacina_dataAplicacao': '2023-12-22T00:00:00.000Z',
#    'paciente_endereco_uf': 'SP',
#    'paciente_endereco_coIbgeMunicipio': '353800',
#    'data_importacao_datalake': '2023-12-23T18:06:22.000Z',
#    'paciente_id': '3b7b69a2a228dc71401cb117589a88fa8505b6028b439ae4d0438c6257b968a1',
#    '@timestamp': '2023-12-23T21:15:02.684Z',
#    'document_id': '025f2224-8222-41be-8d96-76e86b46ac1d-i0b0',
#    'id_sistema_origem': '18262',
#    'paciente_racaCor_codigo': '99',
#    'ds_condicao_maternal': None,
#    'vacina_descricao_dose': '2ª Dose',
#    'estalecimento_noFantasia': 'UBS VILA BERTIOGA DOMINGOS DELASCIO',
#    'paciente_dataNascimento': '1987-06-01',
#    'data_importacao_rnds': '2023-12-22T18:22:33.000Z',
#    '@version': '1',
#    'vacina_codigo': '87',
#    'vacina_numDose': '2',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY',
#    'vacina_categoria_codigo': '2',
#    'co_condicao_maternal': None,
#    'status': 'final',
#    'paciente_enumSexoBiologico': 'M',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'SAO PAULO',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'paciente_racaCor_valor': 'SEM INFORMACAO',
#    'paciente_endereco_cep': '12411',
#    'estabelecimento_municipio_codigo': '355030',
#    'vacina_fabricante_referencia': None,
#    'vacina_grupoAtendimento_nome': 'Faixa Etária'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '718e12b3-ccd4-444c-bd7a-a3dda6d2ee8d-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'Novo PNI',
#    'dt_deleted': None,
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_idade': 16,
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_nome': 'PFIZER',
#    'paciente_endereco_nmMunicipio': 'UARINI',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'AM',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE UARINI',
#    'estabelecimento_valor': '3320413',
#    'vacina_lote': '2F1070A',
#    'vacina_dataAplicacao': '2023-10-26T00:00:00.000Z',
#    'paciente_endereco_uf': 'AM',
#    'paciente_endereco_coIbgeMunicipio': '130426',
#    'data_importacao_datalake': '2023-12-23T18:06:22.000Z',
#    'paciente_id': '2bf78d54e814719cd785211d2f7860198e64ac1b8fdc1976cda2b61f16c788fa',
#    '@timestamp': '2023-12-23T21:15:02.697Z',
#    'document_id': '718e12b3-ccd4-444c-bd7a-a3dda6d2ee8d-i0b0',
#    'id_sistema_origem': '16341',
#    'paciente_racaCor_codigo': '03',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_descricao_dose': '1º Reforço',
#    'estalecimento_noFantasia': 'CENTRO DE SAUDE MARIO LOPES',
#    'paciente_dataNascimento': '2007-04-12',
#    'data_importacao_rnds': '2023-12-22T20:38:02.000Z',
#    '@version': '1',
#    'vacina_codigo': '87',
#    'vacina_numDose': '6',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY',
#    'vacina_categoria_codigo': '2',
#    'co_condicao_maternal': 1,
#    'status': 'final',
#    'paciente_enumSexoBiologico': 'M',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'UARINI',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'paciente_racaCor_valor': 'PARDA',
#    'paciente_endereco_cep': '69530',
#    'estabelecimento_municipio_codigo': '130426',
#    'vacina_fabricante_referencia': '28290',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'de936cb1-65af-4ee6-ba7d-be766c1f172e-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'Novo PNI',
#    'dt_deleted': None,
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_idade': 40,
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_nome': 'SINOVAC/BUTANTAN',
#    'paciente_endereco_nmMunicipio': 'TERESINA',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'PI',
#    'estabelecimento_razaoSocial': 'MUNICIPIO TERESINA',
#    'estabelecimento_valor': '5347351',
#    'vacina_lote': '230095',
#    'vacina_dataAplicacao': '2023-12-22T00:00:00.000Z',
#    'paciente_endereco_uf': 'PI',
#    'paciente_endereco_coIbgeMunicipio': '221100',
#    'data_importacao_datalake': '2023-12-23T18:06:22.000Z',
#    'paciente_id': '666f798f60375a39fb589b52c3c2e6027bba827a64bbd739533df078616edd6a',
#    '@timestamp': '2023-12-23T21:15:02.768Z',
#    'document_id': 'de936cb1-65af-4ee6-ba7d-be766c1f172e-i0b0',
#    'id_sistema_origem': '16341',
#    'paciente_racaCor_codigo': '01',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_descricao_dose': '1ª Dose',
#    'estalecimento_noFantasia': 'UNIDADE BASICA DE SAUDE MARIA DULCE CUNHA SAO JOAO',
#    'paciente_dataNascimento': '1983-11-29',
#    'data_importacao_rnds': '2023-12-22T22:14:01.000Z',
#    '@version': '1',
#    'vacina_codigo': '86',
#    'vacina_numDose': '1',
#    'vacina_nome': 'COVID-19 SINOVAC/BUTANTAN - CORONAVAC',
#    'vacina_categoria_codigo': '2',
#    'co_condicao_maternal': 1,
#    'status': 'final',
#    'paciente_enumSexoBiologico': 'M',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'TERESINA',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'paciente_racaCor_valor': 'BRANCA',
#    'paciente_endereco_cep': '64078',
#    'estabelecimento_municipio_codigo': '221100',
#    'vacina_fabricante_referencia': '152',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '68a26d02-c47e-4daa-a400-0448cdae6969-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'Novo PNI',
#    'dt_deleted': None,
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_idade': 14,
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_endereco_nmMunicipio': 'VARZEA GRANDE',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'MT',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE VARZEA GRANDE',
#    'estabelecimento_valor': '2390736',
#    'vacina_lote': 'GN0764',
#    'vacina_dataAplicacao': '2023-12-22T00:00:00.000Z',
#    'paciente_endereco_uf': 'MT',
#    'paciente_endereco_coIbgeMunicipio': '510840',
#    'data_importacao_datalake': '2023-12-23T18:06:22.000Z',
#    'paciente_id': '41ec06b720553ba9dccea68d31b24e1749b6b1db97e0adc1b67bd0785087eb35',
#    '@timestamp': '2023-12-23T21:15:02.612Z',
#    'document_id': '68a26d02-c47e-4daa-a400-0448cdae6969-i0b0',
#    'id_sistema_origem': '16341',
#    'paciente_racaCor_codigo': '99',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_descricao_dose': '1ª Dose Revacinação',
#    'estalecimento_noFantasia': 'ESF JARDIM GLORIA MOACYR D LANNES',
#    'paciente_dataNascimento': '2009-05-21',
#    'data_importacao_rnds': '2023-12-22T19:13:05.000Z',
#    '@version': '1',
#    'vacina_codigo': '99',
#    'vacina_numDose': '32',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'vacina_categoria_codigo': '2',
#    'co_condicao_maternal': 1,
#    'status': 'final',
#    'paciente_enumSexoBiologico': 'F',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'VARZEA GRANDE',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'paciente_racaCor_valor': 'SEM INFORMACAO',
#    'paciente_endereco_cep': '78158',
#    'estabelecimento_municipio_codigo': '510840',
#    'vacina_fabricante_referencia': '28290',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'cd63ca92-8a44-4727-a1e1-eefbdb177f5f-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'Novo PNI',
#    'dt_deleted': None,
#    'paciente_nacionalidade_enumNacionalidade': 'E',
#    'paciente_idade': 28,
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_nome': 'PFIZER',
#    'paciente_endereco_nmMunicipio': 'PACARAIMA',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'RR',
#    'estabelecimento_razaoSocial': 'MUNICIPIO DE BOA VISTA',
#    'estabelecimento_valor': '2744449',
#    'vacina_lote': 'PCA0101',
#    'vacina_dataAplicacao': '2023-12-22T00:00:00.000Z',
#    'paciente_endereco_uf': 'RR',
#    'paciente_endereco_coIbgeMunicipio': '140045',
#    'data_importacao_datalake': '2023-12-23T18:06:22.000Z',
#    'paciente_id': '24cc0096b834790c58894bba2196f2847fc946c877bfe866515f6fe8d53d2888',
#    '@timestamp': '2023-12-23T21:15:02.623Z',
#    'document_id': 'cd63ca92-8a44-4727-a1e1-eefbdb177f5f-i0b0',
#    'id_sistema_origem': '16341',
#    'paciente_racaCor_codigo': '03',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_descricao_dose': '2ª Dose',
#    'estalecimento_noFantasia': 'UNIDADE BASICA DE SAUDE ENF VANDERLY NASCIMENTO DE SOUZA',
#    'paciente_dataNascimento': '1995-02-14',
#    'data_importacao_rnds': '2023-12-22T18:56:37.000Z',
#    '@version': '1',
#    'vacina_codigo': '87',
#    'vacina_numDose': '2',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY',
#    'vacina_categoria_codigo': '2',
#    'co_condicao_maternal': 1,
#    'status': 'final',
#    'paciente_enumSexoBiologico': 'M',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'BOA VISTA',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'paciente_racaCor_valor': 'PARDA',
#    'paciente_endereco_cep': '69345',
#    'estabelecimento_municipio_codigo': '140010',
#    'vacina_fabricante_referencia': '28290',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'be6dc0b9-b0e2-4343-af15-4f4ed10eb6a7-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'Novo PNI',
#    'dt_deleted': None,
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_idade': 36,
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_nome': 'PFIZER',
#    'paciente_endereco_nmMunicipio': 'BELO HORIZONTE',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'MG',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL PRESIDENTE JUSCELINO',
#    'estabelecimento_valor': '2157357',
#    'vacina_lote': 'FG3535',
#    'vacina_dataAplicacao': '2023-08-31T00:00:00.000Z',
#    'paciente_endereco_uf': 'MG',
#    'paciente_endereco_coIbgeMunicipio': '310620',
#    'data_importacao_datalake': '2023-12-23T18:06:22.000Z',
#    'paciente_id': 'b62602fc56076f77b6a933102779aa884bbff132d35fb520d054633b80c8222b',
#    '@timestamp': '2023-12-23T21:15:02.623Z',
#    'document_id': 'be6dc0b9-b0e2-4343-af15-4f4ed10eb6a7-i0b0',
#    'id_sistema_origem': '16341',
#    'paciente_racaCor_codigo': '01',
#    'ds_condicao_maternal': 'Nenhuma',
#    'vacina_descricao_dose': '1º Reforço',
#    'estalecimento_noFantasia': 'CENTRO DE SAUDE DE PRESIDENTE JUSCELINO',
#    'paciente_dataNascimento': '1986-09-03',
#    'data_importacao_rnds': '2023-12-22T22:10:06.000Z',
#    '@version': '1',
#    'vacina_codigo': '87',
#    'vacina_numDose': '6',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY',
#    'vacina_categoria_codigo': '2',
#    'co_condicao_maternal': 1,
#    'status': 'final',
#    'paciente_enumSexoBiologico': 'M',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'estabelecimento_municipio_nome': 'PRESIDENTE JUSCELINO',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'paciente_racaCor_valor': 'BRANCA',
#    'paciente_endereco_cep': '30640',
#    'estabelecimento_municipio_codigo': '315320',
#    'vacina_fabricante_referencia': '28290',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '2033ef2e-f6ff-4d93-acc4-b0321f49a39d-i0b0',
#   '_score': 1.0,
#   '_source': {'sistema_origem': 'VACIVIDA',
#    'dt_deleted': None,
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'paciente_idade': 19,
#    'vacina_categoria_nome': 'Faixa Etária',
#    'vacina_fabricante_nome': 'PFIZER',
#    'paciente_endereco_nmMunicipio': 'SAO PAULO',
#    'paciente_endereco_coPais': '10',
#    'estabelecimento_uf': 'SP',
#    'estabelecimento_razaoSocial': 'PREFEITURA DO MUNICIPIO DE SAO PAULO',
#    'estabelecimento_valor': '3956946',
#    'vacina_lote': '2F1070A',
#    'vacina_dataAplicacao': '2023-12-22T00:00:00.000Z',
#    'paciente_endereco_uf': 'SP',
#    'paciente_endereco_coIbgeMunicipio': '355030',
#    'data_importacao_datalake': '2023-12-23T18:06:22.000Z',
#    'paciente_id': '125b1139e14c0ec0699d691bed9631107709d5f63311a8cb972739c623af9a17',
#    '@timestamp': '2023-12-23T21:15:02.670Z',
#    'document_id': '2033ef2e-f6ff-4d93-acc4-b0321f49a39d-i0b0',
#    'id_sistema_origem': '18262',
#    'paciente_racaCor_codigo': '03',
#    'ds_condicao_maternal': None,
#    'vacina_descricao_dose': '2ª Dose',
#    'estalecimento_noFantasia': 'UBS JARDIM OLINDA',
#    'paciente_dataNascimento': '2004-02-12',
#    'data_importacao_rnds': '2023-12-22T18:32:22.000Z',
#    '@version': '1',
#    'vacina_codigo': '87',
#    'vacina_numDose': '2',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY',
#    'vacina_categoria_codigo': '2',
#    'co_condicao_maternal': None,
#    'status': 'final',
#    'paciente_enumSexoBiologico': 'F',
# ...
#    'ds_condicao_maternal': 'Nenhuma',
#    'id_sistema_origem': '16341',
#    'vacina_categoria_codigo': '2',
#    'paciente_idade': 13,
#    'co_condicao_maternal': 1,
#    'data_importacao_datalake': '2023-11-23T18:06:25.000Z',
#    'estabelecimento_municipio_codigo': '261370',
#    'vacina_numDose': '6',
#    'vacina_codigo': '87',
#    'paciente_endereco_nmMunicipio': 'PETROLINA',
#    'vacina_dataAplicacao': '2023-05-29T00:00:00.000Z',
#    'paciente_dataNascimento': '2010-02-12',
#    '@version': '1',
#    'paciente_endereco_uf': 'PE',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'estabelecimento_uf': 'PE'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '765cb08e-d14e-4658-9173-d192b70424f1-i0b0',
#   '_score': 1.0,
#   '_source': {'document_id': '765cb08e-d14e-4658-9173-d192b70424f1-i0b0',
#    'vacina_descricao_dose': '1º Reforço',
#    'data_importacao_rnds': '2023-11-23T15:41:30.000Z',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE ITANHAEM',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'dt_deleted': None,
#    'paciente_endereco_coIbgeMunicipio': '352610',
#    'vacina_fabricante_nome': 'PFIZER',
#    'paciente_endereco_coPais': '10',
#    'paciente_racaCor_valor': 'AMARELA',
#    'paciente_id': '9021edef946f25c9ff534b831f6bf9a25b445ab32445ba6d0f2c556de8db15d8',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'estabelecimento_municipio_nome': 'ITANHAEM',
#    'paciente_enumSexoBiologico': 'M',
#    '@timestamp': '2023-11-23T21:16:08.497Z',
#    'sistema_origem': 'VACIVIDA',
#    'status': 'final',
#    'estalecimento_noFantasia': 'UNIDADE DE SAUDE DA FAMILIA GUAPIRANGA',
#    'estabelecimento_valor': '2087901',
#    'paciente_endereco_cep': '11800',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária',
#    'vacina_fabricante_referencia': None,
#    'vacina_lote': '2F1070A',
#    'paciente_racaCor_codigo': '04',
#    'ds_condicao_maternal': None,
#    'id_sistema_origem': '18262',
#    'vacina_categoria_codigo': '2',
#    'paciente_idade': 31,
#    'co_condicao_maternal': None,
#    'data_importacao_datalake': '2023-11-23T18:06:25.000Z',
#    'estabelecimento_municipio_codigo': '352210',
#    'vacina_numDose': '6',
#    'vacina_codigo': '87',
#    'paciente_endereco_nmMunicipio': 'JUQUIA',
#    'vacina_dataAplicacao': '2023-11-23T00:00:00.000Z',
#    'paciente_dataNascimento': '1992-06-14',
#    '@version': '1',
#    'paciente_endereco_uf': 'SP',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'estabelecimento_uf': 'SP'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'd88551a9-cc44-4d93-980f-205bafe9902f-i0b0',
#   '_score': 1.0,
#   '_source': {'document_id': 'd88551a9-cc44-4d93-980f-205bafe9902f-i0b0',
#    'vacina_descricao_dose': '1º Reforço',
#    'data_importacao_rnds': '2023-11-23T14:02:54.000Z',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE GUARULHOS',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'dt_deleted': None,
#    'paciente_endereco_coIbgeMunicipio': '351880',
#    'vacina_fabricante_nome': 'PFIZER',
#    'paciente_endereco_coPais': '10',
#    'paciente_racaCor_valor': 'BRANCA',
#    'paciente_id': '222dedf435789592eba4be1c3c1b7e8661be23b51cd98ea7a01c29960e6d5f6b',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'estabelecimento_municipio_nome': 'GUARULHOS',
#    'paciente_enumSexoBiologico': 'F',
#    '@timestamp': '2023-11-23T21:16:08.513Z',
#    'sistema_origem': 'VACIVIDA',
#    'status': 'final',
#    'estalecimento_noFantasia': 'UBS NOVA BONSUCESSO',
#    'estabelecimento_valor': '7587198',
#    'paciente_endereco_cep': '07178',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária',
#    'vacina_fabricante_referencia': None,
#    'vacina_lote': '2F1070A',
#    'paciente_racaCor_codigo': '01',
#    'ds_condicao_maternal': None,
#    'id_sistema_origem': '18262',
#    'vacina_categoria_codigo': '2',
#    'paciente_idade': 13,
#    'co_condicao_maternal': None,
#    'data_importacao_datalake': '2023-11-23T18:06:25.000Z',
#    'estabelecimento_municipio_codigo': '351880',
#    'vacina_numDose': '6',
#    'vacina_codigo': '87',
#    'paciente_endereco_nmMunicipio': 'GUARULHOS',
#    'vacina_dataAplicacao': '2023-11-23T00:00:00.000Z',
#    'paciente_dataNascimento': '2010-02-18',
#    '@version': '1',
#    'paciente_endereco_uf': 'SP',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'estabelecimento_uf': 'SP'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'b8f62423-56ee-4b3b-9a7b-c70e972c629b-i0b0',
#   '_score': 1.0,
#   '_source': {'document_id': 'b8f62423-56ee-4b3b-9a7b-c70e972c629b-i0b0',
#    'vacina_descricao_dose': '1ª Dose',
#    'data_importacao_rnds': '2023-11-22T20:29:24.000Z',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'estabelecimento_razaoSocial': 'MUNICIPAL DE VILA VELHA',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'dt_deleted': None,
#    'paciente_endereco_coIbgeMunicipio': '316294',
#    'vacina_fabricante_nome': 'PFIZER',
#    'paciente_endereco_coPais': '10',
#    'paciente_racaCor_valor': 'PRETA',
#    'paciente_id': 'c6c139ced12418a3c1ff99c997c759d5f06171d0682038eef27bd5cc4647ebc8',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'estabelecimento_municipio_nome': 'VILA VELHA',
#    'paciente_enumSexoBiologico': 'F',
#    '@timestamp': '2023-11-23T21:16:08.513Z',
#    'sistema_origem': 'VACINA E CONFIA ES',
#    'status': 'final',
#    'estalecimento_noFantasia': 'UNIDADE DE SAUDE DA FAMILIA DE VILA GARRIDO',
#    'estabelecimento_valor': '2546825',
#    'paciente_endereco_cep': '37945',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária',
#    'vacina_fabricante_referencia': None,
#    'vacina_lote': '2F1070A',
#    'paciente_racaCor_codigo': '02',
#    'ds_condicao_maternal': None,
#    'id_sistema_origem': '24294',
#    'vacina_categoria_codigo': '2',
#    'paciente_idade': 12,
#    'co_condicao_maternal': None,
#    'data_importacao_datalake': '2023-11-23T18:06:25.000Z',
#    'estabelecimento_municipio_codigo': '320520',
#    'vacina_numDose': '1',
#    'vacina_codigo': '87',
#    'paciente_endereco_nmMunicipio': 'SAO JOSE DA BARRA',
#    'vacina_dataAplicacao': '2023-11-22T00:00:00.000Z',
#    'paciente_dataNascimento': '2011-09-26',
#    '@version': '1',
#    'paciente_endereco_uf': 'MG',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'estabelecimento_uf': 'ES'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '6c06880a-6ed8-420c-8607-36c1f3d089e2-i0b0',
#   '_score': 1.0,
#   '_source': {'document_id': '6c06880a-6ed8-420c-8607-36c1f3d089e2-i0b0',
#    'vacina_descricao_dose': '1º Reforço',
#    'data_importacao_rnds': '2023-11-22T19:11:19.000Z',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE FRANCA',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'dt_deleted': None,
#    'paciente_endereco_coIbgeMunicipio': '351620',
#    'vacina_fabricante_nome': 'PFIZER',
#    'paciente_endereco_coPais': '10',
#    'paciente_racaCor_valor': 'PARDA',
#    'paciente_id': '400f4fe24cfdc9970271592330389353c231cf48620ede1718d1d4caf9fc7884',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'estabelecimento_municipio_nome': 'FRANCA',
#    'paciente_enumSexoBiologico': 'F',
#    '@timestamp': '2023-11-23T21:16:08.515Z',
#    'sistema_origem': 'VACIVIDA',
#    'status': 'final',
#    'estalecimento_noFantasia': 'UBS LEPORACE',
#    'estabelecimento_valor': '2035871',
#    'paciente_endereco_cep': '14401',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária',
#    'vacina_fabricante_referencia': None,
#    'vacina_lote': '2F1070A',
#    'paciente_racaCor_codigo': '03',
#    'ds_condicao_maternal': None,
#    'id_sistema_origem': '18262',
#    'vacina_categoria_codigo': '2',
#    'paciente_idade': 12,
#    'co_condicao_maternal': None,
#    'data_importacao_datalake': '2023-11-23T18:06:25.000Z',
#    'estabelecimento_municipio_codigo': '351620',
#    'vacina_numDose': '6',
#    'vacina_codigo': '87',
#    'paciente_endereco_nmMunicipio': 'FRANCA',
#    'vacina_dataAplicacao': '2023-11-22T00:00:00.000Z',
#    'paciente_dataNascimento': '2011-08-22',
#    '@version': '1',
#    'paciente_endereco_uf': 'SP',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'estabelecimento_uf': 'SP'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'a46026a2-d05b-42be-94af-b47f15c44c7e-i0b0',
#   '_score': 1.0,
#   '_source': {'document_id': 'a46026a2-d05b-42be-94af-b47f15c44c7e-i0b0',
#    'vacina_descricao_dose': '1ª Dose Revacinação',
#    'data_importacao_rnds': '2023-11-23T13:10:42.000Z',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE FRANCISCO SA',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'dt_deleted': None,
#    'paciente_endereco_coIbgeMunicipio': '150442',
#    'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_endereco_coPais': '10',
#    'paciente_racaCor_valor': 'PRETA',
#    'paciente_id': 'e01ed0bca3a2f611337dc61e53f59e5c07382ddc06e84a82f58cbf75fed40e46',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'estabelecimento_municipio_nome': 'FRANCISCO SA',
#    'paciente_enumSexoBiologico': 'F',
#    '@timestamp': '2023-11-23T21:16:08.518Z',
#    'sistema_origem': 'Novo PNI',
#    'status': 'final',
#    'estalecimento_noFantasia': 'UBS EDITH SILVEIRA',
#    'estabelecimento_valor': '2185490',
#    'paciente_endereco_cep': '67214',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária',
#    'vacina_fabricante_referencia': '28290',
#    'vacina_lote': 'GN0764',
#    'paciente_racaCor_codigo': '02',
#    'ds_condicao_maternal': 'Nenhuma',
#    'id_sistema_origem': '16341',
#    'vacina_categoria_codigo': '2',
#    'paciente_idade': 8,
#    'co_condicao_maternal': 1,
#    'data_importacao_datalake': '2023-11-23T18:06:25.000Z',
#    'estabelecimento_municipio_codigo': '312670',
#    'vacina_numDose': '32',
#    'vacina_codigo': '99',
#    'paciente_endereco_nmMunicipio': 'MARITUBA',
#    'vacina_dataAplicacao': '2023-10-28T00:00:00.000Z',
#    'paciente_dataNascimento': '2015-05-14',
#    '@version': '1',
#    'paciente_endereco_uf': 'PA',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'estabelecimento_uf': 'MG'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': '833906b8-605f-410f-a801-42526bdcac0e-i0b0',
#   '_score': 1.0,
#   '_source': {'document_id': '833906b8-605f-410f-a801-42526bdcac0e-i0b0',
#    'vacina_descricao_dose': '1º Reforço',
#    'data_importacao_rnds': '2023-11-22T18:27:41.000Z',
#    'vacina_grupoAtendimento_codigo': '000207',
#    'estabelecimento_razaoSocial': 'MUNICIPIO DE CURITIBA',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'dt_deleted': None,
#    'paciente_endereco_coIbgeMunicipio': '412550',
#    'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_endereco_coPais': '10',
#    'paciente_racaCor_valor': 'BRANCA',
#    'paciente_id': '377625677535a42871e236c1451031210e6382f7a1970356d94b113f763e28a6',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'estabelecimento_municipio_nome': 'CURITIBA',
#    'paciente_enumSexoBiologico': 'F',
#    '@timestamp': '2023-11-23T21:16:08.547Z',
#    'sistema_origem': 'E-saúde Curitiba',
#    'status': 'final',
#    'estalecimento_noFantasia': 'UMS SAO JOAO DEL REY PSF',
#    'estabelecimento_valor': '0016993',
#    'paciente_endereco_cep': '83005',
#    'vacina_grupoAtendimento_nome': 'Pessoas de 5 a 11 anos',
#    'vacina_fabricante_referencia': None,
#    'vacina_lote': 'GN0764##',
#    'paciente_racaCor_codigo': '01',
#    'ds_condicao_maternal': None,
#    'id_sistema_origem': '19762',
#    'vacina_categoria_codigo': '2',
#    'paciente_idade': 6,
#    'co_condicao_maternal': None,
#    'data_importacao_datalake': '2023-11-23T18:06:25.000Z',
#    'estabelecimento_municipio_codigo': '410690',
#    'vacina_numDose': '6',
#    'vacina_codigo': '99',
#    'paciente_endereco_nmMunicipio': 'SAO JOSE DOS PINHAIS',
#    'vacina_dataAplicacao': '2023-11-22T00:00:00.000Z',
#    'paciente_dataNascimento': '2017-04-21',
#    '@version': '1',
#    'paciente_endereco_uf': 'PR',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'estabelecimento_uf': 'PR'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'cf050216-e315-4ba9-b2c5-0fb342273c72-i0b0',
#   '_score': 1.0,
#   '_source': {'document_id': 'cf050216-e315-4ba9-b2c5-0fb342273c72-i0b0',
#    'vacina_descricao_dose': '1º Reforço',
#    'data_importacao_rnds': '2023-11-23T17:42:34.000Z',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE GUARULHOS',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'dt_deleted': None,
#    'paciente_endereco_coIbgeMunicipio': '351880',
#    'vacina_fabricante_nome': 'PFIZER',
#    'paciente_endereco_coPais': '10',
#    'paciente_racaCor_valor': 'SEM INFORMACAO',
#    'paciente_id': 'ce16388c5fce9f86467485f80ec6961fa711f59c91a45668d4d7e07999d58152',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'estabelecimento_municipio_nome': 'GUARULHOS',
#    'paciente_enumSexoBiologico': 'M',
#    '@timestamp': '2023-11-23T21:16:08.548Z',
#    'sistema_origem': 'VACIVIDA',
#    'status': 'final',
#    'estalecimento_noFantasia': 'UBS MORROS',
#    'estabelecimento_valor': '2052318',
#    'paciente_endereco_cep': '07135',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária',
#    'vacina_fabricante_referencia': None,
#    'vacina_lote': '2F1070A',
#    'paciente_racaCor_codigo': '99',
#    'ds_condicao_maternal': None,
#    'id_sistema_origem': '18262',
#    'vacina_categoria_codigo': '2',
#    'paciente_idade': 29,
#    'co_condicao_maternal': None,
#    'data_importacao_datalake': '2023-11-23T18:06:25.000Z',
#    'estabelecimento_municipio_codigo': '351880',
#    'vacina_numDose': '6',
#    'vacina_codigo': '87',
#    'paciente_endereco_nmMunicipio': 'GUARULHOS',
#    'vacina_dataAplicacao': '2023-11-23T00:00:00.000Z',
#    'paciente_dataNascimento': '1993-12-17',
#    '@version': '1',
#    'paciente_endereco_uf': 'SP',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'estabelecimento_uf': 'SP'}},
#  {'_index': 'desc-imunizacao-v5',
#   '_type': '_doc',
#   '_id': 'b5d8c0ec-a1ad-45a6-94aa-e2deebee565b-i0b0',
#   '_score': 1.0,
#   '_source': {'document_id': 'b5d8c0ec-a1ad-45a6-94aa-e2deebee565b-i0b0',
#    'vacina_descricao_dose': '1º Reforço',
#    'data_importacao_rnds': '2023-11-23T15:56:38.000Z',
#    'vacina_grupoAtendimento_codigo': '000210',
#    'estabelecimento_razaoSocial': 'PREFEITURA MUNICIPAL DE IRATI',
#    'vacina_nome': 'COVID-19 PFIZER - COMIRNATY PEDIÁTRICA',
#    'paciente_endereco_nmPais': 'BRASIL',
#    'dt_deleted': None,
#    'paciente_endereco_coIbgeMunicipio': '411070',
#    'vacina_fabricante_nome': 'PFIZER - PEDIÁTRICA',
#    'paciente_endereco_coPais': '10',
#    'paciente_racaCor_valor': 'BRANCA',
#    'paciente_id': 'ccdd3c56bfa16ed8298d804919e3e2fb10758e3e0555a66ecfa6116cd46b594e',
#    'paciente_nacionalidade_enumNacionalidade': 'B',
#    'estabelecimento_municipio_nome': 'IRATI',
#    'paciente_enumSexoBiologico': 'M',
#    '@timestamp': '2023-11-23T21:16:08.548Z',
#    'sistema_origem': 'Novo PNI',
#    'status': 'final',
#    'estalecimento_noFantasia': 'UNIDADE BASICA DE SAUDE ADHEMAR VIEIRA DE ARAUJO',
#    'estabelecimento_valor': '2502313',
#    'paciente_endereco_cep': '84500',
#    'vacina_grupoAtendimento_nome': 'Faixa Etária',
#    'vacina_fabricante_referencia': '28290',
#    'vacina_lote': 'GN0764',
#    'paciente_racaCor_codigo': '01',
#    'ds_condicao_maternal': 'Nenhuma',
#    'id_sistema_origem': '16341',
#    'vacina_categoria_codigo': '2',
#    'paciente_idade': 9,
#    'co_condicao_maternal': 1,
#    'data_importacao_datalake': '2023-11-23T18:06:25.000Z',
#    'estabelecimento_municipio_codigo': '411070',
#    'vacina_numDose': '6',
#    'vacina_codigo': '99',
#    'paciente_endereco_nmMunicipio': 'IRATI',
#    'vacina_dataAplicacao': '2023-11-23T00:00:00.000Z',
#    'paciente_dataNascimento': '2014-10-10',
#    '@version': '1',
#    'paciente_endereco_uf': 'PR',
#    'vacina_categoria_nome': 'Faixa Etária',
#    'estabelecimento_uf': 'PR'}},
#  ...]

# %%
df_vacinas_brasil = pd.json_normalize(vacinas_brasil["hits"]["hits"])
df_vacinas_brasil
# Out:
#                   _index _type                                        _id  \
# 0     desc-imunizacao-v5  _doc  b561bd45-ec2a-488b-8742-73a64153f07d-i0b0
# 1     desc-imunizacao-v5  _doc  5f52e28f-438c-4acb-993e-a966c9a65d7d-i0b0
# 2     desc-imunizacao-v5  _doc  dc866de7-69bd-4102-ba46-8a71506edb51-i0b0
# 3     desc-imunizacao-v5  _doc  03d35d7a-5a30-4665-8873-cb27fc1bfde7-i0b0
# 4     desc-imunizacao-v5  _doc  ef4a1e15-07ae-4cf0-8d76-6c72d78ecd79-i0b0
# ...                  ...   ...                                        ...
# 9995  desc-imunizacao-v5  _doc  ac8dd0f1-5cc2-4294-9fa6-fd66d23602a4-i0b0
# 9996  desc-imunizacao-v5  _doc  aac9ed4c-5f41-40b1-8c2b-e876944b755d-i0b0
# 9997  desc-imunizacao-v5  _doc  3c9f0944-dc20-4d63-834c-36caa6a5e241-i0b0
# 9998  desc-imunizacao-v5  _doc  edd8b6fe-b6fa-4d46-8979-2d875df60db1-i0b0
# 9999  desc-imunizacao-v5  _doc  6f802ac0-37fb-4c64-8ebb-73ea37130d0e-i0b0
#
#       _score _source.sistema_origem        _source.dt_deleted  \
# 0        1.0               Novo PNI  2023-12-23T00:00:00.000Z
# 1        1.0               Novo PNI                      None
# 2        1.0               Novo PNI                      None
# 3        1.0               Novo PNI                      None
# 4        1.0                 SIGRAH                      None
# ...      ...                    ...                       ...
# 9995     1.0               Novo PNI                      None
# 9996     1.0               Novo PNI                      None
# 9997     1.0               VACIVIDA                      None
# 9998     1.0               Novo PNI                      None
# 9999     1.0               Novo PNI                      None
#
#      _source.paciente_nacionalidade_enumNacionalidade  _source.paciente_idade  \
# 0                                                   B                       5
# 1                                                   B                      10
# 2                                                   B                       9
# 3                                                   B                      12
# 4                                                   B                      14
# ...                                               ...                     ...
# 9995                                                B                      10
# 9996                                                B                      12
# 9997                                                B                       8
# 9998                                                B                      14
# 9999                                                B                      42
#
#      _source.vacina_categoria_nome _source.vacina_fabricante_nome  ...  \
# 0                     Faixa Etária            PFIZER - PEDIÁTRICA  ...
# 1                     Faixa Etária            PFIZER - PEDIÁTRICA  ...
# 2                     Faixa Etária            PFIZER - PEDIÁTRICA  ...
# 3                     Faixa Etária               SINOVAC/BUTANTAN  ...
# 4           Trabalhadores de Saúde                         PFIZER  ...
# ...                            ...                            ...  ...
# 9995                  Faixa Etária            PFIZER - PEDIÁTRICA  ...
# 9996                  Faixa Etária                         PFIZER  ...
# 9997                  Faixa Etária            PFIZER - PEDIÁTRICA  ...
# 9998                  Faixa Etária                         PFIZER  ...
# 9999     Trabalhadores Industriais                         PFIZER  ...
#
#         _source.status _source.paciente_enumSexoBiologico  \
# 0     entered-in-error                                  F
# 1                final                                  M
# 2                final                                  F
# 3                final                                  F
# 4                final                                  M
# ...                ...                                ...
# 9995             final                                  M
# 9996             final                                  M
# 9997             final                                  F
# 9998             final                                  F
# 9999             final                                  M
#
#      _source.paciente_endereco_nmPais _source.estabelecimento_municipio_nome  \
# 0                              BRASIL                        BARAO DE COCAIS
# 1                              BRASIL                            SAO GONCALO
# 2                              BRASIL                               EIRUNEPE
# 3                              BRASIL                      CAREIRO DA VARZEA
# 4                              BRASIL                         BELO HORIZONTE
# ...                               ...                                    ...
# 9995                           BRASIL                               ALENQUER
# 9996                           BRASIL                             TERRA NOVA
# 9997                           BRASIL                                TAUBATE
# 9998                           BRASIL                         CHAPADA GAUCHA
# 9999                           BRASIL                              ARAGUAINA
#
#      _source.vacina_grupoAtendimento_codigo _source.paciente_racaCor_valor  \
# 0                                    000210                         BRANCA
# 1                                    000210                          PARDA
# 2                                    000210                          PARDA
# 3                                    000210                          PARDA
# 4                                    000926                         BRANCA
# ...                                     ...                            ...
# 9995                                 000210                          PARDA
# 9996                                 000210                          PARDA
# 9997                                 000210                          PARDA
# 9998                                 000210                        AMARELA
# 9999                                 001601                        AMARELA
#
#      _source.paciente_endereco_cep _source.estabelecimento_municipio_codigo  \
# 0                            35960                                   310540
# 1                            24716                                   330490
# 2                                                                    130140
# 3                            69075                                   130115
# 4                            30610                                   310620
# ...                            ...                                      ...
# 9995                         68200                                   150040
# 9996                         44270                                   293170
# 9997                         01046                                   355410
# 9998                         39314                                   311615
# 9999                         65928                                   170210
#
#      _source.vacina_fabricante_referencia _source.vacina_grupoAtendimento_nome
# 0                                   28290                         Faixa Etária
# 1                                   28290                         Faixa Etária
# 2                                   28290                         Faixa Etária
# 3                                     152                         Faixa Etária
# 4                                    None                               Outros
# ...                                   ...                                  ...
# 9995                                28290                         Faixa Etária
# 9996                                28290                         Faixa Etária
# 9997                                 None                         Faixa Etária
# 9998                                28290                         Faixa Etária
# 9999                                28290            Trabalhadores Industriais
#
# [10000 rows x 46 columns]

# %%
""" Analisando e tratando as informações contidas em cada coluna e quais delas serão utilizadas para gerar três novos DataFrames.
"""

df_vacinas_brasil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 46 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   _index                                            10000 non-null  object
#  1   _type                                             10000 non-null  object
#  2   _id                                               10000 non-null  object
#  3   _score                                            10000 non-null  float64
#  4   _source.sistema_origem                            10000 non-null  object
#  5   _source.dt_deleted                                203 non-null    object
#  6   _source.paciente_nacionalidade_enumNacionalidade  9999 non-null   object
#  7   _source.paciente_idade                            10000 non-null  int64
#  8   _source.vacina_categoria_nome                     9991 non-null   object
#  9   _source.vacina_fabricante_nome                    10000 non-null  object
#  10  _source.paciente_endereco_nmMunicipio             9999 non-null   object
#  11  _source.paciente_endereco_coPais                  9999 non-null   object
#  12  _source.estabelecimento_uf                        10000 non-null  object
#  13  _source.estabelecimento_razaoSocial               10000 non-null  object
#  14  _source.estabelecimento_valor                     10000 non-null  object
#  15  _source.vacina_lote                               10000 non-null  object
#  16  _source.vacina_dataAplicacao                      10000 non-null  object
#  17  _source.paciente_endereco_uf                      9999 non-null   object
#  18  _source.paciente_endereco_coIbgeMunicipio         9999 non-null   object
#  19  _source.data_importacao_datalake                  10000 non-null  object
#  20  _source.paciente_id                               10000 non-null  object
#  21  _source.@timestamp                                10000 non-null  object
#  22  _source.document_id                               10000 non-null  object
#  23  _source.id_sistema_origem                         10000 non-null  object
#  24  _source.paciente_racaCor_codigo                   10000 non-null  object
#  25  _source.ds_condicao_maternal                      6326 non-null   object
#  26  _source.vacina_descricao_dose                     10000 non-null  object
#  27  _source.estalecimento_noFantasia                  10000 non-null  object
#  28  _source.paciente_dataNascimento                   10000 non-null  object
#  29  _source.data_importacao_rnds                      10000 non-null  object
#  30  _source.@version                                  10000 non-null  object
#  31  _source.vacina_codigo                             10000 non-null  object
#  32  _source.vacina_numDose                            10000 non-null  object
#  33  _source.vacina_nome                               10000 non-null  object
#  34  _source.vacina_categoria_codigo                   9991 non-null   object
#  35  _source.co_condicao_maternal                      6326 non-null   float64
#  36  _source.status                                    10000 non-null  object
#  37  _source.paciente_enumSexoBiologico                10000 non-null  object
#  38  _source.paciente_endereco_nmPais                  9999 non-null   object
#  39  _source.estabelecimento_municipio_nome            10000 non-null  object
#  40  _source.vacina_grupoAtendimento_codigo            10000 non-null  object
#  41  _source.paciente_racaCor_valor                    10000 non-null  object
#  42  _source.paciente_endereco_cep                     9999 non-null   object
#  43  _source.estabelecimento_municipio_codigo          10000 non-null  object
#  44  _source.vacina_fabricante_referencia              6534 non-null   object
#  45  _source.vacina_grupoAtendimento_nome              9993 non-null   object
# dtypes: float64(2), int64(1), object(43)
# memory usage: 3.5+ MB

# %%
""" Criando os Data Frames com as colunas desejadas.
"""

#Data Frame com as informações sobre os pacientes.

df_pacientes_selecao = ['_id','_source.paciente_dataNascimento','_source.paciente_idade',
                        '_source.paciente_racaCor_codigo', '_source.paciente_enumSexoBiologico','_source.paciente_endereco_uf','_source.paciente_endereco_coIbgeMunicipio'] 
df_pacientes = df_vacinas_brasil[df_pacientes_selecao]
df_pacientes.head(10)
# Out:
#                                          _id _source.paciente_dataNascimento  \
# 0  b561bd45-ec2a-488b-8742-73a64153f07d-i0b0                      2017-12-05
# 1  5f52e28f-438c-4acb-993e-a966c9a65d7d-i0b0                      2013-03-17
# 2  dc866de7-69bd-4102-ba46-8a71506edb51-i0b0                      2014-06-03
# 3  03d35d7a-5a30-4665-8873-cb27fc1bfde7-i0b0                      2010-11-17
# 4  ef4a1e15-07ae-4cf0-8d76-6c72d78ecd79-i0b0                      2008-12-16
# 5  39c3e3cb-8404-4bf8-bf45-32a766ecaddf-i0b0                      2008-07-04
# 6  57358f61-b6b4-4d13-bda8-dd7e866614c5-i0b0                      2017-11-19
# 7  b0c913a0-338c-4323-a66e-a9c39a229488-i0b0                      2013-05-05
# 8  e0b00e1f-983e-4d7d-84b5-3ece2c8c71a3-i0b0                      2012-09-17
# 9  89d446ef-4310-496a-a36d-a5672f77207a-i0b0                      2016-06-03
#
#    _source.paciente_idade _source.paciente_racaCor_codigo  \
# 0                       5                              01
# 1                      10                              03
# 2                       9                              03
# 3                      12                              03
# 4                      14                              01
# 5                      15                              01
# 6                       6                              03
# 7                      10                              03
# 8                      11                              03
# 9                       6                              03
#
#   _source.paciente_enumSexoBiologico _source.paciente_endereco_uf  \
# 0                                  F                           MG
# 1                                  M                           RJ
# 2                                  F                           AM
# 3                                  F                           AM
# 4                                  M                           MG
# 5                                  M                           AL
# 6                                  M                           BA
# 7                                  M                           RJ
# 8                                  M                           CE
# 9                                  M                           CE
#
#   _source.paciente_endereco_coIbgeMunicipio
# 0                                    315720
# 1                                    330490
# 2                                    130140
# 3                                    130260
# 4                                    310620
# 5                                    270430
# 6                                    291840
# 7                                    330455
# 8                                    231320
# 9                                    230195

# %%
#Data Frame com as informações sobre as vacinas.

df_info_vacinas_selecao = ['_id', '_source.vacina_nome','_source.vacina_fabricante_nome', '_source.vacina_lote', '_source.vacina_codigo', '_source.vacina_fabricante_referencia',
                            '_source.vacina_categoria_codigo', '_source.vacina_grupoAtendimento_nome', '_source.status' ]
df_info_vacinas = df_vacinas_brasil[df_info_vacinas_selecao]
df_info_vacinas.head(10)
# Out:
#                                          _id  \
# 0  b561bd45-ec2a-488b-8742-73a64153f07d-i0b0
# 1  5f52e28f-438c-4acb-993e-a966c9a65d7d-i0b0
# 2  dc866de7-69bd-4102-ba46-8a71506edb51-i0b0
# 3  03d35d7a-5a30-4665-8873-cb27fc1bfde7-i0b0
# 4  ef4a1e15-07ae-4cf0-8d76-6c72d78ecd79-i0b0
# 5  39c3e3cb-8404-4bf8-bf45-32a766ecaddf-i0b0
# 6  57358f61-b6b4-4d13-bda8-dd7e866614c5-i0b0
# 7  b0c913a0-338c-4323-a66e-a9c39a229488-i0b0
# 8  e0b00e1f-983e-4d7d-84b5-3ece2c8c71a3-i0b0
# 9  89d446ef-4310-496a-a36d-a5672f77207a-i0b0
#
#                       _source.vacina_nome _source.vacina_fabricante_nome  \
# 0  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA            PFIZER - PEDIÁTRICA
# 1  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA            PFIZER - PEDIÁTRICA
# 2  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA            PFIZER - PEDIÁTRICA
# 3   COVID-19 SINOVAC/BUTANTAN - CORONAVAC               SINOVAC/BUTANTAN
# 4             COVID-19 PFIZER - COMIRNATY                         PFIZER
# 5             COVID-19 PFIZER - COMIRNATY                         PFIZER
# 6  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA            PFIZER - PEDIÁTRICA
# 7  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA            PFIZER - PEDIÁTRICA
# 8  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA            PFIZER - PEDIÁTRICA
# 9  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA            PFIZER - PEDIÁTRICA
#
#   _source.vacina_lote _source.vacina_codigo  \
# 0              GN0764                    99
# 1              GN0764                    99
# 2              GN0764                    99
# 3              220303                    86
# 4              FW6014                    87
# 5             2F1070A                    87
# 6              GN0764                    99
# 7              GN0764                    99
# 8              GY0354                    99
# 9              FX9154                    99
#
#   _source.vacina_fabricante_referencia _source.vacina_categoria_codigo  \
# 0                                28290                               2
# 1                                28290                               2
# 2                                28290                               2
# 3                                  152                               2
# 4                                 None                               9
# 5                                28290                               2
# 6                                28290                               2
# 7                                28290                               2
# 8                                28290                               2
# 9                                28290                               2
#
#   _source.vacina_grupoAtendimento_nome    _source.status
# 0                         Faixa Etária  entered-in-error
# 1                         Faixa Etária             final
# 2                         Faixa Etária             final
# 3                         Faixa Etária             final
# 4                               Outros             final
# 5                         Faixa Etária             final
# 6                         Faixa Etária             final
# 7                         Faixa Etária             final
# 8                         Faixa Etária             final
# 9                         Faixa Etária             final

# %%
#Data Frame com as informações sobre as aplicações.


df_aplicacao_selecao = ['_id','_source.vacina_nome','_source.vacina_categoria_nome', '_source.estabelecimento_uf', '_source.estabelecimento_municipio_nome'
                        ,'_source.estabelecimento_razaoSocial','_source.vacina_dataAplicacao', '_source.vacina_descricao_dose','_source.vacina_numDose' ]
df_aplicacao = df_vacinas_brasil[df_aplicacao_selecao]
df_aplicacao.head(5)
# Out:
#                                          _id  \
# 0  b561bd45-ec2a-488b-8742-73a64153f07d-i0b0
# 1  5f52e28f-438c-4acb-993e-a966c9a65d7d-i0b0
# 2  dc866de7-69bd-4102-ba46-8a71506edb51-i0b0
# 3  03d35d7a-5a30-4665-8873-cb27fc1bfde7-i0b0
# 4  ef4a1e15-07ae-4cf0-8d76-6c72d78ecd79-i0b0
#
#                       _source.vacina_nome _source.vacina_categoria_nome  \
# 0  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA                  Faixa Etária
# 1  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA                  Faixa Etária
# 2  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA                  Faixa Etária
# 3   COVID-19 SINOVAC/BUTANTAN - CORONAVAC                  Faixa Etária
# 4             COVID-19 PFIZER - COMIRNATY        Trabalhadores de Saúde
#
#   _source.estabelecimento_uf _source.estabelecimento_municipio_nome  \
# 0                         MG                        BARAO DE COCAIS
# 1                         RJ                            SAO GONCALO
# 2                         AM                               EIRUNEPE
# 3                         AM                      CAREIRO DA VARZEA
# 4                         MG                         BELO HORIZONTE
#
#             _source.estabelecimento_razaoSocial _source.vacina_dataAplicacao  \
# 0       PREFEITURA MUNICIPAL DE BARAO DE COCAIS     2023-10-21T00:00:00.000Z
# 1  SECRETARIA MUNICIPAL DE SAUDE DE SAO GONCALO     2023-12-22T00:00:00.000Z
# 2              PREFEITURA MUNICIPAL DE EIRUNEPE     2023-12-01T00:00:00.000Z
# 3     PREFEITURA MUNICIPAL DE CAREIRO DA VARZEA     2023-09-22T00:00:00.000Z
# 4                   MUNICIPIO DE BELO HORIZONTE     2023-02-03T00:00:00.000Z
#
#   _source.vacina_descricao_dose _source.vacina_numDose
# 0                       3ª Dose                      3
# 1                       2ª Dose                      2
# 2                       3ª Dose                      3
# 3                       2ª Dose                      2
# 4                       Reforço                     38

# %%
""" Renomeando as colunas dos DataFrames.
"""


renomeadas_pacientes = {'_id':'id_paciente','_source.paciente_dataNascimento': 'data_nascimento','_source.paciente_idade': 'idade',
                        '_source.paciente_racaCor_codigo' : 'codigo_raca', '_source.paciente_enumSexoBiologico': 'sexo','_source.paciente_endereco_uf': 'UF',
                        '_source.paciente_endereco_coIbgeMunicipio': 'codigo_municipio'}


df_pacientes= df_pacientes.rename(columns= renomeadas_pacientes)
df_pacientes.head(5)
# Out:
#                                  id_paciente data_nascimento  idade  \
# 0  b561bd45-ec2a-488b-8742-73a64153f07d-i0b0      2017-12-05      5
# 1  5f52e28f-438c-4acb-993e-a966c9a65d7d-i0b0      2013-03-17     10
# 2  dc866de7-69bd-4102-ba46-8a71506edb51-i0b0      2014-06-03      9
# 3  03d35d7a-5a30-4665-8873-cb27fc1bfde7-i0b0      2010-11-17     12
# 4  ef4a1e15-07ae-4cf0-8d76-6c72d78ecd79-i0b0      2008-12-16     14
#
#   codigo_raca sexo  UF codigo_municipio
# 0          01    F  MG           315720
# 1          03    M  RJ           330490
# 2          03    F  AM           130140
# 3          03    F  AM           130260
# 4          01    M  MG           310620

# %%
renomeadas_info_vacinas = {'_id':'id_paciente', '_source.vacina_nome':'nome_vacina','_source.vacina_fabricante_nome':'fabricante', '_source.vacina_lote':'lote',
                            '_source.vacina_codigo':'lote_vacina', '_source.vacina_fabricante_referencia':'referencia_fabricante',
                            '_source.vacina_categoria_codigo':'codigo_categoria', '_source.vacina_grupoAtendimento_nome':'grupo_atendimento', '_source.status': 'status'}

df_info_vacinas = df_info_vacinas.rename(columns= renomeadas_info_vacinas)
df_info_vacinas.head(5)
# Out:
#                                  id_paciente  \
# 0  b561bd45-ec2a-488b-8742-73a64153f07d-i0b0
# 1  5f52e28f-438c-4acb-993e-a966c9a65d7d-i0b0
# 2  dc866de7-69bd-4102-ba46-8a71506edb51-i0b0
# 3  03d35d7a-5a30-4665-8873-cb27fc1bfde7-i0b0
# 4  ef4a1e15-07ae-4cf0-8d76-6c72d78ecd79-i0b0
#
#                               nome_vacina           fabricante    lote  \
# 0  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA  PFIZER - PEDIÁTRICA  GN0764
# 1  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA  PFIZER - PEDIÁTRICA  GN0764
# 2  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA  PFIZER - PEDIÁTRICA  GN0764
# 3   COVID-19 SINOVAC/BUTANTAN - CORONAVAC     SINOVAC/BUTANTAN  220303
# 4             COVID-19 PFIZER - COMIRNATY               PFIZER  FW6014
#
#   lote_vacina referencia_fabricante codigo_categoria grupo_atendimento  \
# 0          99                 28290                2      Faixa Etária
# 1          99                 28290                2      Faixa Etária
# 2          99                 28290                2      Faixa Etária
# 3          86                   152                2      Faixa Etária
# 4          87                  None                9            Outros
#
#              status
# 0  entered-in-error
# 1             final
# 2             final
# 3             final
# 4             final

# %%
renomeadas_aplicacao = {'_id':'id_paciente','_source.vacina_nome':'nome_vacina','_source.vacina_categoria_nome':'categoria_aplicacao', '_source.estabelecimento_uf': 'UF_estabelecimento',
                         '_source.estabelecimento_municipio_nome':'nome_municipio','_source.estabelecimento_razaoSocial':'razao_social','_source.vacina_dataAplicacao':'data_aplicacao', 
                         '_source.vacina_descricao_dose':'descricao_dose','_source.vacina_numDose':'numero_dose'}

df_aplicacao = df_aplicacao.rename(columns= renomeadas_aplicacao)
df_aplicacao.head(5)
# Out:
#                                  id_paciente  \
# 0  b561bd45-ec2a-488b-8742-73a64153f07d-i0b0
# 1  5f52e28f-438c-4acb-993e-a966c9a65d7d-i0b0
# 2  dc866de7-69bd-4102-ba46-8a71506edb51-i0b0
# 3  03d35d7a-5a30-4665-8873-cb27fc1bfde7-i0b0
# 4  ef4a1e15-07ae-4cf0-8d76-6c72d78ecd79-i0b0
#
#                               nome_vacina     categoria_aplicacao  \
# 0  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA            Faixa Etária
# 1  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA            Faixa Etária
# 2  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA            Faixa Etária
# 3   COVID-19 SINOVAC/BUTANTAN - CORONAVAC            Faixa Etária
# 4             COVID-19 PFIZER - COMIRNATY  Trabalhadores de Saúde
#
#   UF_estabelecimento     nome_municipio  \
# 0                 MG    BARAO DE COCAIS
# 1                 RJ        SAO GONCALO
# 2                 AM           EIRUNEPE
# 3                 AM  CAREIRO DA VARZEA
# 4                 MG     BELO HORIZONTE
#
#                                    razao_social            data_aplicacao  \
# 0       PREFEITURA MUNICIPAL DE BARAO DE COCAIS  2023-10-21T00:00:00.000Z
# 1  SECRETARIA MUNICIPAL DE SAUDE DE SAO GONCALO  2023-12-22T00:00:00.000Z
# 2              PREFEITURA MUNICIPAL DE EIRUNEPE  2023-12-01T00:00:00.000Z
# 3     PREFEITURA MUNICIPAL DE CAREIRO DA VARZEA  2023-09-22T00:00:00.000Z
# 4                   MUNICIPIO DE BELO HORIZONTE  2023-02-03T00:00:00.000Z
#
#   descricao_dose numero_dose
# 0        3ª Dose           3
# 1        2ª Dose           2
# 2        3ª Dose           3
# 3        2ª Dose           2
# 4        Reforço          38

# %%
"""
Verificando o tipo das variáveis das colunas para o ajuste de seu tipo.
"""


df_pacientes.dtypes
# Out:
# id_paciente         object
# data_nascimento     object
# idade                int64
# codigo_raca         object
# sexo                object
# UF                  object
# codigo_municipio    object
# dtype: object

# %%
df_pacientes['data_nascimento'] = pd.to_datetime(df_pacientes['data_nascimento'])
df_pacientes.dtypes
# Out:
# id_paciente                 object
# data_nascimento     datetime64[ns]
# idade                        int64
# codigo_raca                 object
# sexo                        object
# UF                          object
# codigo_municipio            object
# dtype: object

# %%
converter_int = ['codigo_raca']

df_pacientes[converter_int] = df_pacientes[converter_int].astype(int)
df_pacientes.dtypes
# Out:
# id_paciente                 object
# data_nascimento     datetime64[ns]
# idade                        int64
# codigo_raca                  int32
# sexo                        object
# UF                          object
# codigo_municipio            object
# dtype: object

# %%
df_info_vacinas.dtypes
# Out:
# id_paciente              object
# nome_vacina              object
# fabricante               object
# lote                     object
# lote_vacina              object
# referencia_fabricante    object
# codigo_categoria         object
# grupo_atendimento        object
# status                   object
# dtype: object

# %%
df_aplicacao.dtypes
converter_int = ['numero_dose']

df_aplicacao[converter_int] = df_aplicacao[converter_int].astype(int)
df_aplicacao.dtypes
# Out:
# id_paciente            object
# nome_vacina            object
# categoria_aplicacao    object
# UF_estabelecimento     object
# nome_municipio         object
# razao_social           object
# data_aplicacao         object
# descricao_dose         object
# numero_dose             int32
# dtype: object

# %%
df_aplicacao['data_aplicacao'] = pd.to_datetime(df_aplicacao['data_aplicacao'])
df_aplicacao['data_aplicacao'] = df_aplicacao['data_aplicacao'].dt.strftime('%Y-%m-%d')
df_aplicacao['data_aplicacao'] = pd.to_datetime(df_aplicacao['data_aplicacao'])

df_aplicacao.dtypes
# Out:
# id_paciente                    object
# nome_vacina                    object
# categoria_aplicacao            object
# UF_estabelecimento             object
# nome_municipio                 object
# razao_social                   object
# data_aplicacao         datetime64[ns]
# descricao_dose                 object
# numero_dose                     int32
# dtype: object

# %%
""" Verificando a existência de nulos nos DataFrames e lidando com a ausência de dados.
"""

#pacientes
df_pacientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_paciente       10000 non-null  object
#  1   data_nascimento   10000 non-null  datetime64[ns]
#  2   idade             10000 non-null  int64
#  3   codigo_raca       10000 non-null  int32
#  4   sexo              10000 non-null  object
#  5   UF                9999 non-null   object
#  6   codigo_municipio  9999 non-null   object
# dtypes: datetime64[ns](1), int32(1), int64(1), object(4)
# memory usage: 507.9+ KB

# %%
df_pacientes['codigo_municipio'] = df_pacientes['codigo_municipio'].fillna('ausente')
df_pacientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_paciente       10000 non-null  object
#  1   data_nascimento   10000 non-null  datetime64[ns]
#  2   idade             10000 non-null  int64
#  3   codigo_raca       10000 non-null  int32
#  4   sexo              10000 non-null  object
#  5   UF                9999 non-null   object
#  6   codigo_municipio  10000 non-null  object
# dtypes: datetime64[ns](1), int32(1), int64(1), object(4)
# memory usage: 507.9+ KB

# %%
#info_vacinas
df_info_vacinas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id_paciente            10000 non-null  object
#  1   nome_vacina            10000 non-null  object
#  2   fabricante             10000 non-null  object
#  3   lote                   10000 non-null  object
#  4   lote_vacina            10000 non-null  object
#  5   referencia_fabricante  6534 non-null   object
#  6   codigo_categoria       9991 non-null   object
#  7   grupo_atendimento      9993 non-null   object
#  8   status                 10000 non-null  object
# dtypes: object(9)
# memory usage: 703.3+ KB

# %%
df_info_vacinas['codigo_categoria'] = df_info_vacinas['codigo_categoria'].fillna('ausente')
df_info_vacinas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id_paciente            10000 non-null  object
#  1   nome_vacina            10000 non-null  object
#  2   fabricante             10000 non-null  object
#  3   lote                   10000 non-null  object
#  4   lote_vacina            10000 non-null  object
#  5   referencia_fabricante  6534 non-null   object
#  6   codigo_categoria       10000 non-null  object
#  7   grupo_atendimento      9993 non-null   object
#  8   status                 10000 non-null  object
# dtypes: object(9)
# memory usage: 703.3+ KB

# %%
#aplicação

df_aplicacao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id_paciente          10000 non-null  object
#  1   nome_vacina          10000 non-null  object
#  2   categoria_aplicacao  9991 non-null   object
#  3   UF_estabelecimento   10000 non-null  object
#  4   nome_municipio       10000 non-null  object
#  5   razao_social         10000 non-null  object
#  6   data_aplicacao       10000 non-null  datetime64[ns]
#  7   descricao_dose       10000 non-null  object
#  8   numero_dose          10000 non-null  int32
# dtypes: datetime64[ns](1), int32(1), object(7)
# memory usage: 664.2+ KB

# %%
df_aplicacao['categoria_aplicacao'] = df_aplicacao['categoria_aplicacao'].fillna('ausente')
df_aplicacao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id_paciente          10000 non-null  object
#  1   nome_vacina          10000 non-null  object
#  2   categoria_aplicacao  10000 non-null  object
#  3   UF_estabelecimento   10000 non-null  object
#  4   nome_municipio       10000 non-null  object
#  5   razao_social         10000 non-null  object
#  6   data_aplicacao       10000 non-null  datetime64[ns]
#  7   descricao_dose       10000 non-null  object
#  8   numero_dose          10000 non-null  int32
# dtypes: datetime64[ns](1), int32(1), object(7)
# memory usage: 664.2+ KB

# %%
""" Realizando o relacionamento entre os DataFrames.
"""
# Out:
# ' Realizando o relacionamento entre os DataFrames.\n'

# %%
# DataFrame de informações de vacinas por paciente.

df_pacientes_info_vacinas = pd.merge(df_pacientes, df_info_vacinas, on='id_paciente', how='left')
df_pacientes_info_vacinas.head(10)
# Out:
#                                  id_paciente data_nascimento  idade  \
# 0  b561bd45-ec2a-488b-8742-73a64153f07d-i0b0      2017-12-05      5
# 1  5f52e28f-438c-4acb-993e-a966c9a65d7d-i0b0      2013-03-17     10
# 2  dc866de7-69bd-4102-ba46-8a71506edb51-i0b0      2014-06-03      9
# 3  03d35d7a-5a30-4665-8873-cb27fc1bfde7-i0b0      2010-11-17     12
# 4  ef4a1e15-07ae-4cf0-8d76-6c72d78ecd79-i0b0      2008-12-16     14
# 5  39c3e3cb-8404-4bf8-bf45-32a766ecaddf-i0b0      2008-07-04     15
# 6  57358f61-b6b4-4d13-bda8-dd7e866614c5-i0b0      2017-11-19      6
# 7  b0c913a0-338c-4323-a66e-a9c39a229488-i0b0      2013-05-05     10
# 8  e0b00e1f-983e-4d7d-84b5-3ece2c8c71a3-i0b0      2012-09-17     11
# 9  89d446ef-4310-496a-a36d-a5672f77207a-i0b0      2016-06-03      6
#
#    codigo_raca sexo  UF codigo_municipio  \
# 0            1    F  MG           315720
# 1            3    M  RJ           330490
# 2            3    F  AM           130140
# 3            3    F  AM           130260
# 4            1    M  MG           310620
# 5            1    M  AL           270430
# 6            3    M  BA           291840
# 7            3    M  RJ           330455
# 8            3    M  CE           231320
# 9            3    M  CE           230195
#
#                               nome_vacina           fabricante     lote  \
# 0  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA  PFIZER - PEDIÁTRICA   GN0764
# 1  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA  PFIZER - PEDIÁTRICA   GN0764
# 2  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA  PFIZER - PEDIÁTRICA   GN0764
# 3   COVID-19 SINOVAC/BUTANTAN - CORONAVAC     SINOVAC/BUTANTAN   220303
# 4             COVID-19 PFIZER - COMIRNATY               PFIZER   FW6014
# 5             COVID-19 PFIZER - COMIRNATY               PFIZER  2F1070A
# 6  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA  PFIZER - PEDIÁTRICA   GN0764
# 7  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA  PFIZER - PEDIÁTRICA   GN0764
# 8  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA  PFIZER - PEDIÁTRICA   GY0354
# 9  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA  PFIZER - PEDIÁTRICA   FX9154
#
#   lote_vacina referencia_fabricante codigo_categoria grupo_atendimento  \
# 0          99                 28290                2      Faixa Etária
# 1          99                 28290                2      Faixa Etária
# 2          99                 28290                2      Faixa Etária
# 3          86                   152                2      Faixa Etária
# 4          87                  None                9            Outros
# 5          87                 28290                2      Faixa Etária
# 6          99                 28290                2      Faixa Etária
# 7          99                 28290                2      Faixa Etária
# 8          99                 28290                2      Faixa Etária
# 9          99                 28290                2      Faixa Etária
#
#              status
# 0  entered-in-error
# 1             final
# 2             final
# 3             final
# 4             final
# 5             final
# 6             final
# 7             final
# 8             final
# 9             final

# %%
# DataFrame de informações de aplicações por paciente.

df_pacientes_aplicacao = pd.merge(df_pacientes, df_aplicacao, on='id_paciente', how='left')
df_pacientes_aplicacao.head(5)
# Out:
#                                  id_paciente data_nascimento  idade  \
# 0  b561bd45-ec2a-488b-8742-73a64153f07d-i0b0      2017-12-05      5
# 1  5f52e28f-438c-4acb-993e-a966c9a65d7d-i0b0      2013-03-17     10
# 2  dc866de7-69bd-4102-ba46-8a71506edb51-i0b0      2014-06-03      9
# 3  03d35d7a-5a30-4665-8873-cb27fc1bfde7-i0b0      2010-11-17     12
# 4  ef4a1e15-07ae-4cf0-8d76-6c72d78ecd79-i0b0      2008-12-16     14
#
#    codigo_raca sexo  UF codigo_municipio  \
# 0            1    F  MG           315720
# 1            3    M  RJ           330490
# 2            3    F  AM           130140
# 3            3    F  AM           130260
# 4            1    M  MG           310620
#
#                               nome_vacina     categoria_aplicacao  \
# 0  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA            Faixa Etária
# 1  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA            Faixa Etária
# 2  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA            Faixa Etária
# 3   COVID-19 SINOVAC/BUTANTAN - CORONAVAC            Faixa Etária
# 4             COVID-19 PFIZER - COMIRNATY  Trabalhadores de Saúde
#
#   UF_estabelecimento     nome_municipio  \
# 0                 MG    BARAO DE COCAIS
# 1                 RJ        SAO GONCALO
# 2                 AM           EIRUNEPE
# 3                 AM  CAREIRO DA VARZEA
# 4                 MG     BELO HORIZONTE
#
#                                    razao_social data_aplicacao descricao_dose  \
# 0       PREFEITURA MUNICIPAL DE BARAO DE COCAIS     2023-10-21        3ª Dose
# 1  SECRETARIA MUNICIPAL DE SAUDE DE SAO GONCALO     2023-12-22        2ª Dose
# 2              PREFEITURA MUNICIPAL DE EIRUNEPE     2023-12-01        3ª Dose
# 3     PREFEITURA MUNICIPAL DE CAREIRO DA VARZEA     2023-09-22        2ª Dose
# 4                   MUNICIPIO DE BELO HORIZONTE     2023-02-03        Reforço
#
#    numero_dose
# 0            3
# 1            2
# 2            3
# 3            2
# 4           38

# %%
# DataFrame de informações de vacinas por aplicação.

df_vacinas_aplicacao = pd.merge(df_info_vacinas, df_aplicacao, on='id_paciente', how='left')
df_pacientes_aplicacao.head(5)
# Out:
#                                  id_paciente data_nascimento  idade  \
# 0  b561bd45-ec2a-488b-8742-73a64153f07d-i0b0      2017-12-05      5
# 1  5f52e28f-438c-4acb-993e-a966c9a65d7d-i0b0      2013-03-17     10
# 2  dc866de7-69bd-4102-ba46-8a71506edb51-i0b0      2014-06-03      9
# 3  03d35d7a-5a30-4665-8873-cb27fc1bfde7-i0b0      2010-11-17     12
# 4  ef4a1e15-07ae-4cf0-8d76-6c72d78ecd79-i0b0      2008-12-16     14
#
#    codigo_raca sexo  UF codigo_municipio  \
# 0            1    F  MG           315720
# 1            3    M  RJ           330490
# 2            3    F  AM           130140
# 3            3    F  AM           130260
# 4            1    M  MG           310620
#
#                               nome_vacina     categoria_aplicacao  \
# 0  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA            Faixa Etária
# 1  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA            Faixa Etária
# 2  COVID-19 PFIZER - COMIRNATY PEDIÁTRICA            Faixa Etária
# 3   COVID-19 SINOVAC/BUTANTAN - CORONAVAC            Faixa Etária
# 4             COVID-19 PFIZER - COMIRNATY  Trabalhadores de Saúde
#
#   UF_estabelecimento     nome_municipio  \
# 0                 MG    BARAO DE COCAIS
# 1                 RJ        SAO GONCALO
# 2                 AM           EIRUNEPE
# 3                 AM  CAREIRO DA VARZEA
# 4                 MG     BELO HORIZONTE
#
#                                    razao_social data_aplicacao descricao_dose  \
# 0       PREFEITURA MUNICIPAL DE BARAO DE COCAIS     2023-10-21        3ª Dose
# 1  SECRETARIA MUNICIPAL DE SAUDE DE SAO GONCALO     2023-12-22        2ª Dose
# 2              PREFEITURA MUNICIPAL DE EIRUNEPE     2023-12-01        3ª Dose
# 3     PREFEITURA MUNICIPAL DE CAREIRO DA VARZEA     2023-09-22        2ª Dose
# 4                   MUNICIPIO DE BELO HORIZONTE     2023-02-03        Reforço
#
#    numero_dose
# 0            3
# 1            2
# 2            3
# 3            2
# 4           38
